# %% [markdown]
# # ObsID : 0945030131, SRCNUM : 7, Instru : EMOS2
# Not on Simbad

# %% [markdown]
# ## ESASky
# There are a bunch of EPIC Stack pointers on the light green/blue source and one pointer on an extremely close blue source. https://sky.esa.int/esasky/?target=52.38566666666666%20-28.617833333333333&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# **Green source**
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J032932.2-283705
# - IAU name : 4XMM J032932.3-283705
# - RA : 03h 29m 32.247s
# - DEC : -28° 37' 05.84"
#
# **Blue source**
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J032933.0-283717
# - IAU name : 4XMM J032933.1-283720
# - RA : 03h 29m 33.006s
# - DEC : -28° 37' 17.85""

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files
# Spectrum, Background, Response, Auxiliary response.

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945030131_SRCNUM7_EMOS2_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.787e-03 +/- 6.825e-04 (77.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-78
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.4e+04 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0945030131_SRCNUM7_EMOS2_background_spectrum.fits
#   Background Exposure Time: 1.398e+04 sec
#  Using Response (RMF) File            ObsID0945030131_SRCNUM7_EMOS2.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945030131_SRCNUM7_EMOS2.arf

# %%
n_cts = 4.787e-03*1.4e+04
print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 67.018
#
# The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.000001 0.05")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
#      4 channels (1-4) ignored in spectrum #     1
#       No channels ignored (no channels in specified range)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 657.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              8.381526e+06     using 74 bins.
#
# Test statistic : Chi-Squared              1.461004e+12     using 74 bins.
#  Null hypothesis probability of 0.000000e+00 with 71 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 162.715      1.72193e+06  -1      0.416391       197.379      0.410491
# 162.007      1.021         0      0.119245       198.700      0.256455
# 161.164      2.95652       0    0.00856789       198.660      0.262065
# 160.975      3.36068       0    0.00251901       198.604      0.269535
# 160.829      3.26983       0    0.00105501       198.545      0.276968
# 160.698      3.16172       0   0.000340119       198.484      0.284233
# 160.58       3.05939       0   0.000165192       198.421      0.291296
# 160.472      2.96358       0   7.94184e-05       198.357      0.298137
# 160.372      2.87655       0   3.73177e-05       198.291      0.304740
-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.5425E-11| -0.0001   0.0000   1.0000
#  4.4631E-04|  0.9999   0.0132   0.0001
#  1.2841E+00| -0.0132   0.9999  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.716e-04  -1.700e-02   1.533e-07
#   -1.700e-02   1.284e+00  -7.465e-06
#    1.533e-07  -7.465e-06   6.545e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# aluel Model Component  Parameter  Unit     V
#  par  comp
#    1    1   TBabs      nH         10^22    6.74186E-07  +/-  2.59153E-02
#    2    2   bremss     kT         keV      2.23316      +/-  1.13307
#    3    2   bremss     norm                2.80722E-05  +/-  8.09033E-06
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 63.5343     using 74 bins.
#
# Test statistic : Chi-Squared                 66.0737     using 74 bins.
#  Null hypothesis probability of 6.4321e-01 with 71 degrees of freedom
#  Model Flux 6.8328e-05 photons (9.0176e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 661.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic                771907.8     using 74 bins.
#
# Test statistic : Chi-Squared              4.959239e+09     using 74 bins.
#  Null hypothesis probability of 0.000000e+00 with 71 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 433409       223059       -3      0.381752       34.8611      0.443534
# 191827       172515       -4      0.119195       15.5528      0.131192
# 38102.6      249306       -5     0.0386489       5.65858     0.0202656
# 13046.6      320132       -6     0.0152183       38.1055    0.00929013
# 7525.53      245115       -7    0.00429374       12.3274    0.00430691
# 1424.84      311916       -8    0.00195271      0.471182   0.000302125
# 64.4793      888454       -9   0.000460285       4.32940   5.83263e-05
# 63.4626      2166.78     -10   0.000157208       2.49079   4.98560e-05
# 63.4217      17503.3     -11   1.91430e-05       2.76225   5.04102e-05
# 63.3888      23125.6      -1   4.06950e-06       2.84562   5.09922e-05
# 63.3812      21553.4      -1   3.01651e-07       2.85909   5.11177e-05
# 63.3799      21099        -1   6.61092e-08       2.86153   5.11408e-05
# 63.3796      21014.9      -1   7.21967e-09       2.86197   5.11450e-05
# 63.3796      20999.7      -1   3.53903e-09       2.86205   5.11458e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  5.1022E-11| -0.0002  -0.0000   1.0000
#  4.9453E-04|  1.0000   0.0015   0.0002
#  8.3794E-01| -0.0015   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.965e-04  -1.271e-03   9.756e-08
#   -1.271e-03   8.379e-01   3.555e-06
#    9.756e-08   3.555e-06   8.754e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.53903E-09  +/-  2.22814E-02
#    2    2   apec       kT         keV      2.86205      +/-  0.915392
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                5.11458E-05  +/-  9.35612E-06
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 63.3796     using 74 bins.
#
# Test statistic : Chi-Squared                 60.9136     using 74 bins.
#  Null hypothesis probability of 7.9773e-01 with 71 degrees of freedom
#  Model Flux 5.3547e-05 photons (9.0326e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 659.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              4.964480e+06     using 74 bins.
#
# Test statistic : Chi-Squared              3.386612e+11     using 74 bins.
#  Null hypothesis probability of 0.000000e+00 with 71 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 3.35327e+06  1.24504e+06  -2      0.127246       5.89500      0.298440
# 171.21       5.77289e+06  -3       4143.42      -2.03758      0.114031
# 171.21       1.37088e-10  -4       999999.      -2.43501   4.17450e+10
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0000E+18| -0.0008  -0.2710   0.9626
#  1.4854E+28|  0.0228  -0.9623  -0.2709
#  5.6625E+35|  0.9997   0.0217   0.0070
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.660e+35   1.231e+34   3.941e+33
#    1.231e+34   2.678e+32   8.574e+31
#    3.941e+33   8.574e+31   2.744e+31
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.22718e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 62.4689      75106.4      -1   1.22718e-17      0.484238   1.33878e-06       2.98740   4.97090e-05
# 62.1631      52297.8       0   1.22718e-17      0.803349   1.24949e-06       2.93740   4.97925e-05
# 61.8036      82873.3      -1   1.22718e-17      0.751194   2.16512e-06       2.96124   4.86646e-05
# 61.787       13353.7      -2   1.22718e-17      0.784145   2.46049e-06       2.98621   4.80254e-05
# 61.7865      1494.77      -3   1.22718e-17      0.778080   2.47404e-06       2.98866   4.79948e-05
# 61.7865      12.2558      -4   1.22718e-17      0.778091   2.47424e-06       2.98866   4.79946e-05
# 61.7865      0.00369223    3   2.52178e-18      0.778091   2.47424e-06       2.98866   4.79946e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  2.9950E-12| -0.0000  -0.0000   0.9898  -0.0000   0.1424
#  8.8965E-11| -0.0000   0.0000  -0.1424  -0.0000   0.9898
#  1.3306E-01| -0.0004  -0.9943  -0.0000   0.1064   0.0000
#  1.4107E+00| -0.0009  -0.1064  -0.0000  -0.9943  -0.0000
#  3.5483E+03|  1.0000  -0.0005  -0.0000  -0.0009   0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    3.548e+03  -1.683e+00  -1.023e-05  -3.021e+00   1.261e-04
#   -1.683e+00   1.483e-01   4.495e-07   1.367e-01  -6.519e-07
#   -1.023e-05   4.495e-07   6.268e-12   8.653e-07  -1.310e-11
#   -3.021e+00   1.367e-01   8.653e-07   1.399e+00   2.664e-06
#    1.261e-04  -6.519e-07  -1.310e-11   2.664e-06   1.027e-10
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.52178E-18  +/-  59.5678
#    2   apec       kT         keV      0.778091     +/-  0.385134
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.47424E-06  +/-  2.50351E-06
#    6    3   apec       kT         keV      2.98866      +/-  1.18271
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                4.79946E-05  +/-  1.01345E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 61.7865     using 74 bins.
#
# Test statistic : Chi-Squared                 64.3106     using 74 bins.
#  Null hypothesis probability of 6.3739e-01 with 69 degrees of freedom
#  Model Flux 5.7046e-05 photons (9.4274e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 52.3844241°
# - Dec = -28.6182713°
#
# 52.38 -28.62
#
# **Column density :** nH = 4*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
print()
print(color.BOLD+"apec+apec"+color.END)
print(f"(tbabs) : {nH_apecapec*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 40055.692113514604
#
# bremss
# (tbabs) : 6741858520214507.0
#
# apec
# (tbabs) : 35390297392660.48
#
# powerlaw
# (tbabs) : 9.999991244404016e+27
#
# apec+apec
# (tbabs) : 25217.759248474133

# %% [markdown]
# ## Flux
# ### X-ray flux
# - X-ray Flux of the best-fitting model ``Apec + Apec`` with Chi-squared = 61.7856 using 74 bins: **9.4274e-14 ergs/cm^2/s**.

# %%
Flux = 9.4274e-14 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END+f"F_x-ray = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux : F_x-ray = 9.4274e-14 ergs/cm^2/s

# %% [markdown]
# ### Optical flux

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)
    
G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio
# No magnitude value from GAIA is available, so we use GAIA's limiting magnitude of G = 20.7.

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
print(f"F_x-ray = {Flux/F}*F_optical")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 1.7108133688120655
# F_x-ray = 1.7108133688120655*F_optical

# %% [markdown]
# ## Luminosity
# No distance or parallax is available on ESASky.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s

print(color.BOLD+"For a star in the milky way? with d=[1 pc - 30 kpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s

print()
print(color.BOLD+"For a galaxy? with d=[1 Mpc - 10 Gpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")
# Out:
# For a star in the milky way? with d=[1 pc - 30 kpc] :
# Luminosity : [1.1280002591336044e+25, 1.1280002591336043e+31] erg/s
#
# For a galaxy? with d=[1 Mpc - 10 Gpc] :
# Luminosity : [1.1280002591336043e+37, 1.1280002591336043e+45] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L = 4*np.pi*Flux*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L,D_pc)
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
