# %% [markdown]
# # ObsID : 0945030131, SRCNUM : 7, Instru : EMOS2
# Not on Simbad

# %% [markdown]
# ## ESASky
# There are a bunch of EPIC Stack pointers on the light green/blue source and one pointer on an extremely close blue source. https://sky.esa.int/esasky/?target=52.38566666666666%20-28.617833333333333&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# **Green source**
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J032932.2-283705
# - IAU name : 4XMM J032932.3-283705
# - RA : 03h 29m 32.247s
# - DEC : -28° 37' 05.84"
#
# **Blue source**
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J032933.0-283717
# - IAU name : 4XMM J032933.1-283720
# - RA : 03h 29m 33.006s
# - DEC : -28° 37' 17.85""

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files
# Spectrum, Background, Response, Auxiliary response.

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945030131_SRCNUM7_EMOS2_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.787e-03 +/- 6.825e-04 (77.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-78
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.4e+04 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0945030131_SRCNUM7_EMOS2_background_spectrum.fits
#   Background Exposure Time: 1.398e+04 sec
#  Using Response (RMF) File            ObsID0945030131_SRCNUM7_EMOS2.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945030131_SRCNUM7_EMOS2.arf

# %%
n_cts = 4.787e-03*1.4e+04
print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 67.018
#
# The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.000001 0.05")
Plot("data")
spec.ignore("**-0.2 12-**")
# Out:
#      4 channels (1-4) ignored in spectrum #     1
#     67 channels (12,78) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 657.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic                14531.77     using 7 bins.
#
# Test statistic : Chi-Squared              8.872040e+06     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 14.5975      3222.21      -3       7068.69       1.33842       1049.54
# 14.3893      1.48873e-20  10       3261.36       197.096   3.09822e+13
# 14.3893      0.000583475   9       3261.36       197.096   3.09822e+13
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 1
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 2
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 3
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.9749E+13| -0.0000  -0.0000  -1.0000
#  0.0000E+00|  0.0000  -1.0000   0.0000
#  4.9749E+15|  1.0000  -0.0000  -0.0000
# ----------------------------------------
#
# ===========================
#   Covariance Matrix
#         1           2           3
#   -2.035e+19  -4.508e+21  -2.109e+33
#   -4.508e+21  -9.982e+23  -4.671e+35
#   -2.109e+33  -4.671e+35  -2.185e+47
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3261.36      +/-  -1.00000
#    2    2   bbody      kT         keV      197.096      +/-  -1.00000
#    3    2   bbody      norm                3.09822E+13  +/-  -1.00000
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 14.3893     using 7 bins.
#
# Test statistic : Chi-Squared                  5.3954     using 7 bins.
#  Null hypothesis probability of 2.4908e-01 with 4 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 659.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                6840.617     using 7 bins.
#
# Test statistic : Chi-Squared              2.100062e+06     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 14.5975      1399.97      -3       2039.07       2.56967       1392.83
# 14.5975      9.58898e-07  -4       999999.       195.072   3.09454e+10
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.1450E+15|  0.9997   0.0046  -0.0248
#  1.1450E+17| -0.0045   1.0000   0.0004
#  9.4458E+35| -0.0248   0.0003  -0.9997
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.812e+32  -7.261e+30   2.342e+34
#   -7.261e+30   9.071e+28  -2.926e+32
#    2.342e+34  -2.926e+32   9.440e+35
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.99999E+05  +/-  2.41076E+16
#    2    2   bremss     kT         keV      195.072      +/-  3.01188E+14
#    3    2   bremss     norm                3.09454E+10  +/-  9.71597E+17
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 14.5975     using 7 bins.
#
# Test statistic : Chi-Squared                  5.4637     using 7 bins.
# with 4 degrees of freedomity of 2.4294e-01

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 860.5, 661.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic                3322.840     using 7 bins.
#
# Test statistic : Chi-Squared                487149.1     using 7 bins.
#  Null hypothesis probability of 0.0e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 14.5975      1076.08      -3       410.552     0.0386727       416.520
# 14.5975      2.35188e-68  69       115.992     0.0688450       70130.9
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 1
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 2
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 5
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.0000E+18| -0.0000   0.0000  -1.0000
#  1.0000E+18| -0.0001   1.0000   0.0000
#  2.5078E+152|  1.0000   0.0001  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#  -3.981e+143  8.090e+151 -1.869e+158
#   8.090e+151 -2.609e+151  6.029e+157
#  -1.869e+158  6.029e+157 -1.393e+164
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    115.992      +/-  -1.00000
#    2    2   apec       kT         keV      6.88450E-02  +/-  -1.00000
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                7.01309E+04  +/-  -1.00000
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 14.5975     using 7 bins.
#
# Test statistic : Chi-Squared                  5.4637     using 7 bins.
#  Null hypothesis probability of 2.4294e-01 with 4 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 859.5, 660.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                13608.61     using 7 bins.
#
# Test statistic : Chi-Squared              8.105975e+06     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 14.5975      3150.03      -3       3853.04      -1.31183      0.277354
# 2.46415      3.59255e-11   7       1914.13      -2.41410       4063.28
# 2.46415      1.3381        6       1914.13      -2.41410       4063.28
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  8.2267E+07| -0.0031  -1.0000   0.0001
#  8.2267E+09|  1.0000  -0.0031  -0.0038
#  7.9042E+21|  0.0038   0.0001   1.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.160e+17   2.674e+15   3.028e+19
#    2.674e+15   6.161e+13   6.978e+17
#    3.028e+19   6.978e+17   7.904e+21
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1914.13      +/-  3.40637E+08
#    2    2   powerlaw   PhoIndex            -2.41410     +/-  7.84895E+06
#    3    2   powerlaw   norm                4063.28      +/-  8.89048E+10
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  2.4641     using 7 bins.
#
# Test statistic : Chi-Squared                  1.3798     using 7 bins.
#  Null hypothesis probability of 8.4770e-01 with 4 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 665.5, -0.5)

# %% [markdown]
# ### Bremss + Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*(bremss+powerlaw)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremsspowerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>(bremss<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                20540.86     using 7 bins.
#
# Test statistic : Chi-Squared              1.847255e+07     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 14.5975      2238.44      -3       3887.58       1.04809      0.141468      -2.19687       487.483
# 14.5356      1.47416e-07   7       3723.41       198.513   2.18134e+11      -2.43332       1077.40
# 14.5355      4.65329e-05   6       3723.40       198.509   2.18159e+11      -2.49806       2056.73
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 5
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  1.0000E+18| -0.0000   0.0000  -0.0002   0.0003   1.0000
#  6.4908E+22|  1.0000   0.0023  -0.0000  -0.0066   0.0000
#  1.4900E+26| -0.0065  -0.0572   0.0000  -0.9983   0.0003
#  3.7710E+26| -0.0027   0.9984  -0.0000  -0.0572  -0.0000
#  1.4802E+42| -0.0000   0.0000   1.0000   0.0000   0.0002
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    6.383e+22  -9.011e+23  -6.430e+31   5.680e+24   1.410e+28
#   -1.126e+24   7.207e+25   9.735e+33   6.677e+26   1.927e+30
#   -1.126e+32   1.234e+34   1.480e+42   1.785e+35   5.127e+38
#    4.669e+24   3.824e+26   1.055e+35   3.766e+26   3.862e+29
#    1.141e+28   1.081e+30   2.999e+38  -8.499e+27  -1.942e+33
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bremss<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3723.40      +/-  2.52655E+11
#    2    2   bremss     kT         keV      198.509      +/-  8.48925E+12
#    3    2   bremss     norm                2.18159E+11  +/-  1.21665E+21
#    4    3   powerlaw   PhoIndex            -2.49806     +/-  1.94070E+13
#    5    3   powerlaw   norm                2056.73      +/-  -1.00000
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 14.5355     using 7 bins.
#
# i-Squared                  5.4433     using 7 bins.
#  Null hypothesis probability of 6.5768e-02 with 2 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremsspowerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 661.5, -0.5)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 52.3844241°
# - Dec = -28.6182713°
#
# 52.38 -28.62
#
# **Column density :** nH = 4*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
print()
print(color.BOLD+"bremss+powerlaw"+color.END)
print(f"(tbabs) : {nH_bremsspowerlaw*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 3.2613590096707696e+25
#
# bremss
# (tbabs) : 9.999991611939395e+27
#
# apec
# (tbabs) : 1.1599179942241028e+24
#
# powerlaw
# (tbabs) : 1.9141308331543958e+25
#
# bremss+powerlaw
# (tbabs) : 3.7233976570095756e+25

# %% [markdown]
# ## Flux
# ### X-ray flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 0.0022655 photons (4.3011e-11 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 4.3011e-11 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END+f"F_X = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux : F_X = 4.3011e-11 ergs/cm^2/s

# %% [markdown]
# ### Optical flux

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)
    
G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
print(f"F_x-ray = {Flux/F}*F_optical")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 349915.1767977836
# F_x-ray = 349915.1767977836*F_optical

# %% [markdown]
# ## Luminosity
# No distance or parallax is available on ESASky.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s

print(color.BOLD+"For a star in the milky way? with d=[1 pc - 30 kpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s

print()
print(color.BOLD+"For a galaxy? with d=[1 Mpc - 10 Gpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")
# Out:
# For a star in the milky way? with d=[1 pc - 30 kpc] :
# Luminosity : [5.146320209771034e+27, 5.146320209771034e+33] erg/s
#
# For a galaxy? with d=[1 Mpc - 10 Gpc] :
# Luminosity : [5.146320209771035e+39, 5.146320209771035e+47] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L = 4*np.pi*Flux*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L,D_pc)
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
