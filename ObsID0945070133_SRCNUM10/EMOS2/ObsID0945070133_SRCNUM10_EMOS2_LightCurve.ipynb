# %% [markdown]
# # ObsID : 0945070133, SRCNUM : 10, Instru : EMOS2

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob

import stingray as st
from stingray import Lightcurve, AveragedPowerspectrum
from stingray.gti import create_gti_mask

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [10,5]

# %%
def lightcurve(file):
    hdul = fits.open(file)
    print()
    print(color.BOLD +file+ color.END)
    hdul.info()
    
    rate_data = hdul[1].columns
    print()
    print(rate_data)
        
    time = hdul[1].data.field('TIME')
    rate = hdul[1].data.field('RATE')
    error = hdul[1].data.field('ERROR')
    backrate = hdul[1].data.field('BACKV')
    
    """
    print()
    print(f"TIME = {time} s")
    print(f"RATE = {rate} count/s")
    print(f"ERROR = {error} count/s")
    """
    
    lcs = []
    backlcs = []
    gtis = []
    for i in hdul[2].data:
        gtis.append([i[0],i[1]])
    lcs.append(Lightcurve(time, rate, error, gti=gtis, input_counts=False))
    backlcs.append(Lightcurve(time, backrate, error, gti=gtis, input_counts=False))
    
    for i in range(len(lcs)):
        plt.xlabel('Time (s)')
        plt.ylabel('Countrate (/s)')
        plt.plot(lcs[i].time, lcs[i].countrate, color='steelblue', lw=1, ds='steps-mid', label='Source corr')
        plt.plot(backlcs[i].time, backlcs[i].countrate, color='firebrick',lw=1, ls='--', ds='steps-mid', label='Background')
        plt.title(f'{file}')
        plt.legend(loc='upper right')
        plt.grid()
        for j in range(len(lcs[i].gti)-1):
            plt.axvspan(lcs[i].gti[j][1],lcs[i].gti[j+1][0],color='purple',alpha=0.25)
        plt.show()

# %% [markdown]
# ## Time bin size = 10s

# %%
lightcurve(glob.glob('ObsID*SRCNUM*E*t10_lccorr.lc')[0])
# Out:
# ObsID0945070133_SRCNUM10_EMOS2_t10_lccorr.lc
# Filename: ObsID0945070133_SRCNUM10_EMOS2_t10_lccorr.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      17   ()
#   1  RATE          1 BinTableHDU     79   875R x 6C   [D, E, E, E, E, E]
#   2  SRC_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   3  BKG_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   4  REG00105      1 BinTableHDU     24   1R x 5C   [16A, E, E, E, B]
#
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 's'
#     name = 'RATE'; format = 'E'; unit = 'count/s'
#     name = 'ERROR'; format = 'E'; unit = 'count/s'
#     name = 'FRACEXP'; format = 'E'; unit = 'fraction'
#     name = 'BACKV'; format = 'E'; unit = 'count/s'
#     name = 'BACKE'; format = 'E'; unit = 'count/s'
# )

# %% [markdown]
# ## Time bin size = 50s

# %%
lightcurve(glob.glob('ObsID*SRCNUM*E*t50_lccorr.lc')[0])
# Out:
# ObsID0945070133_SRCNUM10_EMOS2_t50_lccorr.lc
# Filename: ObsID0945070133_SRCNUM10_EMOS2_t50_lccorr.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      17   ()
#   1  RATE          1 BinTableHDU     79   175R x 6C   [D, E, E, E, E, E]
#   2  SRC_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   3  BKG_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   4  REG00105      1 BinTableHDU     24   1R x 5C   [16A, E, E, E, B]
#
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 's'
#     name = 'RATE'; format = 'E'; unit = 'count/s'
#     name = 'ERROR'; format = 'E'; unit = 'count/s'
#     name = 'FRACEXP'; format = 'E'; unit = 'fraction'
#     name = 'BACKV'; format = 'E'; unit = 'count/s'
#     name = 'BACKE'; format = 'E'; unit = 'count/s'
# )

# %% [markdown]
# ## Time bin size = 200s

# %%
lightcurve(glob.glob('ObsID*SRCNUM*E*t200_lccorr.lc')[0])
# Out:
# ObsID0945070133_SRCNUM10_EMOS2_t200_lccorr.lc
# Filename: ObsID0945070133_SRCNUM10_EMOS2_t200_lccorr.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      17   ()
#   1  RATE          1 BinTableHDU     79   44R x 6C   [D, E, E, E, E, E]
#   2  SRC_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   3  BKG_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   4  REG00105      1 BinTableHDU     24   1R x 5C   [16A, E, E, E, B]
#
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 's'
#     name = 'RATE'; format = 'E'; unit = 'count/s'
#     name = 'ERROR'; format = 'E'; unit = 'count/s'
#     name = 'FRACEXP'; format = 'E'; unit = 'fraction'
#     name = 'BACKV'; format = 'E'; unit = 'count/s'
#     name = 'BACKE'; format = 'E'; unit = 'count/s'
# )

# %% [markdown]
# ## Time bin size = 500s

# %%
lightcurve(glob.glob('ObsID*SRCNUM*E*t500_lccorr.lc')[0])
# Out:
# ObsID0945070133_SRCNUM10_EMOS2_t500_lccorr.lc
# Filename: ObsID0945070133_SRCNUM10_EMOS2_t500_lccorr.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      17   ()
#   1  RATE          1 BinTableHDU     79   18R x 6C   [D, E, E, E, E, E]
#   2  SRC_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   3  BKG_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   4  REG00105      1 BinTableHDU     24   1R x 5C   [16A, E, E, E, B]
#
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 's'
#     name = 'RATE'; format = 'E'; unit = 'count/s'
#     name = 'ERROR'; format = 'E'; unit = 'count/s'
#     name = 'FRACEXP'; format = 'E'; unit = 'fraction'
#     name = 'BACKV'; format = 'E'; unit = 'count/s'
#     name = 'BACKE'; format = 'E'; unit = 'count/s'
# )
