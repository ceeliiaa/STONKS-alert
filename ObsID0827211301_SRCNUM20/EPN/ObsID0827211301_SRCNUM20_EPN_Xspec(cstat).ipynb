# %% [markdown]
# # ObsID : 0827211301, SRCNUM : 20, Instru : EPN
# Not on Simbad. Previous observation of the source ObsID : 0945020137, SRCNUM : 21

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=52.73769389063616%20-28.634488186049&hips=GALEX+GR6%2F7+AIS+color&fov=0.182241278518&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J033057.0-283804
# - IAU name : 4XMM J033056.9-283804
# - RA : 03h 30m 57.047s
# - DEC : -28° 38' 04.16"

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*SRCNUM*E*spectrum_grp_cstat.fits')[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: ObsID0827211301_SRCNUM20_EPN_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.279e-02 +/- 1.625e-03 (22.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-947
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 2.533e+04 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0827211301_SRCNUM20_EPN_background_spectrum.fits
#   Background Exposure Time: 2.533e+04 sec
#  Using Response (RMF) File            ObsID0827211301_SRCNUM20_EPN.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0827211301_SRCNUM20_EPN.arf

# %%
n_cts = 1.279e-02*2.533e+04

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 323.97069999999997

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.000001 0.05")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
#      8 channels (1-8) ignored in spectrum #     1
#     94 channels (854-947) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('*Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 661.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              2.547828e+07     using 845 bins.
#
# Test statistic : Chi-Squared              2.971663e+11     using 845 bins.
#  Null hypothesis probability of 0.000000e+00 with 842 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 860.886      5.15039e+06  -3      0.498205       198.689      0.461150
# 852.747      4.0176       -3      0.239332       198.476      0.866220
# 849.159      2.17737      -3     0.0861221       199.170       1.32424
# 848.688      2.36978      -2     0.0332348       199.309       1.11356
# 848.57       3.06429      -3    0.00236473       199.348       1.54540
# 847.578      4.95893      -2   0.000988907       199.356       1.23417
# 847.562      4.1239        0   0.000415362       199.356       1.23541
# 847.552      4.14936       0   0.000129022       199.355       1.23657
# 847.549      4.16336       0   5.75257e-05       199.355       1.23764
# 847.546      4.16858       0   2.18150e-05       199.355       1.23863
# 847.544      4.17218       0   3.97644e-06       199.354       1.23954
# 847.542      4.17488       0   1.74852e-06       199.354       1.24037
# 847.541      4.17679       0   6.35412e-07       199.354       1.24113
# 847.54       4.17851       0   7.92520e-08       199.354       1.24182
# 847.539      4.18006       0   9.77583e-09       199.353       1.24247
# 847.538      4.18152       0   1.09638e-09       199.353       1.24307
# 847.537      4.1828        0   1.20810e-11       199.353       1.24360
# 847.536      4.17876       0   3.65485e-12       199.353       1.24404
# 847.535      4.17513       0   1.51829e-12       199.352       1.24470
# 847.534      4.2853        0   4.46421e-13       199.352       1.24518
# 847.534      4.44415       0   1.92674e-13       199.352       1.24574
# 847.533      4.14877       0   8.56017e-14       199.352       1.24634
# 847.531      3.92278       0   1.49349e-14       199.352       1.24711
# 847.528      3.82642       0   7.38828e-15       199.351       1.24959
# 847.524      4.90283       0   3.24478e-15       199.350       1.25221
# 847.521      5.39125       0   7.19913e-16       199.349       1.25463
# 847.515      6.21395       0   3.58979e-16       199.347       1.26039
# 847.508      5.46474      -1   5.43541e-17       199.343       1.26689
# 847.498      0.149279     -2   2.46272e-17       199.345       1.29198
# 847.498      0.00375003    2   5.67241e-18       199.345       1.29198
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.2146E-02| -0.0000  -0.0193   0.9998
#  1.8812E+07|  1.0000   0.0088   0.0002
#  4.2998E+07|  0.0088  -0.9998  -0.0193
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.881e+07  -2.134e+05  -4.126e+03
#   -2.134e+05   4.298e+07   8.318e+05
#   -4.126e+03   8.318e+05   1.610e+04
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.67241E-18  +/-  4337.54
#    2    2   bbody      kT         keV      199.345      +/-  6555.92
#    3    2   bbody      norm                1.29198      +/-  126.876
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                847.4977     using 845 bins.
#
# Test statistic : Chi-Squared                734.7042     using 845 bins.
#  Null hypothesis probability of 9.9672e-01 with 842 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 660.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              6.062310e+06     using 845 bins.
#
# Test statistic : Chi-Squared              2.122519e+10     using 845 bins.
#  Null hypothesis probability of 0.000000e+00 with 842 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 993612       1.15617e+06  -3      0.395348       199.078      0.182605
# 234412       928818       -1      0.152208       199.259     0.0328460
# 87777.7      1.22904e+06  -1     0.0584744       199.321     0.0105332
# 38853.1      1.47468e+06  -1     0.0285462       199.362    0.00453879
# 12226        1.56842e+06  -1    0.00987263       199.363    0.00153199
# 2969.63      1.55275e+06  -1    0.00275892       199.363   0.000450401
# 1068.38      1.26507e+06  -1   0.000638428       199.363   0.000149278
# 802.26       718663       -1   0.000208012       199.363   5.15953e-05
# 800.604      87796.3      -1   6.33581e-05       199.363   3.94269e-05
# 800.52       47609.4       0   1.68194e-05       199.336   3.96502e-05
# 800.46       44903.2       0   5.31338e-06       199.308   3.98559e-05
# 800.411      42430.2       0   2.46353e-06       199.280   4.00456e-05
# 800.369      40159.5       0   1.05043e-06       199.252   4.02204e-05
# 800.332      38071.1       0   3.49260e-07       199.223   4.03815e-05
# 800.3        36149.8       0   1.12707e-09       199.195   4.05298e-05
# 800.272      34382.2       0   4.51509e-10       199.166   4.06664e-05
-05
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 7.84376e-19 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 779.497      0.529827     -3   7.84376e-19      0.409789   4.55575e-05
# ==============================
#  Variances and Principal Axes
#                  2        3
#  2.9084E-11|  0.0001   1.0000
#  1.0625E-02|  1.0000  -0.0001
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    1.062e-02  -1.160e-06
#   -1.160e-06   1.557e-10
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    7.84376E-19  +/-  -1.00000
#    2    2   bremss     kT         keV      0.409789     +/-  0.103077
#    3    2   bremss     norm                4.55575E-05  +/-  1.24760E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                779.4974     using 845 bins.
#
# Test statistic : Chi-Squared                624.6550     using 845 bins.
#  Null hypothesis probability of 1.0000e+00 with 842 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 657.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              2.613272e+06     using 845 bins.
#
# Test statistic : Chi-Squared              7.426401e+09     using 845 bins.
#  Null hypothesis probability of 0.000000e+00 with 842 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 1.915e+06    801563       -3      0.166641       41.3758      0.494284
# 511431       856834       -4    0.00991172       56.6279     0.0980605
# 32446.2      949165       -1      0.804857       61.5120     0.0187197
# 7656.71      315259       -1      0.144195       63.9451    0.00294367
# 3674.56      507295       -1     0.0159617       63.9827    0.00115602
# 1083.87      620258       -1    0.00106103       63.9923   0.000310101
# 1052.64      361026       -2   0.000379032       63.9979   0.000294759
# 1019.27      348169       -2   4.90925e-05       64.0000   0.000278112
# 953.308      331979       -2   8.73407e-06       64.0000   0.000242897
# 886.621      291910       -2   3.85673e-06       64.0000   0.000200827
# 851.026      234530       -2   1.47061e-06       64.0000   0.000172902
# 825.42       189277       -2   2.63712e-07       64.0000   0.000147157
# 811.664      141070       -2   1.07681e-07       64.0000   0.000128292
# 807.037      101193       -2   2.70034e-08       64.0000   0.000119869
# 805.395      81744.7      -2   6.39708e-09       64.0000   0.000116339
# 804.775      73254.4      -2   1.19148e-09       64.0000   0.000114893
# 804.532      69717.6      -2   5.37814e-10       64.0000   0.000114307
# 804.435      68271.6      -2   2.10363e-10       64.0000   0.000114068
# 804.396      67682.9      -2   4.65099e-11       64.0000   0.000113972
# 804.378      67444.6      -2   5.53322e-12       64.0000   0.000113928
# 799.408      67335.2      -1   1.57929e-12       64.0000   8.18367e-05
# 799.241      17944.5       0   3.28761e-13       61.3920   8.21309e-05
# 799.175      14447.1       0   2.21147e-14       60.3537   8.23222e-05
# 799.119      12769         0   2.98815e-15       59.4137   8.24889e-05
# 799.062      11231.4       0   1.11153e-15       58.3661   8.26869e-05
# 799.026      9466.55       0   4.38868e-16       57.5811   8.27916e-05
# 798.994      8261.37       0   1.74130e-16       56.8976   8.29357e-05
# 798.994      6900.02      14   1.84336e-16       56.8976   8.29357e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.1057E-10| -0.0006  -0.0000   1.0000
#  5.7717E-05|  1.0000   0.0000   0.0006
#  8.6036E+04| -0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.026e-05  -4.677e-01  -1.875e-07
#   -4.677e-01   8.604e+04   4.070e-02
#   -1.875e-07   4.070e-02   1.938e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.84336E-16  +/-  7.76271E-03
#    2    2   apec       kT         keV      56.8976      +/-  293.319
# 00000      frozen      Abundanc            1.
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                8.29357E-05  +/-  1.39225E-04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                798.9938     using 845 bins.
#
# Test statistic : Chi-Squared                708.9789     using 845 bins.
#  Null hypothesis probability of 9.9968e-01 with 842 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 854.5, 656.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.467905e+07     using 845 bins.
#
# Test statistic : Chi-Squared              9.883976e+10     using 845 bins.
#  Null hypothesis probability of 0.000000e+00 with 842 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 875.629      3.73193e+06   0       359.740       8.27059      0.417680
# 875.629      0.000163372  -1       999999.       1.19586       15800.2
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.2111E+07| -0.0053  -0.6224   0.7827
#  2.2319E+11|  0.0456  -0.7820  -0.6216
#  3.3350E+14|  0.9989   0.0324   0.0325
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.328e+14   1.079e+13   1.082e+13
#    1.079e+13   4.869e+11   4.599e+11
#    1.082e+13   4.599e+11   4.388e+11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.99999E+05  +/-  1.82426E+07
#    2    2   powerlaw   PhoIndex            1.19586      +/-  6.97815E+05
#    3    2   powerlaw   norm                1.58002E+04  +/-  6.62388E+05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                875.6289     using 845 bins.
#
# Test statistic : Chi-Squared                606.9680     using 845 bins.
#  Null hypothesis probability of 1.0000e+00 with 842 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_powerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 854.5, 656.5, -0.5)

# %% [markdown]
# ### Black body + Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbodypowerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              4.017478e+07     using 845 bins.
#
# Test statistic : Chi-Squared              6.897673e+11     using 845 bins.
#  Null hypothesis probability of 0.000000e+00 with 840 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 3.50131e+06  3.87329e+06  -1      0.233413       198.921    0.00556744       5.66446      0.123648
# 133706       3.92659e+06  -1       160.087       199.261    0.00116744      -1.39154    0.00637771
# 875.63       2.13867e+06  -2       72.6383       199.338   0.000447958       8.32682    0.00151712
# 875.629      0.663197     -3       999997.       89.5452       3.35006       9.16404       349.601
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
# ***Warning: Zero alpha-matrix diagonal element for parameter 2
# ***Warning: Zero alpha-matrix diagonal element for parameter 3
# ***Warning: Zero alpha-matrix diagonal element for parameter 4
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 1 is pegged at 999997 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 2 is pegged at 89.5452 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 3 is pegged at 3.35006 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 4 is pegged at 9.16404 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 5 is pegged at 349.601 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***XSPEC Error:  No variable parameters for fit
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 AllModels.clear()
#       2 mo = Model("tbabs*(bbody+powerlaw)")
# ----> 3 Fit.perform()
#       4 Plot.device = "/xs"
#       5 Plot("data resid")
#
# File /mnt/c/Users/acer/HEASoft/heasoft-6.34/x86_64-pc-linux-gnu-libc2.35/lib/python/xspec/fit.py:533, in FitManager.perform(self)
#     530 """Perform a fit."""
#     532 fitArgs = ["fit"]
# --> 533 _pyXspec.doXspecCmd(fitArgs)
#
# Exception: Error executing command: fit

# %% [raw]
# img = plt.imread(glob.glob('*Spectrum_bbodypowerlaw.png')[0])
# plt.imshow(img)
# plt.axis('off')

# %% [markdown]
# ### Bremsstrahlung + Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*(bremss+powerlaw)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH
# 775.441      2076.17       0   7.59708e-18       64.0000   5.97918e-05     0.0914609   2.70572e-05
# 775.441      2019.67       0   7.59708e-18       64.0000   5.97674e-05     0.0914558   2.70658e-05
# 775.44       1981.02       0   7.59708e-18       64.0000   5.97507e-05     0.0914507   2.70733e-05
# 775.44       1954.72       0   7.59708e-18       64.0000   5.97393e-05     0.0914456   2.70797e-05
# 775.44       1936.94       0   7.59708e-18       64.0000   5.97317e-05     0.0914407   2.70855e-05
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 7.59708e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 775.44       1925.04       0   7.59708e-18       64.0000   5.97266e-05     0.0914359   2.70906e-05
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  2.8393E-11| -0.0000   0.2563   0.0008   0.9666
#  1.5696E-10| -0.0000   0.9666   0.0000  -0.2563
#  2.9784E-04|  0.0000   0.0002  -1.0000   0.0008
#  7.9632E+05|  1.0000   0.0000   0.0000  -0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    7.963e+05   1.068e-01   4.657e+00  -4.783e-04
#    1.068e-01   1.448e-08   5.569e-07  -4.180e-11
#    4.657e+00   5.569e-07   3.251e-04  -2.419e-07
#   -4.783e-04  -4.180e-11  -2.419e-07   2.290e-10
# ------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    7.59708E-18  +/-  -1.00000
#    2    2   apec       kT         keV      64.0000      +/-  892.370
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                5.97266E-05  +/-  1.20315E-04
#    6    3   apec       kT         keV      9.14359E-02  +/-  1.80301E-02
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                2.70906E-05  +/-  1.51326E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                775.4402     using 845 bins.
#
# Test statistic : Chi-Squared                669.8204     using 845 bins.
#  Null hypothesis probability of 1.0000e+00 with 840 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_apecapec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 854.5, 661.5, -0.5)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 52.7376939°
# - DEC = -28.6344882°
#
# 52.74 -28.63
#
# **Column density :** nH = 2*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
print()
print(color.BOLD+"bremss+powerlaw"+color.END)
print(f"(tbabs) : {nH_bremsspowerlaw*10**22}")
print()
print(color.BOLD+"apec+apec"+color.END)
print(f"(tbabs) : {nH_apecapec*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 56724.10665280934
#
# bremss
# (tbabs) : 7843.758519453492
#
# apec
# (tbabs) : 1843356.4944248192
#
# powerlaw
# (tbabs) : 9.999988533027636e+27
#
# bremss+powerlaw
# (tbabs) : 1.2991823990665953e+23
#
# apec+apec
# (tbabs) : 75970.82229749343

# %% [markdown]
# ## Flux
# ### X-ray flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 0.00010375 photons (1.5065e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 1.5065e-13  # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END+f"F_X = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux : F_X = 1.5065e-13 ergs/cm^2/s

# %% [markdown]
# ### Optical flux
# No GAIA information, so we use the lower limit of 20.7 mag.

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)

G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
print(f"F_x-ray = {Flux/F}*F_optical")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 2.7338824491539304
# F_x-ray = 2.7338824491539304*F_optical

# %% [markdown]
# ## Luminosity
# No distance available.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s


print(color.BOLD+"For a star in the milky way? with d=[1 pc - 30 kpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s


print(color.BOLD+"For a galaxy? with d=[1 Mpc - 10 Gpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")
# Out:
# For a star in the milky way? with d=[1 pc - 30 kpc] :
# Luminosity : [1.8025461849341014e+25, 1.802546184934101e+31] erg/s
# For a galaxy? with d=[1 Mpc - 10 Gpc] :
# Luminosity : [1.8025461849341016e+37, 1.8025461849341016e+45] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L = 4*np.pi*Flux*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L,D_pc)
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
