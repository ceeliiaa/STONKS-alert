# %% [markdown]
# # ObsID : 0827211301, SRCNUM : 20, Instru : EPN
# Not on Simbad. Previous observation of the source ObsID : 0945020137, SRCNUM : 21

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=52.73769389063616%20-28.634488186049&hips=GALEX+GR6%2F7+AIS+color&fov=0.182241278518&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J033057.0-283804
# - IAU name : 4XMM J033056.9-283804
# - RA : 03h 30m 57.047s
# - DEC : -28° 38' 04.16"

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*SRCNUM*E*spectrum_grp_cstat.fits')[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: ObsID0827211301_SRCNUM20_EPN_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.279e-02 +/- 1.625e-03 (22.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-947
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 2.533e+04 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0827211301_SRCNUM20_EPN_background_spectrum.fits
#   Background Exposure Time: 2.533e+04 sec
#  Using Response (RMF) File            ObsID0827211301_SRCNUM20_EPN.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0827211301_SRCNUM20_EPN.arf

# %%
n_cts = 1.279e-02*2.533e+04

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 323.97069999999997

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.000001 0.05")
Plot("data")
spec.ignore("**-0.2 12-**")
# Out:
#      8 channels (1-8) ignored in spectrum #     1
#    936 channels (12,947) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('*Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 661.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic                1996.020     using 3 bins.
#
# Test statistic : Chi-Squared                78867.98     using 3 bins.
#  Cannot calculate null hypothesis probability
# GammQ: A <=  0
# GammQ: A <=  0
# .
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.37352      499.979      -3       3.40527       43.3935      0.383164
# 6.32004      0.0615904     1       1.34506       32.7165      0.663243
# 3.1691       0.294454      0      0.651664       25.9813       1.06829
# 1.28201      0.585567      0      0.134119       23.0253       1.42784
# 0.652401     2.60077      -1      0.167234       23.8266       1.28045
# 0.65044      0.0543001    -2      0.211455       23.3460       1.35799
# 0.648581     0.0566013    -2      0.277409       22.7950       1.45366
# 0.646887     0.0634258    -2      0.373583       22.2393       1.55897
# 0.644042     0.0583103    -2      0.494669       21.7931       1.65109
# 0.641583     0.036669     -2      0.598733       21.5435       1.70703
# 0.641155     0.0119757    -2      0.655396       21.4258       1.73374
# 0.641116     0.00207087   -2      0.681841       21.3679       1.74712
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.0437E+04|  0.7374   0.1569  -0.6570
#  2.0437E+06|  0.6755  -0.1743   0.7165
#  4.2332E+13|  0.0021   0.9721   0.2345
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.921e+08   8.744e+10   2.109e+10
#    8.744e+10   4.000e+13   9.650e+12
#    2.109e+10   9.650e+12   2.328e+12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.681841     +/-  1.38587E+04
#    2    2   bbody      kT         keV      21.3679      +/-  6.32486E+06
#    3    2   bbody      norm                1.74712      +/-  1.52578E+06
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  0.6411     using 3 bins.
#
# Test statistic : Chi-Squared                  0.7224     using 3 bins.
#  Cannot calculate null hypothesis probability.

# %%
img = plt.imread(glob.glob('*Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 660.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                1400.300     using 3 bins.
#
# Test statistic : Chi-Squared                40235.26     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 1.37853      353.686      -2       9.41770       2.77152      0.339499
# 0.677991     1.3105       -3       6.93715       1.72679      0.299785
# 0.653843     0.352199     -2       6.61486       1.64519      0.298480
# 0.652267     0.00851556   -2       6.34980       1.53340      0.290354
# 0.650501     0.0281702    -2       6.08087       1.43555      0.282784
# 0.648711     0.0269763    -2       5.81215       1.34766      0.275448
# 0.646885     0.0283569    -2       5.54548       1.27102      0.268296
# 0.645071     0.0258396    -2       5.28207       1.20220      0.261351
# 0.643268     0.0251682    -2       5.02247       1.14012      0.254716
# 0.64149      0.0247825    -2       4.76806       1.08421      0.248408
# 0.639763     0.0235165    -2       4.52053       1.03393      0.242416
# 0.638107     0.0222042    -2       4.28146      0.988740      0.236757
# 0.636533     0.0207894    -2       4.05169      0.947872      0.231532
# 0.635066     0.0188049    -2       3.83344      0.911189      0.226709
# 0.633719     0.016355     -2       3.62793      0.878141      0.222354
# 0.632513     0.0141273    -2       3.43735      0.848728      0.218429
# 0.63145      0.0114847    -2       3.26230      0.822395      0.215020
# 0.630499     0.00906928   -3       1.69667      0.587958      0.185695
# 0.627967     0.229519     -2       1.76096      0.596889      0.192805
# 0.627592     0.00329733   -2       1.82505      0.602582      0.198326
# 0.627326     0.00645103   -2       1.88127      0.606788      0.203494
# 0.627136     0.00323367   -2       1.93019      0.609868      0.208372
# 0.627078     0.00145404   -3       2.35085      0.630828      0.255099
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.5303E-02| -0.1150   0.6694   0.7339
#  7.6496E+04|  0.6393  -0.5156   0.5704
#  5.4959E+09|  0.7603   0.5348  -0.3687
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.177e+09   2.235e+09  -1.540e+09
#    2.235e+09   1.572e+09  -1.084e+09
#   -1.540e+09  -1.084e+09   7.470e+08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.35085      +/-  5.63656E+04
#    2    2   bremss     kT         keV      0.630828     +/-  3.96475E+04
#    3    2   bremss     norm                0.255099     +/-  2.73312E+04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  0.6271     using 3 bins.
#
# Test statistic : Chi-Squared                  0.7136     using 3 bins.
#  Cannot calculate null hypothesis probability.
# GammQ: A <=  0
# GammQ: A <=  0

# %%
img = plt.imread(glob.glob('*Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 664.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic                1077.944     using 3 bins.
#
# Test statistic : Chi-Squared                24665.94     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 1.34508      439.706      -2       5.23519       48.1522      0.420614
# 0.727283     1.80166      -2       5.27222       56.7258      0.356797
# 0.689819     0.605621     -2       5.11189       62.0742      0.332101
# 0.657461     0.454375     -1       5.15763       63.2002      0.321892
# 0.653353     0.173308     -1       5.15871       63.7855      0.317553
# 0.652657     0.0899161    -1       5.14605       63.9959      0.314949
# 0.652498     0.068747     -1       5.12983       63.9995      0.312796
# 0.652393     0.0658516    -1       5.11306       63.9998      0.310722
# 0.652304     0.0651885    -1       5.09611       63.9999      0.308683
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.0194E-02| -0.1187  -0.0006   0.9929
#  1.0012E+05|  0.9929  -0.0023   0.1187
#  8.1520E+13|  0.0022   1.0000   0.0009
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.083e+08   1.824e+11   1.661e+08
#    1.824e+11   8.152e+13   7.420e+10
#    1.661e+08   7.420e+10   6.755e+07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.09611      +/-  2.02077E+04
#    2    2   apec       kT         keV      63.9999      +/-  9.02879E+06
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                0.308683     +/-  8218.75
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  0.6523     using 3 bins.
#
# Test statistic : Chi-Squared                  0.7448     using 3 bins.
#  Cannot calculate null hypothesis probability.
# GammQ: A <=  0
# GammQ: A <=  0

# %%
img = plt.imread(glob.glob('*Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 857.5, 657.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                2587.937     using 3 bins.
#
# Test statistic : Chi-Squared                129642.3     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 7.51465      644.006      -3       92.9221       7.22236      0.216016
# 7.44399      2.43563e-06   5       23.8223       4.84006      0.992563
# 7.44367      0.0181323     4       23.8129       4.83875      0.994063
# 7.44041      0.0182011     3       23.7191       4.82576       1.00902
# 7.4015       0.0189002     2       22.8296       4.70171       1.15369
# 6.10973      0.0270795     1       17.4310       3.90153       2.20634
# 2.88729      0.248433      0       15.2581       3.40919       3.31790
# 0.720763     0.549214      0       14.1220       3.10977       4.28981
# 0.671471     0.153115     -1       14.0020       3.07144       4.43526
# 0.671324     0.00612067   -2       14.0629       3.04640       4.41829
# 0.670925     0.000259771  -3       14.8040       2.79376       4.22460
# 0.669631     0.0232503    -2       15.0040       2.75828       4.21999
# 0.669205     0.000753349  -2       15.2115       2.71567       4.24203
# 0.668698     0.000803428  -2       15.4467       2.67044       4.27264
# 0.668097     0.0010477    -2       15.7134       2.62270       4.31273
# 0.667394     0.00135564   -2       16.0151       2.57259       4.36338
# 0.66658      0.00172977   -2       16.3556       2.52038       4.42567
# 0.665654     0.00216784   -2       16.7382       2.46646       4.50057
# 0.664621     0.00265692   -2       17.1656       2.41141       4.58876
# 0.663499     0.00316824   -2       17.6390       2.35592       4.69050
# 0.662315     0.00365374   -2       18.1576       2.30081       4.80537
# 0.661107     0.00404803   -2       18.7174       2.24698       4.93216
# 0.659919     0.00427963   -2       19.3114       2.19531       5.06873
# 0.658796     0.0042922    -2       19.9292       2.14656       5.21222
# 0.657771     0.00406819   -2       20.5585       2.10131       5.35929
# 0.656869     0.0036411    -2       21.1862       2.05989       5.50662
# 0.656095     0.00308557   -2       21.8005       2.02238       5.65125
# 0.655446     0.00248971   -2       22.3922       1.98866       5.79092
# 0.654908     0.00192666   -2       22.9550       1.95847       5.92411
# 0.654465     0.00144007   -2       23.4857       1.93147       6.05000
# 0.654101     0.00104529   -2       23.9831       1.90731       6.16831
# 0.653801     0.0007387    -2       24.4478       1.88562       6.27912
# 0.653553     0.00050765   -2       24.8814       1.86609       6.38277
# 0.653346     0.000337318  -2       25.2859       1.84844       6.47970
# 0.653173     0.000214486  -2       25.6636       1.83240       6.57043
# 0.653026     0.000129619  -2       26.0167       1.81777       6.65546
# 0.652901     7.92642e-05  -2       26.3475       1.80437       6.73531
# 0.652794     6.53287e-05  -2       26.6580       1.79203       6.81043
# 0.652676     7.55808e-05  -3       29.5715       1.67793       7.52072
# 0.651995     0.0233298    -3       31.1374       1.62922       7.87367
# 0.651902     0.00461632   -3       32.1723       1.59739       8.12766
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.8925E+06| -0.0542  -0.9944   0.0903
#  2.8925E+08|  0.9852  -0.0680  -0.1574
#  3.4964E+15|  0.1627   0.0805   0.9834
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.253e+13   4.577e+13   5.594e+14
#    4.577e+13   2.264e+13   2.767e+14
#    5.594e+14   2.767e+14   3.381e+15
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    32.1723      +/-  9.61947E+06
#    2    2   powerlaw   PhoIndex            1.59739      +/-  4.75809E+06
#    3    2   powerlaw   norm                8.12766      +/-  5.81485E+07
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  0.6519     using 3 bins.
#
# Test statistic : Chi-Squared                  0.7350     using 3 bins.
#  Cannot calculate null hypothesis probability.
# GammQ: A <=  0
# GammQ: A <=  0

# %%
img = plt.imread(glob.glob('*Spectrum_powerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 657.5, -0.5)

# %% [markdown]
# ### Black body + Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbodypowerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Ill-formed Fit problem - number of variable parameters exceeds number of bins
# ***Warning: Ill-formed Fit problem - number of variable parameters exceeds number of bins
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 AllModels.clear()
#       2 mo = Model("tbabs*(bbody+powerlaw)")
# ----> 3 Fit.perform()
#       4 Plot.device = "/xs"
#       5 Plot("data resid")
#
# File /mnt/c/Users/acer/HEASoft/heasoft-6.34/x86_64-pc-linux-gnu-libc2.35/lib/python/xspec/fit.py:533, in FitManager.perform(self)
#     530 """Perform a fit."""
#     532 fitArgs = ["fit"]
# --> 533 _pyXspec.doXspecCmd(fitArgs)
#
# Exception: Error executing command: fit

# %% [raw]
# img = plt.imread(glob.glob('*Spectrum_bbodypowerlaw.png')[0])
# plt.imshow(img)
# plt.axis('off')

# %% [markdown]
# ### Bremsstrahlung + Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*(bremss+powerlaw)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremsspowerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>(bremss<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Ill-formed Fit problem - number of variable parameters exceeds number of bins
# ***Warning: Ill-formed Fit problem - number of variable parameters exceeds number of bins
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 AllModels.clear()
#       2 mo = Model("tbabs*(bremss+powerlaw)")
# ----> 3 Fit.perform()
#       4 Plot.device = "/xs"
#       5 Plot("data resid")
#
# File /mnt/c/Users/acer/HEASoft/heasoft-6.34/x86_64-pc-linux-gnu-libc2.35/lib/python/xspec/fit.py:533, in FitManager.perform(self)
#     530 """Perform a fit."""
#     532 fitArgs = ["fit"]
# --> 533 _pyXspec.doXspecCmd(fitArgs)
#
# Exception: Error executing command: fit

# %% [raw]
# img = plt.imread(glob.glob('*Spectrum_bremsspowerlaw.png')[0])
# plt.imshow(img)
# plt.axis('off')

# %% [markdown]
# ### Apec + Apec

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apecapec = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Ill-formed Fit problem - number of variable parameters exceeds number of bins
# ***Warning: Ill-formed Fit problem - number of variable parameters exceeds number of bins
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 AllModels.clear()
#       2 mo = Model("tbabs*(apec+apec)")
# ----> 3 Fit.perform()
#       4 Plot.device = "/xs"
#       5 Plot("data resid")
#
# File /mnt/c/Users/acer/HEASoft/heasoft-6.34/x86_64-pc-linux-gnu-libc2.35/lib/python/xspec/fit.py:533, in FitManager.perform(self)
#     530 """Perform a fit."""
#     532 fitArgs = ["fit"]
# --> 533 _pyXspec.doXspecCmd(fitArgs)
#
# Exception: Error executing command: fit

# %% [raw]
# img = plt.imread(glob.glob('*Spectrum_apecapec.png')[0])
# plt.imshow(img)
# plt.axis('off')

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 52.7376939°
# - DEC = -28.6344882°
#
# 52.74 -28.63
#
# **Column density :** nH = 2*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 6.818409328511275e+21
#
# bremss
# (tbabs) : 2.3508473354375896e+22
#
# apec
# (tbabs) : 5.096113161659971e+22
#
# powerlaw
# (tbabs) : 3.217233758696496e+23

# %% [markdown]
# ## Flux
# ### X-ray flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux   0.35182 photons (8.865e-10 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 8.865e-10  # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END+f"F_X = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux : F_X = 8.865e-10 ergs/cm^2/s

# %% [markdown]
# ### Optical flux
# No GAIA information, so we use the lower limit of 20.7 mag.

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)

G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
print(f"F_x-ray = {Flux/F}*F_optical")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 16087.532633089675
# F_x-ray = 16087.532633089675*F_optical

# %% [markdown]
# ## Luminosity
# No distance available.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s


print(color.BOLD+"For a star in the milky way? with d=[1 pc - 30 kpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s


print(color.BOLD+"For a galaxy? with d=[1 Mpc - 10 Gpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")
# Out:
# For a star in the milky way? with d=[1 pc - 30 kpc] :
# Luminosity : [1.0607083922629147e+29, 1.0607083922629146e+35] erg/s
# For a galaxy? with d=[1 Mpc - 10 Gpc] :
# Luminosity : [1.0607083922629148e+41, 1.0607083922629149e+49] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L = 4*np.pi*Flux*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L,D_pc)
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
