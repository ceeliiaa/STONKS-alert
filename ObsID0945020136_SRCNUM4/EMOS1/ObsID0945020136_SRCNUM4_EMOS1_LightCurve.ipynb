# %% [markdown]
# # ObsID : 0945020136, SRCNUM : 4, Instru : EMOS1

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob

import stingray as st
from stingray import Lightcurve, AveragedPowerspectrum

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [10,5]

# %%
def lightcurve(file):
    hdul = fits.open(file)
    print()
    print(color.BOLD +file+ color.END)
    hdul.info()
    
    rate_data = hdul[1].columns
    print()
    print(rate_data)
        
    time = hdul[1].data.field('TIME')
    rate = hdul[1].data.field('RATE')
    error = hdul[1].data.field('ERROR')
    backrate = hdul[1].data.field('BACKV')
    
    """
    print()
    print(f"TIME = {time} s")
    print(f"RATE = {rate} count/s")
    print(f"ERROR = {error} count/s")
    """
    
    lcs = []
    backlcs = []
    gtis = []
    for i in hdul[2].data:
        gtis.append([i[0],i[1]])
    lcs.append(Lightcurve(time, rate, error, gti=gtis, input_counts=False))
    backlcs.append(Lightcurve(time, backrate, error, gti=gtis, input_counts=False))
    
    for i in range(len(lcs)):
        plt.xlabel('Time (s)')
        plt.ylabel('Countrate (/s)')
        plt.plot(lcs[i].time, lcs[i].countrate, color='steelblue', lw=1, ds='steps-mid', label='Source corr')
        plt.plot(backlcs[i].time, backlcs[i].countrate, color='firebrick',lw=1, ls='--', ds='steps-mid', label='Background')
        plt.title(f'{file}')
        plt.legend(loc='upper right')
        plt.grid()
        for j in range(len(lcs[i].gti)-1):
            plt.axvspan(lcs[i].gti[j][1],lcs[i].gti[j+1][0],color='purple',alpha=0.25)
        plt.show()
    return lcs

# %% [markdown]
# ## Time bin size = 10s

# %%
#lightcurve(glob.glob('ObsID*_SRCNUM*_E*_t10_lccorr.lc')[0])
lc_EMOS1 = glob.glob('ObsID*_SRCNUM*_EMOS1_t10_lccorr.lc')
lc_EMOS2 = glob.glob('ObsID*_SRCNUM*_EMOS2_t10_lccorr.lc')
lc_combined = lightcurve(lc_EMOS1[0])[0]+lightcurve(lc_EMOS2[0])[0]
# Out:
# ObsID0945020136_SRCNUM4_EMOS1_t10_lccorr.lc
# Filename: ObsID0945020136_SRCNUM4_EMOS1_t10_lccorr.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      17   ()
#   1  RATE          1 BinTableHDU     77   775R x 6C   [D, E, E, E, E, E]
#   2  SRC_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   3  BKG_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   4  REG00105      1 BinTableHDU     24   1R x 5C   [16A, E, E, E, B]
#
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 's'
#     name = 'RATE'; format = 'E'; unit = 'count/s'
#     name = 'ERROR'; format = 'E'; unit = 'count/s'
#     name = 'FRACEXP'; format = 'E'; unit = 'fraction'
#     name = 'BACKV'; format = 'E'; unit = 'count/s'
#     name = 'BACKE'; format = 'E'; unit = 'count/s'
# )
# ObsID0945020136_SRCNUM4_EMOS2_t10_lccorr.lc
# Filename: ObsID0945020136_SRCNUM4_EMOS2_t10_lccorr.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      17   ()
#   1  RATE          1 BinTableHDU     79   775R x 6C   [D, E, E, E, E, E]
#   2  SRC_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   3  BKG_GTIS      1 BinTableHDU     28   1R x 2C   [D, D]
#   4  REG00105      1 BinTableHDU     24   1R x 5C   [16A, E, E, E, B]
#
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 's'
#     name = 'RATE'; format = 'E'; unit = 'count/s'
#     name = 'ERROR'; format = 'E'; unit = 'count/s'
#     name = 'FRACEXP'; format = 'E'; unit = 'fraction'
#     name = 'BACKV'; format = 'E'; unit = 'count/s'
#     name = 'BACKE'; format = 'E'; unit = 'count/s'
# )
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\stingray\lightcurve.py:596, in Lightcurve._operation_with_other_obj(self, other, operation)
#     595     diff = np.abs((self.time[mask_self] - other.time[mask_other]))
# --> 596     assert np.all(diff < self.dt / 100)
#     597 except (ValueError, AssertionError):
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       2 lc_EMOS1 = glob.glob('ObsID*_SRCNUM*_EMOS1_t10_lccorr.lc')
#       3 lc_EMOS2 = glob.glob('ObsID*_SRCNUM*_EMOS2_t10_lccorr.lc')
# ----> 4 lc_combined = lightcurve(lc_EMOS1[0])[0]+lightcurve(lc_EMOS2[0])[0]
#
# File ~\anaconda3\Lib\site-packages\stingray\lightcurve.py:659, in Lightcurve.__add__(self, other)
#     636 def __add__(self, other):
#     637     """
#     638     Add the counts of two light curves element by element, assuming the light curves
#     639     have the same time array.
#    (...)
#     656     >>> assert np.allclose(lc.counts, [ 900, 1300, 1200])
#     657     """
# --> 659     return self._operation_with_other_obj(other, np.add)
#
# File ~\anaconda3\Lib\site-packages\stingray\lightcurve.py:598, in Lightcurve._operation_with_other_obj(self, other, operation)
#     596     assert np.all(diff < self.dt / 100)
#     597 except (ValueError, AssertionError):
# --> 598     raise ValueError(
#     599         "GTI-filtered time arrays of both light curves "
#     600         "must be of same dimension and equal."
#     601     )
#     603 new_time = self.time[mask_self]
#     604 new_counts = operation(self.counts[mask_self], other.counts[mask_other])
#
# ValueError: GTI-filtered time arrays of both light curves must be of same dimension and equal.

# %%
lc_combined.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 lc_combined.plot()
#
# AttributeError: 'list' object has no attribute 'plot'

# %% [markdown]
# ## Time bin size = 50s

# %%
lightcurve(glob.glob('ObsID*_SRCNUM*_E*_t50_lccorr.lc')[0])

# %% [markdown]
# ## Time bin size = 200s

# %%
lightcurve(glob.glob('ObsID*_SRCNUM*_E*_t200_lccorr.lc')[0])

# %% [markdown]
# ## Time bin size = 500s

# %%
lightcurve(glob.glob('ObsID*_SRCNUM*_E*_t500_lccorr.lc')[0])
