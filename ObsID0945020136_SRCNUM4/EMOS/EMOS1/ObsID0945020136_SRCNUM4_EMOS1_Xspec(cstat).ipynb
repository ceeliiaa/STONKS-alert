# %% [markdown]
# # ObsID : 0945020136, SRCNUM : 4, Instru : EMOS1
# **Simbad :** Galaxy (2dFGRS TGS322Z047) https://simbad.cds.unistra.fr/simbad/sim-id?Ident=%404738151&Name=2dFGRS%20TGS322Z047&submit=submit

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=52.97008333333333%20-28.304833333333328&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
#
# - Stack Catalogue name : 4XMMs J033152.7-281818
# - IAU name : 4XMM J033152.7-281818
# - RA : 03h 31m 52.751s
# - DEC : -28° 18' 18.16"
#
# ``GAIA``
#
# - Designation : Gaia DR3 5057378691743871360
# - RA : 03h 31m 52.742s
# - DEC : -28° 18' 18.52"
# - Parallax : -0.7065 mas
# - Magnitude G (mag) : 19.6328
#
# ``GLADE``
#
# - No : 2 124 866
# - RA : 03h 31m 52.754s
# - DEC : -28° 18' 18.08"
# - Distance : 289.8972 Mpc
#
# ``2MASS``
#
# - Name : 03315275-2818185
# - RA : 03h 31m 52.751s
# - DEC : -28° 18' 18.57"

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ### Redshift

# %%
def redshift(d_Mpc):
    H0 = 70 # Hubble constant (km/s/Mpc)
    c = 299792.458 # km/s
    return H0*d_Mpc/c

z = redshift(289.8972)
print("Redshift : z =", z)
# Out:
# Redshift : z = 0.06768950805293442

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945020136_SRCNUM4_EMOS1_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  6.826e-03 +/- 1.295e-03 (64.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-76
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 7689 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0945020136_SRCNUM4_EMOS1_background_spectrum.fits
#   Background Exposure Time: 7686 sec
#  Using Response (RMF) File            ObsID0945020136_SRCNUM4_EMOS1.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945020136_SRCNUM4_EMOS1.arf

# %%
n_cts = 6.826e-03*7689

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 52.485113999999996
#
# The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 857.5, 659.5, -0.5)

# %% [markdown]
# ### Black body model
# **tbabs :**

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
plt.show()
nH_bbody = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              4.432668e+06     using 76 bins.
#
# Test statistic : Chi-Squared              1.597234e+11     using 76 bins.
#  Null hypothesis probability of 0.000000e+00 with 73 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 965313       909197       -3      0.363228     0.0949646      0.326361
# 110.119      6.3e+06      -4       415.255       198.760      0.111302
# 110.102      0.000262339  -4       95.9192       199.160     0.0238757
# 110.099      0.122677     -2       8.49282       199.309    0.00242485
# 98.8289      1.4313        0     0.0496383       67.8184     0.0747068
# 96.4164      31.987        0     0.0222427       74.6579     0.0521410
# 96.2631      12.573        0     0.0103014       74.3846     0.0526911
# 96.16        11.579        0    0.00446842       74.1428     0.0531818
# 96.0876      10.6334       0    0.00160501       73.9313     0.0536134
# 96.0349      9.77263       0   0.000192378       73.7481     0.0539891
# 95.9987      9.00906       0   1.74742e-05       73.5899     0.0543132
# 95.9708      8.33507       0   6.59524e-06       73.4547     0.0545900
# 95.9485      7.75625       0   1.17581e-06       73.3389     0.0548253
# 95.9306      7.26206       0   5.00542e-07       73.2400     0.0550247
# 95.9163      6.84132       0   1.63837e-07       73.1554     0.0551932
# 95.9047      6.48339       0   7.98597e-08       73.0831     0.0553352
# 95.8952      6.17963       0   3.79567e-08       73.0211     0.0554544
# 95.8875      5.92167       0   1.70419e-08       72.9677     0.0555541
# 95.8812      5.70285       0   6.59999e-09       72.9218     0.0556372
# 95.876       5.51746       0   1.38572e-09       72.8818     0.0557060
# 95.8717      5.35959       0   8.35353e-11       72.8476     0.0557628
# 95.8681      5.22684       0   2.26659e-12       72.8179     0.0558095
# 95.8652      5.11569       0   1.05086e-12       72.7918     0.0558474
# 95.8617      5.02064       0   4.24383e-13       72.7619     0.0558945
# 95.8565      4.88488       0   1.05827e-13       72.7174     0.0559748
# 95.8516      4.81895       0   3.05636e-14       72.6745     0.0560525
# 95.8449      4.57104       0   1.04333e-14       72.6145     0.0561687
# 95.8374      4.33244       0   5.12727e-15       72.5438     0.0563088
# 95.8354      3.88181       0   2.17745e-15       72.4811     0.0562418
# 95.8155      4.52018       0   9.04488e-16       72.2246     0.0566153
# 95.8054      3.12113       0   9.74174e-17       72.0426     0.0568423
# 95.7911      2.06697      -1   3.12561e-17       71.2099     0.0566379
# 95.7911      0.0573679    17   3.17675e-16       71.2099     0.0566379
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.8339E-04| -0.0000  -0.0024   1.0000
#  2.0486E+04|  1.0000   0.0002   0.0000
#  2.4591E+06|  0.0002  -1.0000  -0.0024
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.049e+04  -5.983e+02  -1.397e+00
#   -5.983e+02   2.459e+06   5.803e+03
#   -1.397e+00   5.803e+03   1.370e+01
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.17675E-16  +/-  143.130
#    2    2   bbody      kT         keV      71.2099      +/-  1568.15
#    3    2   bbody      norm                5.66379E-02  +/-  3.70071
# ________________________________________________________
#
#
# Fit statistic  : C-Statistic                 95.7911     using 76 bins.
#
# Test statistic : Chi-Squared                 61.7299     using 76 bins.
#  Null hypothesis probability of 8.2372e-01 with 73 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 660.5, -0.5)

# %% [markdown]
# **ztbabs :**

# %%
AllModels.clear()
moz = Model("ztbabs*bbody")
moz.zTBabs.Redshift = z
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody_z = moz.zTBabs.nH.values[0]
# Out:
# ========================================================================
# Model zTBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   zTBabs     nH         10^22    1.00000      +/-  0.0
#    2    1   zTBabs     Redshift            0.0          frozen
#    3    2   bbody      kT         keV      3.00000      +/-  0.0
#    4    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              4.430388e+06     using 76 bins.
#
# Test statistic : Chi-Squared              1.596737e+11     using 76 bins.
#  Null hypothesis probability of 0.000000e+00 with 73 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              4.540082e+06     using 76 bins.
#
# Test statistic : Chi-Squared              1.647865e+11     using 76 bins.
#  Null hypothesis probability of 0.000000e+00 with 73 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          3:kT        4:norm
# 110.119      931375       -3      0.297372    0.00998589      0.311361
# 110.119      0.00412397   -4       999998.    0.00995784   7.03345e+06
# ========================================
#  Variances and Principal Axes
#                  1        3        4
#  6.5264E+03| -0.0143   0.9999   0.0014
#  1.8293E+09|  0.9992   0.0143  -0.0376
#  1.5398E+15| -0.0376   0.0009  -0.9993
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.183e+12  -4.962e+10   5.791e+13
#   -4.962e+10   1.130e+09  -1.318e+12
#    5.791e+13  -1.318e+12   1.538e+15
# ------------------------------------
#
# ========================================================================
# Model zTBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   zTBabs     nH         10^22    9.99998E+05  +/-  1.47735E+06
#    2    1   zTBabs     Redshift            6.76895E-02  frozen
#    3    2   bbody      kT         keV      9.95784E-03  +/-  3.36214E+04
#    4    2   bbody      norm                7.03345E+06  +/-  3.92124E+07
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                110.1189     using 76 bins.
#
# Test statistic : Chi-Squared                 58.3622     using 76 bins.
#  Null hypothesis probability of 8.9385e-01 with 73 degrees of freedom

# %% [raw]
# img = plt.imread(glob.glob("ObsID*SRCNUM*E*Spectrum_bbody2_z.png")[0])
# plt.imshow(img)
# plt.axis('off')

# %% [markdown]
# ### Bremsstrahlung model
# **tbabs :**

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.067131e+06     using 76 bins.
#
# Test statistic : Chi-Squared              7.778941e+09     using 76 bins.
#  Null hypothesis probability of 0.000000e+00 with 73 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 198978       198720       -3      0.260037       198.067      0.194639
# 110287       173974       -3      0.121689       199.311     0.0932362
# 55201.7      200384       -2     0.0567211       199.347     0.0425524
# 5448.93      220161       -2     0.0280146       199.356    0.00434989
# 1256.15      227173       -2    0.00914875       199.362    0.00114911
# 316.083      222070       -3     0.0538430       199.363   0.000438996
# 70.1426      163022       -4     0.0231755       199.363   5.71062e-05
# 68.3756      36314        -2     0.0698427       69.6180   5.32617e-05
# 67.9729      18503.4      -1     0.0695731       43.7612   5.36219e-05
# 67.901       2685.64      -1     0.0780411       31.1975   5.03541e-05
# 67.7978      1961.58      -1     0.0889134       19.5810   4.72821e-05
# 67.6788      1781.11      -1      0.107142       10.3481   4.52153e-05
# 67.6357      2263.06      -2      0.129510       8.12055   4.57908e-05
# 67.6257      1284.17      -3      0.140746       7.26104   4.68303e-05
# 67.6251      462.605      -4      0.142822       7.23302   4.70781e-05
# 67.6251      14.4324       0      0.142871       7.19575   4.70791e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  7.6585E-11| -0.0001   0.0000   1.0000
#  1.7621E-02|  0.9999   0.0112   0.0001
#  1.3172E+02| -0.0112   0.9999  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.406e-02  -1.471e+00   2.419e-06
#   -1.471e+00   1.317e+02  -1.258e-04
#    2.419e-06  -1.258e-04   2.550e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.142871     +/-  0.184559
#    2    2   bremss     kT         keV      7.19575      +/-  11.4761
#    3    2   bremss     norm                4.70791E-05  +/-  1.59680E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 67.6251     using 76 bins.
#
# Test statistic : Chi-Squared                 55.0545     using 76 bins.
#  Null hypothesis probability of 9.4198e-01 with 73 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 852.5, 657.5, -0.5)

# %% [markdown]
# **ztbabs :**

# %%
AllModels.clear()
moz = Model("ztbabs*bremss")
moz.zTBabs.Redshift = z
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss_z = moz.zTBabs.nH.values[0]
# Out:
# ========================================================================
# Model zTBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   zTBabs     nH         10^22    1.00000      +/-  0.0
#    2    1   zTBabs     Redshift            0.0          frozen
#    3    2   bremss     kT         keV      7.00000      +/-  0.0
#    4    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.064007e+06     using 76 bins.
#
# Test statistic : Chi-Squared              7.756825e+09     using 76 bins.
#  Null hypothesis probability of 0.000000e+00 with 73 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.151509e+06     using 76 bins.
#
# Test statistic : Chi-Squared              8.712944e+09     using 76 bins.
#  Null hypothesis probability of 0.000000e+00 with 73 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          3:kT        4:norm
# 195409       211969       -3      0.233679       198.180      0.181165
# 41865.6      183100       -3      0.112985       199.307     0.0347655
# 8721.09      204710       -2     0.0230875       199.361    0.00661237
# 3909.06      233732       -2    0.00487553       199.363    0.00301037
# 1685.05      240272       -3      0.225753       199.363    0.00196753
# 110.241      168341       -4     0.0717851       199.363   0.000196471
# 68.58        100879       -5     0.0252001       89.3662   6.44585e-05
# 68.5219      16485.6      -2     0.0652430       44.5423   4.50631e-05
# 67.9919      28907.8      -2      0.110830       12.9306   4.00724e-05
# 67.7176      25654.7      -3      0.145164       5.69432   4.45299e-05
# 67.5475      10752.8      -4      0.154882       6.94593   4.63771e-05
# 67.5425      1808.24      -5      0.155089       7.43799   4.66010e-05
# 67.5421      178.428      -6      0.157764       7.24684   4.68208e-05
# 67.5421      25.5993       0      0.157830       7.26652   4.68224e-05
# ========================================
#  Variances and Principal Axes
#                  1        3        4
#  7.5809E-11| -0.0000   0.0000   1.0000
#  2.1764E-02|  0.9999   0.0120   0.0000
#  1.2699E+02| -0.0120   0.9999  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.999e-02  -1.521e+00   2.444e-06
#   -1.521e+00   1.270e+02  -1.139e-04
#    2.444e-06  -1.139e-04   2.315e-10
# ------------------------------------
#
# ========================================================================
# Model zTBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   zTBabs     nH         10^22    0.157830     +/-  0.199983
#    2    1   zTBabs     Redshift            6.76895E-02  frozen
# 52      +/-  11.2683              keV      7.266
#    4    2   bremss     norm                4.68224E-05  +/-  1.52165E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 67.5421     using 76 bins.
#
# Test statistic : Chi-Squared                 55.0564     using 76 bins.
#  Null hypothesis probability of 9.4195e-01 with 73 degrees of freedom

# %%
img = plt.imread(glob.glob("ObsID*SRCNUM*E*Spectrum_bremss2_z.png")[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 857.5, 661.5, -0.5)

# %% [markdown]
# ### Apec model
# **tbabs :**

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = moz.zTBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic                397313.6     using 76 bins.
#
# Test statistic : Chi-Squared              1.110245e+09     using 76 bins.
#  Null hypothesis probability of 0.000000e+00 with 73 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 169.872      115583       -3       257.372       34.6577      0.394665
# 118.277      34.1567      -1       215.149       54.2596     0.0636572
# 109.399      46.5477      -1       190.678       62.8011     0.0145813
# 109.229      22.7872       0       190.784       63.7928     0.0132855
# 109.173      18.22         0       189.392       63.9069     0.0125228
# 109.146      16.8884       0       187.453       63.9622     0.0119441
# 109.129      16.6624       0       185.283       63.9893     0.0114460
# 109.115      16.9163       0       183.011       63.9961     0.0109895
# 109.104      17.3977       0       180.689       63.9981     0.0105584
# 109.093      17.9958       0       178.337       63.9994     0.0101458
# 109.082      18.6644       0       175.965       63.9998    0.00974849
# 109.071      19.3851       0       173.574       63.9999    0.00936484
# 109.06       20.1507       0       171.164       64.0000    0.00899376
# 109.048      20.96         0       168.734       64.0000    0.00863450
# 109.037      21.8145       0       166.280       64.0000    0.00828643
# 109.025      22.7172       0       163.801       64.0000    0.00794899
# 109.013      23.6721       0       161.294       64.0000    0.00762164
# 109.001      24.6839       0       158.754       64.0000    0.00730390
# 108.988      25.7584       0       156.180       64.0000    0.00699529
# 108.975      26.9021       0       153.565       64.0000    0.00669534
# 108.961      28.1225       0       150.907       64.0000    0.00640363
# 108.947      29.4284       0       148.199       64.0000    0.00611972
# 108.932      30.83         0       145.436       64.0000    0.00584319
# 108.917      32.3393       0       142.612       64.0000    0.00557366
# 108.901      33.9703       0       139.719       64.0000    0.00531072
# 108.883      35.7397       0       136.749       64.0000    0.00505399
# 108.757      56.5013      -1       116.258       64.0000    0.00193669
# 107.089      108.742      -2       33.2574       64.0000   0.000780415
# 106.682      791.422      -1       27.3548       64.0000   0.000437837
# 105.969      501.355      -2       16.3523       64.0000   0.000326782
# 99.7152      494.968      -3       4.73921       64.0000   0.000156579
# 92.0621      10558.5      -4       1.36554       64.0000   9.83553e-05
# 90.0258      33194        -1      0.204321       64.0000   4.97117e-05
# 70.0049      85276.8      -2     0.0909083       64.0000   0.000129997
# 68.0615      24108.7      -3     0.0502849       64.0000   0.000160313
# 68.0371      685.995      -4     0.0637510       64.0000   0.000164628
# 23       64.0000   0.000164814   0.06418
# 68.0263      0.0563923     0     0.0650054       59.4392   0.000164133
# 67.9433      839.668      -1     0.0711894       42.7944   0.000152742
# 67.8642      971.936      -1     0.0797231       27.3996   0.000140454
# 67.6784      1062.39      -2     0.0936420       11.8538   0.000125746
# 67.3532      2499.03      -1      0.126653       5.25428   0.000119310
# 67.2158      1484.09      -2      0.152297       5.64365   0.000122898
# 67.1877      184.037      -3      0.177434       5.34391   0.000125784
# 67.1854      21.8315      -4      0.181582       5.40960   0.000126556
# 67.1854      3.66916      -5      0.182874       5.39761   0.000126731
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  5.5905E-10| -0.0001  -0.0000   1.0000
#  2.1252E-02|  0.9996   0.0278   0.0001
#  1.2941E+01| -0.0278   0.9996  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.124e-02  -3.592e-01   3.945e-06
#   -3.592e-01   1.293e+01  -2.874e-05
#    3.945e-06  -2.874e-05   1.088e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.182874     +/-  0.176760
#    2    2   apec       kT         keV      5.39761      +/-  3.59592
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.26731E-04  +/-  3.29917E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 67.1854     using 76 bins.
#
# Test statistic : Chi-Squared                 54.2515     using 76 bins.
#  Null hypothesis probability of 9.5076e-01 with 73 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 860.5, 656.5, -0.5)

# %% [markdown]
# **ztbabs :**

# %%
AllModels.clear()
moz = Model("ztbabs*apec")
moz.zTBabs.Redshift = z
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec_z = moz.zTBabs.nH.values[0]
# Out:
# ========================================================================
# Model zTBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   zTBabs     nH         10^22    1.00000      +/-  0.0
#    2    1   zTBabs     Redshift            0.0          frozen
#    3    2   apec       kT         keV      1.00000      +/-  0.0
#    4    2   apec       Abundanc            1.00000      frozen
#    5    2   apec       Redshift            0.0          frozen
#    6    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                392178.6     using 76 bins.
#
# Test statistic : Chi-Squared              1.077429e+09     using 76 bins.
#  Null hypothesis probability of 0.000000e+00 with 73 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                487969.3     using 76 bins.
#
# Test statistic : Chi-Squared              1.793354e+09     using 76 bins.
#  Null hypothesis probability of 0.000000e+00 with 73 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          3:kT        6:norm
# 110.044      134915       -3       690.788       60.9679      0.363335
# 108.521      0.0337296    -3       324.771       5.28913     0.0632663
# 108.449      0.734935      0       328.320       6.62373     0.0584660
# 108.388      0.0244341    -1       326.334       11.5419     0.0492446
# 108.356      0.992811     -1       315.645       15.0204     0.0457335
# 108.344      0.342301     -1       305.599       13.3069     0.0412693
# 108.339      0.102683     -1       295.957       15.8722     0.0375898
# 108.336      0.771712      0       296.110       14.8942     0.0374046
# 108.333      0.619199      0       295.996       14.4310     0.0365134
# 108.331      0.299944     -1       288.893       16.9947     0.0317140
# 108.325      0.0520504     0       288.696       14.7691     0.0317308
# 108.324      0.139579      0       287.455       14.9546     0.0315709
# 108.316      0.0686429    -1       279.688       15.0128     0.0280886
# 108.308      0.0311613    -1       272.118       15.4806     0.0250775
# 108.308      0.0367615     0       271.974       14.7367     0.0250740
# 108.307      0.0111421     0       271.043       15.3509     0.0248544
# 108.307      0.161133      1       271.033       15.2698     0.0248523
# ========================================
#  Variances and Principal Axes
#                  1        3        6
#  4.2800E-04| -0.0004   0.0001   1.0000
#  9.3573E+03|  0.0022  -1.0000   0.0001
#  2.2273E+05|  1.0000   0.0022   0.0004
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.227e+05   4.620e+02   8.361e+01
#    4.620e+02   9.358e+03  -6.348e-01
#    8.361e+01  -6.348e-01   3.188e-02
# ------------------------------------
#
# ========================================================================
# Model zTBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   zTBabs     nH         10^22    271.033      +/-  471.937
#    2    1   zTBabs     Redshift            6.76895E-02  frozen
#    3    2   apec       kT         keV      15.2698      +/-  96.7384
#    4    2   apec       Abundanc            1.00000      frozen
#    5    2   apec       Redshift            0.0          frozen
#    6    2   apec       norm                2.48523E-02  +/-  0.178557
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                108.3069     using 76 bins.
#
# Test statistic : Chi-Squared                 58.2078     using 76 bins.
#  Null hypothesis probability of 8.9654e-01 with 73 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2_z.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 661.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %% [raw]
# AllModels.clear()
# mo = Model("tbabs*powerlaw")
# Fit.perform()
# Plot.device = "/xs"
# Plot("data resid")

# %% [raw]
# img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw2.png')[0])
# plt.imshow(img)
# plt.axis('off')

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :** from ESASky
#
# - RA = 52.9697976°
# - Dec = -28.3050451°
#
# 53.97 -28.31
#
# **Column density :** nH = 3*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print(f"(ztbabs) : {nH_bbody_z*10**22}")
print()
print(color.BOLD+"bremss"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print(f"(ztbabs) : {nH_bremss_z*10**22}")
print()
print(color.BOLD+"apec"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print(f"(ztbabs) : {nH_apec_z*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 3176750.345141201
# (ztbabs) : 9.999977502866567e+27
#
# bremss
# (tbabs) : 1.4287116003861497e+21
# (ztbabs) : 1.5783044172445057e+21
#
# apec
# (tbabs) : 1.828740538429944e+21
# (ztbabs) : 2.710330633520318e+24

# %% [markdown]
# ## Flux
# ### X-ray flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 5.5599e-05 photons (9.0172e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 9.0172e-13 # ergs/cm^2/s
print(color.BOLD+"X-ray  flux : "+color.END+f"F_X = {Flux} ergs/cm^2/s")
# Out:
# X-ray  flux : F_X = 9.0172e-13 ergs/cm^2/s

# %% [markdown]
# ### Optical flux

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)
    
G = 19.6328

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 1.4725474536744745e-13 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
print(f"F_x-ray = {Flux/F}*F_optical")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 6.1235378034841705
# F_x-ray = 6.1235378034841705*F_optical

# %% [markdown]
# ### Luminosity

# %%
"""GAIA"""

P_mas = 0.7065 # Parallaxe en mas
d_kpc = 1/P_mas # Distance en kpc
d_cm = d_kpc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
Luminosity = 4*np.pi*Flux*(d_cm)**2 # erg/s

print(color.BOLD+"(GAIA)"+color.END)
print(f"Distance : {d_cm} cm")
print(f"Luminosité : {Luminosity} erg/s")
print()

"""GLADE"""

d_kpc = 289897.2 # Distance en kpc
d_cm = d_kpc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
Luminosity = 4*np.pi*Flux*(d_cm)**2 # erg/s

print(color.BOLD+"(GLADE)"+color.END)
print(f"Distance : {d_cm} cm")
print(f"Luminosité : {Luminosity} erg/s")
# Out:
# (GAIA)
# Distance : 4.3675866949752303e+21 cm
# Luminosité : 2.1615467605886376e+32 erg/s
#
# (GLADE)
# Distance : 8.945357900400001e+26 cm
# Luminosité : 9.067279618712659e+42 erg/s
