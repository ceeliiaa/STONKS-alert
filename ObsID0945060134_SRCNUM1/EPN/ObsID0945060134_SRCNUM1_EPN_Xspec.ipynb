# %% [markdown]
# # ObsID : 0945060134, SRCNUM : 1, Instru : EPN
# Not on Simbad

# %% [markdown]
# ## ESASky
#
# Dans ESASky le pointeur est sur une source verte, éloignée de la source EPIC stack la plus proche. Cependant, lorsqu'on regarde l'image sur XMM Archive, il semblerait que ce soit bien cette source verte. https://sky.esa.int/esasky/?target=53.59466666666666%20-28.902777777777782&hips=DSS2+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``2MASS``
# - Name : 03342264-2854082
# - RA : 03h 34m 22.642s
# - DEC : -28° 54' 08.24"
#
# ``GAIA``
# - Designation : DR3 5057101614813827200
# - RA : 03h 34m 22.626s
# - DEC : -28° 54' 08.62"
# - Parallax : 2.941 mas
# - G : 19.6951

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: Chi-Squared
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files

# %%
AllData.clear()
spec = Spectrum(glob.glob('P*PNS*SRSPEC*.FTZ')[0])
# Out:
# Warning: RMF FILTER keyword (Medium) is not consistent with that in the ARF (Thin1)
# Warning: RMF FILTER keyword (Medium) is not consistent with that in spectrum (Thin1)
#
# 1 spectrum  in use
#
# Spectral Data File: P0945060134PNS003SRSPEC0001.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.673e-02 +/- 2.181e-03 (72.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-14
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7820 sec
#  Using fit statistic: chi
#  Using Background File                P0945060134PNS003BGSPEC0001.FTZ
#   Background Exposure Time: 7820 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY6.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0945060134PNS003SRCARF0001.FTZ

# %%
n_cts = 2.673e-02*7820

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 209.0286

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")
spec.ignore("**-0.2 12-**")
# Out:
#       No channels ignored (no channels in specified range)
#      3 channels (12,14) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('*Spectrum.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 651.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.884376e+10     using 11 bins.
#
# Test statistic : Chi-Squared              7.884376e+10     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 138.412      1.07629       0      0.394606       3.09319   1.38680e-05
# 134.651      27843         0      0.157314       3.24176   1.19081e-05
# 129.356      169797        0     0.0414273       3.21362   1.21513e-05
# 127.364      185672        0     0.0146658       3.18891   1.23634e-05
# 126.173      178673        0    0.00235195       3.16764   1.25451e-05
# 125.726      167225        0   0.000910365       3.14950   1.26980e-05
# 125.408      152470        0   0.000218714       3.13433   1.28224e-05
# 125.187      139337        0   5.14826e-05       3.12159   1.29231e-05
# 125.021      127791        0   1.07905e-05       3.11080   1.30041e-05
# 124.893      117824        0   8.42673e-07       3.10160   1.30687e-05
# 124.792      109284        0   2.32426e-07       3.09369   1.31198e-05
# 124.712      101997        0   8.22265e-08       3.08684   1.31597e-05
# 124.648      95794.5       0   8.10303e-09       3.08086   1.31902e-05
# 124.596      90527.1       0   3.52094e-09       3.07561   1.32129e-05
# 124.554      86062.3       0   1.25101e-09       3.07095   1.32290e-05
# 124.519      82284.2       0   1.24915e-10       3.06679   1.32397e-05
# 124.49       79090.7       0   5.49919e-11       3.06304   1.32459e-05
# 124.466      76395         0   2.01759e-11       3.05964   1.32482e-05
# 124.445      74124.5       0   2.82797e-12       3.05653   1.32473e-05
# 124.428      72213         0   6.41789e-13       3.05366   1.32436e-05
# 124.413      70617.9       0   3.67113e-14       3.05096   1.32385e-05
# 124.389      69204.3       0   1.59848e-14       3.04746   1.32416e-05
# 124.357      66742.7       0   5.28551e-15       3.04305   1.32563e-05
# 124.31       62906.1       0   2.10340e-15       3.03715   1.32890e-05
# 124.269      56844.3       0   4.13099e-16       3.03139   1.33184e-05
# 124.197      50980.3       0   2.02437e-16       3.01151   1.32233e-05
# 124          43226.7      -1   3.95952e-17       2.88255   1.16631e-05
# 123.442      62486        -1   1.12681e-18       2.69138   1.03121e-05
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.12681e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 122.971      20346.9      -1   1.12681e-18       2.51310   8.80568e-06
# 113.862      4297.33      -2   1.12681e-18      0.869156   1.50538e-06
# 18.7682      1.1431e+07   -2   1.12681e-18      0.237944   5.24034e-07
# 11.5579      2.20928e+07  -3   1.12681e-18      0.263756   6.64487e-07
# 11.495       1.24266e+06  -4   1.12681e-18      0.260151   6.69157e-07
# 11.495       9538.94      -5   1.12681e-18      0.260097   6.69171e-07
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.12681e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 11.495       9.07409      -3   1.12681e-18      0.260099   6.69173e-07
# ==============================
#  Variances and Principal Axes
#                  2        3
#  2.9518E-15| -0.0000   1.0000
#  2.8659E-04|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    2.866e-04   2.216e-10
#    2.216e-10   3.123e-15
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.12681E-18  +/-  -1.00000
#    2    2   bbody      kT         keV      0.260099     +/-  1.69290E-02
#    3    2   bbody      norm                6.69173E-07  +/-  5.58847E-08
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 11.4950     using 11 bins.
#
# Test statistic : Chi-Squared                 11.4950     using 11 bins.
#  Null hypothesis probability of 1.7520e-01 with 8 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_bbody.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 651.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.243186e+10     using 11 bins.
#
# Test statistic : Chi-Squared              3.243186e+10     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 85.2471      3.54587      -1      0.109857       1.84860   1.41764e-05
# 31.8297      714645       -2     0.0480816      0.644987   5.09252e-05
# 15.6291      129173       -3      0.174727      0.642123   0.000104540
# 12.3093      65429.8      -4      0.181048      0.523215   0.000151373
# 10.6498      30154.8      -5      0.195185      0.521372   0.000178218
# 10.6378      2094.91      -6      0.191915      0.524697   0.000175465
# 10.6378      38.415       -7      0.192115      0.524605   0.000175678
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.0186E-10| -0.0007   0.0005   1.0000
#  7.9395E-04|  0.9135   0.4068   0.0005
#  2.6814E-02| -0.4068   0.9135  -0.0007
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.100e-03  -9.669e-03   8.436e-06
#   -9.669e-03   2.251e-02  -1.803e-05
#    8.436e-06  -1.803e-05   1.515e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.192115     +/-  7.14132E-02
#    2    2   bremss     kT         keV      0.524605     +/-  0.150026
#    3    2   bremss     norm                1.75678E-04  +/-  1.23078E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 10.6378     using 11 bins.
#
# Test statistic : Chi-Squared                 10.6378     using 11 bins.
#  Null hypothesis probability of 2.2308e-01 with 8 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_bremss.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 649.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.448886e+09     using 11 bins.
#
# Test statistic : Chi-Squared              7.448886e+09     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 53.459       14.1112      -3      0.627879      0.650217   6.40942e-05
# 47.4382      105301       -4      0.566785      0.689289   6.95738e-05
# 47.3233      18025.6      -5      0.566262      0.689998   6.73090e-05
# 47.3233      38.0972      -6      0.566273      0.689971   6.73171e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
# 2   0.0001   1.0000
#  2.7929E-03| -0.5196  -0.8544  -0.0000
#  1.4843E-02|  0.8544  -0.5196   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.159e-02  -5.350e-03   2.437e-06
#   -5.350e-03   6.047e-03  -1.330e-06
#    2.437e-06  -1.330e-06   5.634e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.566273     +/-  0.107653
#    2    2   apec       kT         keV      0.689971     +/-  7.77595E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                6.73171E-05  +/-  2.37362E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 47.3233     using 11 bins.
#
# Test statistic : Chi-Squared                 47.3233     using 11 bins.
#  Null hypothesis probability of 1.3304e-07 with 8 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_apec.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 647.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.114051e+11     using 11 bins.
#
# Test statistic : Chi-Squared              1.114051e+11     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 132.555      2.96525      -2      0.424335       1.10402   6.35198e-06
# 110.877      597136        0      0.204095       1.60492   7.87890e-06
# 48.9467      875109       -1     0.0626932       3.14127   1.51210e-05
# 18.6464      189440       -2      0.145451       2.55067   2.87816e-05
# 14.1091      96905.7      -3      0.340838       4.10483   5.03345e-05
# 11.0941      123366       -4      0.411025       4.55860   6.99443e-05
# 10.7898      30928.6      -5      0.405093       4.52328   7.18941e-05
# 10.7898      487.978      -6      0.405416       4.52472   7.19233e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.3868E-11| -0.0003   0.0000   1.0000
#  1.0353E-03|  0.9893  -0.1457   0.0003
#  9.5297E-01|  0.1457   0.9893   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.123e-02   1.372e-01   4.726e-06
#    1.372e-01   9.328e-01   3.005e-05
#    4.726e-06   3.005e-05   1.091e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.405416     +/-  0.145707
#    2    2   powerlaw   PhoIndex            4.52472      +/-  0.965801
#    3    2   powerlaw   norm                7.19233E-05  +/-  3.30347E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 10.7898     using 11 bins.
#
# Test statistic : Chi-Squared                 10.7898     using 11 bins.
#  Null hypothesis probability of 2.1390e-01 with 8 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_powerlaw.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 859.5, 650.5, -0.5)

# %% [markdown]
# ### Black body + Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbodypowerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.748446e+11     using 11 bins.
#
# Test statistic : Chi-Squared              3.748446e+11     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 132.749      37614.3      -2      0.191606       3.16785   1.20293e-05       4.23719   2.12920e-07
# 3.16458   1.20591e-05       5.23278   4.03904e-07
# 116.34       1.79403e+06   0     0.0564159       3.14330   1.22444e-05       6.49396   9.48731e-07
# 96.6296      8.62776e+06   0     0.0671563       3.04663   1.29279e-05       6.32572   8.77736e-07
# 88.9486      1.64459e+06  -1     0.0904318       2.88298   1.17812e-05       5.72434   1.39310e-06
# 80.8149      1.10384e+06  -1      0.110218       2.78072   1.03321e-05       4.68855   3.12517e-06
# 63.875       1.02606e+06  -1      0.128339       2.77606   8.56027e-06       2.90631   9.93317e-06
# 58.7369      498113       -2      0.266974       3.67002   2.84912e-06       2.30679   3.86082e-05
# 40.5272      224692       -1      0.131782       5.12413   2.01449e-07       3.02752   3.63339e-05
# 16.6648      409720       -2      0.189774       196.180   9.31274e-08       2.98965   4.03382e-05
# 12.5146      102998       -2      0.260806       199.310   4.29161e-08       3.46193   4.70266e-05
# 11.243       17136.4      -2      0.317712       199.338   2.06253e-08       3.91307   5.46364e-05
# 11.0055      1876.97      -2      0.361076       92.1122     0.0247826       4.24556   6.17685e-05
# 10.9176      1048.05      -3      0.475506       72.9405     0.0430213       5.11305   8.15621e-05
# 10.512       8471.71      -4      0.523015       84.6279     0.0536361       5.43096   9.61363e-05
# 10.4921      3309.74      -4      0.522911       95.9395     0.0725229       5.42834   9.73663e-05
# 10.4914      197.799      -3      0.522802       96.8477     0.0763680       5.42770   9.73346e-05
# 10.4914      7.2789       -3      0.522825       98.2716     0.0798023       5.42786   9.73406e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  6.5996E-11| -0.0004  -0.0000   0.0000   0.0000   1.0000
#  1.2319E-03|  0.9589  -0.0006   0.2437  -0.1451   0.0004
#  6.1671E-03|  0.2488   0.0023  -0.9684   0.0181   0.0001
#  4.2691E+00|  0.1361  -0.0001   0.0534   0.9893   0.0000
#  5.0760E+10| -0.0000   1.0000   0.0024  -0.0000  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.856e-01  -7.303e+04  -1.720e+02   1.472e+00   4.303e-05
#   -7.303e+04   5.076e+10   1.196e+08  -6.241e+05  -1.492e+01
#   -1.720e+02   1.196e+08   2.818e+05  -1.470e+03  -3.515e-02
#    1.472e+00  -6.241e+05  -1.470e+03   1.185e+01   3.354e-04
#    4.303e-05  -1.492e+01  -3.515e-02   3.354e-04   1.028e-08
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.522825     +/-  0.430850
#    2    2   bbody      kT         keV      98.2716      +/-  2.25299E+05
#    3    2   bbody      norm                7.98023E-02  +/-  530.834
#    4    3   powerlaw   PhoIndex            5.42786      +/-  3.44264
#    5    3   powerlaw   norm                9.73406E-05  +/-  1.01366E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 10.4914     using 11 bins.
#
# Test statistic : Chi-Squared                 10.4914     using 11 bins.
#  Null hypothesis probability of 1.0543e-01 with 6 degrees of freedom

# %%
img = plt.imread(glob.glob('*Spectrum_bbodypowerlaw.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 846.5, 651.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung + Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*(bremss+powerlaw)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH
png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 851.5, 650.5, -0.5)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 53.5942754°
# - Dec = -28.9023933°
#
# 53.59 -28.90
#
# **Column density :** nH = 3*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
print()
print(color.BOLD+"bbody+powerlaw"+color.END)
print(f"(tbabs) : {nH_bbodypowerlaw*10**22}")
print()
print(color.BOLD+"bremss+powerlaw"+color.END)
print(f"(tbabs) : {nH_bremsspowerlaw*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 11268.05163800787
#
# bremss
# (tbabs) : 1.9211467782721356e+21
#
# apec
# (tbabs) : 5.662727731226396e+21
#
# powerlaw
# (tbabs) : 4.054159952006428e+21
#
# bbody+powerlaw
# (tbabs) : 5.228247033510113e+21
#
# bremss+powerlaw
# (tbabs) : 4.053995055601904e+21

# %% [markdown]
# ## Flux
# ### X-ray flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.7523e-05 photons (5.5691e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 5.5691e-14  # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END+f"F_X = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux : F_X = 5.5691e-14 ergs/cm^2/s

# %% [markdown]
# ### Optical flux
# No GAIA information, so we use the lower limit of 20.7 mag.

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)

G = 19.6951

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 1.390430542671063e-13 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
print(f"F_x-ray = {Flux/F}*F_optical")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 0.40053061473330226
# F_x-ray = 0.40053061473330226*F_optical

# %% [markdown]
# ## Luminosity

# %%
"""GAIA"""

P_mas = 2.941 # Parallaxe en mas
d_kpc = 1/P_mas # Distance en kpc
d_cm = d_kpc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
Luminosity = 4*np.pi*Flux*(d_cm)**2 # erg/s

print(color.BOLD+"(GAIA)"+color.END)
print(f"Distance : {d_cm} cm")
print(f"Luminosité : {Luminosity} erg/s")
# Out:
# (GAIA)
# Distance : 1.0492009520571234e+21 cm
# Luminosité : 7.703928301640866e+29 erg/s
