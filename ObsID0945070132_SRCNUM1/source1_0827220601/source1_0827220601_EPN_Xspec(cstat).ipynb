# %% [markdown]
# # ObsID : 0827220601, Instru : EPN
# First detection of the source **0945070132 - 1**.

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files

# %%
AllData.clear()
spec = Spectrum(glob.glob("source1_0827220601_EPN_spectrum_grp_cstat.fits")[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: source1_0827220601_EPN_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.092e-03 +/- 7.245e-04 (9.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-247
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 2.782e+04 sec
#  Using fit statistic: cstat
#  Using Background File                source1_0827220601_EPN_background_spectrum.fits
#   Background Exposure Time: 2.782e+04 sec
#  Using Response (RMF) File            source1_0827220601_EPN.rmf for Source 1
#  Using Auxiliary Response (ARF) File  source1_0827220601_EPN.arf

# %%
print(f"Number of counts = {1.092e-03*2.782e+04} cts")
# Out:
# Number of counts = 30.379440000000002 cts

# %% [markdown]
# The number of counts is lower than 100 cts, indicating that the C-statistic test should be a better choice for a goodness-of-fit statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
#      8 channels (1-8) ignored in spectrum #     1
#     23 channels (225-247) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 855.5, 656.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
plt.show()
nH_bbody = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              1.497924e+08     using 216 bins.
#
# Test statistic : Chi-Squared              5.117298e+13     using 216 bins.
#  Null hypothesis probability of 0.000000e+00 with 213 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 438.322      2.93427e+07  -3     0.0915632       199.120      0.330864
# 205.147      183.364      -3     0.0381214       199.264    0.00479802
# 205.105      10.2134       0       1.65979       199.191    0.00535390
# 205.012      10.0841       0      0.649216       198.949    0.00679604
# 204.993      8.0175        0       1.19077       198.865    0.00724712
# 204.958      7.46809       0      0.224829       198.518    0.00863477
# 204.936      4.60022       0       1.53642       198.437    0.00891998
# 204.915      5.00154       0      0.643692       198.267    0.00941439
# 204.909      4.00402       0       1.20962       198.183    0.00965282
# 204.899      3.91213       0      0.561465       197.914     0.0102717
# 204.893      2.57032       0       1.27538       197.838     0.0104362
# 204.89       2.73938       0      0.709949       197.768     0.0105789
#     1.16178       197.695     0.0107177
# 204.884      2.27685       0      0.829783       197.629     0.0108387
# 204.883      1.9186        0       1.08001       197.562     0.0109543
# 204.881      1.87586       0      0.911160       197.501     0.0110562
# 204.88       1.62512       0       1.03371       197.441     0.0111517
# 204.878      1.54042       0      0.835384       197.209     0.0114677
# 204.877      0.89582       0       1.10147       197.165     0.0115265
# 204.877      0.961868      0      0.949851       197.125     0.0115762
# 204.876      0.796189      0       1.04004       197.086     0.0116239
# 204.876      0.769722      0      0.992424       197.052     0.0116658
# 204.876      0.672516      0       1.02190       197.018     0.0117045
# 204.876      0.624436      0       1.04199       196.876     0.0118352
# 204.875      0.407813      0       1.00783       196.855     0.0118569
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.2666E-04| -0.0004  -0.0002   1.0000
#  6.9022E+02|  1.0000   0.0003   0.0004
#  2.7453E+09| -0.0003   1.0000   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.788e+02  -8.901e+05  -1.593e+02
#   -8.901e+05   2.745e+09   4.920e+05
#   -1.593e+02   4.920e+05   8.818e+01
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00783      +/-  31.2864
#    2    2   bbody      kT         keV      196.855      +/-  5.23954E+04
#    3    2   bbody      norm                1.18569E-02  +/-  9.39054
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                204.8755     using 216 bins.
#
# Test statistic : Chi-Squared                145.2739     using 216 bins.
#  Null hypothesis probability of 9.9988e-01 with 213 degrees of freedom
#  Model Flux 8.4058e-07 photons (1.1036e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ### Bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              2.733468e+07     using 216 bins.
#
# Test statistic : Chi-Squared              1.930320e+12     using 216 bins.
#  Null hypothesis probability of 0.000000e+00 with 213 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 1.67443e+07  5.06774e+06  -3      0.108342       199.332      0.479194
# 8.14252e+06  7.66145e+06  -1     0.0292834       199.348      0.195719
# 577961       7.92269e+06  -1    0.00922412       199.363     0.0131266
# 3273.35      7.38122e+06  -1   0.000832094       199.363   9.07380e-05
# 445.913      6.80834e+06  -1   0.000296426       199.363   1.40703e-05
# 206.183      4.45831e+06  -1   3.65528e-05       199.363   5.16061e-07
# 205.74       384158       -1   1.59549e-05       199.363   2.69741e-07
# 205.613      212962       -1   6.37969e-06       199.363   1.43279e-07
# 205.574      121211       -1   1.93688e-06       199.363   7.59836e-08
# 205.562      71270.8      -1   8.97501e-07       199.363   3.95195e-08
# 205.557      43884.7      -1   3.99914e-07       199.363   1.95800e-08
# 205.556      28809.6      -1   1.49389e-07       199.363   8.62007e-09
# 205.555      20493.2      -1   7.29649e-09       199.363   2.57881e-09
# 205.554      15899.8      -1   3.58828e-09       199.363   9.11316e-10
# 205.553      14631.2      -1   9.65427e-10       199.363   2.63894e-10
# 205.553      14140        -1   3.99367e-10       199.363   1.19926e-10
# 205.552      14035.7      -1   8.79799e-11       199.363   5.00652e-11
# 205.552      13995.4      -1   4.13632e-11       199.363   1.57847e-11
# 205.552      13984.6      -1   4.39335e-12       199.363   6.78390e-12
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.3790E-13| -0.0000  -0.0000   1.0000
#  9.3561E+07|  1.0000   0.0000   0.0000
#  1.8933E+17| -0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.687e+08  -3.773e+12  -8.758e-02
#   -3.773e+12   1.893e+17   4.642e+03
#   -8.758e-02   4.642e+03   1.145e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.39335E-12  +/-  1.29902E+04
#    2    2   bremss     kT         keV      199.363      +/-  4.35126E+08
#    3    2   bremss     norm                6.78390E-12  +/-  1.07011E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                205.5516     using 216 bins.
#
# Test statistic : Chi-Squared                138.9300     using 216 bins.
#  Null hypothesis probability of 9.9998e-01 with 213 degrees of freedom
#  Model Flux 8.1875e-12 photons (3.0115e-20 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic              1.032826e+07     using 216 bins.
#
# Test statistic : Chi-Squared              5.524791e+11     using 216 bins.
#  Null hypothesis probability of 0.000000e+00 with 213 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 5.64884e+06  3.11375e+06  -3      0.329148       44.7731      0.412361
# 534073       2.45194e+06  -4     0.0168606       62.7174     0.0255302
# 164452       3.51681e+06  -1    0.00279626       63.8857    0.00759174
# 25242.3      3.6591e+06   -1    0.00105953       63.9742    0.00121795
# 8100.64      3.62402e+06  -1   0.000507276       63.9883   0.000419997
# 2668.33      3.514e+06    -1   0.000114145       63.9979   0.000155106
# 925.777      3.25567e+06  -1   3.60310e-05       63.9992   6.04651e-05
# 315.04       2.76296e+06  -1   1.73620e-05       63.9999   1.76218e-05
# 237.399      1.71983e+06  -1   8.13255e-06       64.0000   8.60997e-06
# 220.588      1.09535e+06  -1   2.96749e-06       64.0000   5.66839e-06
# 212.56       798340       -1   2.95748e-07       64.0000   3.72033e-06
# 210.939      573597       -1   5.09206e-08       64.0000   3.22238e-06
# 210.197      511224       -1   1.68031e-08       64.0000   2.97271e-06
# 209.833      478740       -1   7.71750e-09       64.0000   2.84369e-06
# 209.648      461621       -1   3.01116e-09       64.0000   2.77601e-06
# 209.551      452548       -1   6.11960e-10       64.0000   2.74023e-06
# 209.5        447726       -1   5.84078e-12       64.0000   2.72124e-06
# 209.48       445160       -1   1.07860e-12       64.0000   2.71377e-06
# 209.464      444149       -1   4.79388e-13       64.0000   2.70764e-06
# 206.761      443318        0   1.09477e-13       64.0000   1.43047e-06
# 205.87       257922        0   1.89137e-14       64.0000   6.81007e-07
# 205.592      136359        0   2.73701e-15       64.0000   1.84074e-07
# 205.561      49828.1       0   8.07184e-16       64.0000   4.75587e-08
# 205.554      25166.4       0   3.48286e-16       64.0000   1.16465e-09
# 205.553      25042.4      -1   1.60225e-16       64.0000   4.70994e-10
# 205.552      24853.1      -2   6.56923e-17       64.0000   2.10911e-10
# 205.552      24786.5      -3   2.56222e-17       64.0000   1.00021e-10
# 205.552      24764.1      -4       3.41788       64.0000   2.76414e-11
# 205.552      180436       -5       999999.       64.0000   1.18088e-05
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
# nt for parameter 2lpha-matrix diagonal eleme
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 1 is pegged at 999999 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 2 is pegged at 64 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 5 is pegged at 1.18088e-05 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***XSPEC Error:  No variable parameters for fit
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 AllModels.clear()
#       2 mo = Model("tbabs*apec")
# ----> 3 Fit.perform()
#       4 Plot.device = "/xs"
#       5 Plot("data resid")
#
# File /mnt/c/Users/acer/HEASoft/heasoft-6.34/x86_64-pc-linux-gnu-libc2.35/lib/python/xspec/fit.py:533, in FitManager.perform(self)
#     530 """Perform a fit."""
#     532 fitArgs = ["fit"]
# --> 533 _pyXspec.doXspecCmd(fitArgs)
#
# Exception: Error executing command: fit

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              7.363386e+07     using 216 bins.
#
# Test statistic : Chi-Squared              1.107973e+13     using 216 bins.
#  Null hypothesis probability of 0.000000e+00 with 213 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 6.84661e+07  1.98631e+07  -1      0.294516       7.10382      0.462369
# 5.33689e+07  9.76224e+07  -2      0.132566      0.281687      0.211948
# 205.699      4.36825e+07   0       258.198       6.07130     0.0975300
# 205.552      0.259886      0       350.364       9.30860     0.0230734
# 205.547      0.000129888  -1       70.1193       9.47641    0.00955194
# 204.98       0.0958147     2       29.4578       8.79235     0.0274716
# 204.715      3.37438       1       28.3430       8.67213     0.0315543
# 201.521      4.22227       0       23.0388       8.02791     0.0560949
# 200.236      6.9442        0       23.7788       7.74045     0.0698754
# 199.245      3.0924       -1       29.8776       7.27465     0.0857075
# 199.133      2.71007      -2       32.3479       7.38464      0.106694
# 199.124      0.475272     -2       33.3681       7.54205      0.140635
# 199.106      0.6604       -2       34.1995       7.68323      0.183250
# 199.09       0.470631     -2       34.9731       7.81418      0.234675
# 199.077      0.32702      -2       35.6989       7.93653      0.295621
# 199.065      0.232025     -2       36.3809       8.05102      0.366799
# 199.056      0.168826     -2       37.0222       8.15829      0.448831
# 199.047      0.125982     -2       37.6256       8.25887      0.542230
# 199.04       0.0963389    -2       38.1939       8.35328      0.647387
# 199.034      0.0735172    -2       38.6289       8.42907      0.746050
# 199.03       0.0516253    -2       39.0554       8.50077      0.852331
# 199.026      0.0422642    -2       39.4603       8.56849      0.966498
# 199.022      0.0353578    -2       39.8440       8.63250       1.08838
# 199.019      0.0299093    -2       40.2076       8.69302       1.21770
# 199.016      0.0255284    -2       40.5524       8.75030       1.35416
# 199.014      0.0219542    -2       40.8795       8.80452       1.49738
# 199.011      0.0190003    -2       41.1899       8.85588       1.64696
# 199.009      0.0165308    -2       41.4847       8.90457       1.80247
# 199.001      0.0144457    -3       43.5904       9.18325       3.07592
# 199          0.0344884    -1       43.4157       9.18654       3.09947
# 199          0.0141057    -1       43.3659       9.19059       3.11077
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.5239E-02| -0.0439  -0.9750   0.2179
#  6.2811E+01|  0.7179  -0.1825  -0.6718
#  6.3105E+03|  0.6947   0.1270   0.7080
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.078e+03   5.485e+02   3.074e+03
#    5.485e+02   1.039e+02   5.750e+02
#    3.074e+03   5.750e+02   3.191e+03
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    43.3659      +/-  55.4802
#    2    2   powerlaw   PhoIndex            9.19059      +/-  10.1935
#    3    2   powerlaw   norm                3.11077      +/-  56.4929
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                198.9998     using 216 bins.
#
# Test statistic : Chi-Squared                150.0871     using 216 bins.
#  Null hypothesis probability of 9.9964e-01 with 213 degrees of freedom
#  Model Flux 9.6161e-07 photons (6.7554e-15 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ## Flux
# ### X-ray flux
# - X-ray flux of the best-fitting model ``Powerlaw`` : **6.7554e-15 ergs/cm^2/s**.

# %%
Flux_pow = 6.7554e-15 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END)
print(f"Powerlaw : F_x-ray = {Flux_pow} ergs/cm^2/s")
# Out:
# X-ray flux :
# Powerlaw : F_x-ray = 6.7554e-15 ergs/cm^2/s

# %% [markdown]
# ### Optical flux

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)

G = 19.7505

F = F_optical(G)

print(color.BOLD+"Optical flux : "+color.END+f"F_optical = {F} ergs/cm^2/s")
# Out:
# Optical flux : F_optical = 1.3212630781247998e-13 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray Flux / Optical Flux ratio : "+color.END)
print(f"Powerlaw : F_x-ray/F_optical = {Flux_pow/F}")
# Out:
# X-ray Flux / Optical Flux ratio :
# Powerlaw : F_x-ray/F_optical = 0.05112834916712869

# %% [markdown]
# ## Luminosity

# %%
"""GAIA"""

P_mas = 0.1954
d_kpc = 1/P_mas # Distance en kpc
d_cm = d_kpc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
Luminosity_pow = 4*np.pi*Flux_pow*(d_cm)**2 # erg/s

print(color.BOLD+"(GAIA)"+color.END)
print(f"Distance : d = {d_cm} cm")
print(color.BOLD+"Luminosity :"+color.END)
print(f"Powerlaw : L_x-ray = {Luminosity_pow} erg/s")

"""Alert file"""
Fx = 3.8*10**(-12)
Lx = 4*np.pi*Fx*(d_cm)**2 # erg/s
print(f"Alert file : L_x = {Lx} erg/s")
# Out:
# (GAIA)
# Distance : d = 1.5791709314227227e+22 cm
# Luminosity :
# Powerlaw : L_x-ray = 2.11699199485741e+31 erg/s
# Alert file : L_x = 1.1908354176596735e+34 erg/s
