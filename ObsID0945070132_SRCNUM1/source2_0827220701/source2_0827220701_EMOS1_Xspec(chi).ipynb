# %% [markdown]
# # ObsID : 0827220701, SRCNUM : 1, Instru : EMOS1
#
# Second previous observation of the source **0945070132 - 1**.

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=53.383375%20-27.15480555555556&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``GAIA``
#
# - Designation : Gaia DR3 5084568549147089792
# - RA : 03h 33m 31.933s
# - DEC : -27° 09' 16.53"
# - Parallax : 0.1954 mas
# - G : 19.7505
# - BP-RP = 0.8773

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: Chi-Squared
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# The expected reduce Chi-squared value of a perfect fit is **≈ 1** with: ``reduce Chi-squared = Chi-squared/(n_bins-n_parameters)``

# %% [markdown]
# ## Load files

# %%
AllData.clear()
spec = Spectrum(glob.glob("P*M1*SRSPEC0001.FTZ")[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# Warning: RMF FILTER keyword (Medium) is not consistent with that in spectrum (Thin1)
#
# 1 spectrum  in use
#
# Spectral Data File: P0827220701M1S001SRSPEC0001.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.899e-01 +/- 2.530e-03 (95.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-92
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 3.115e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0827220701M1S001BGSPEC0001.FTZ
#   Background Exposure Time: 3.115e+04 sec
#  Using Response (RMF) File            m1_e13_im_pall_o.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0827220701M1S001SRCARF0001.FTZ

# %%
print(f"Number of counts = {1.899e-01*3.115e+04} cts")
# Out:
# Number of counts = 5915.385 cts

# %% [markdown]
# The number of counts exceeds 100 cts, indicating that the chi-squared test should be a good choice for a goodness-of-fit statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (92) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('*_Spectrum.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 855.5, 652.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
plt.show()
nH_bbody = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              5.998537e+11     using 91 bins.
#
# Test statistic : Chi-Squared              5.998537e+11     using 91 bins.
#  Null hypothesis probability of 0.000000e+00 with 88 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
#
-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ### Bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.051680e+10     using 91 bins.
#
# Test statistic : Chi-Squared              1.051680e+10     using 91 bins.
#  Null hypothesis probability of 0.000000e+00 with 88 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3519.54      161.692      -3     0.0275864       17.8318   0.000127508
# 1839.8       2.30445e+06  -4     0.0133184       5.65513   0.000236770
# 1771.07      1.69762e+06  -5    0.00466979       1.31766   0.000361575
# 1276.67      1.24616e+06  -6   0.000147885       2.92516   0.000299951
# 494.505      1.46259e+06  -7   1.39144e-05       3.06538   0.000422456
# 487.559      610281       -2   2.25711e-06       3.00889   0.000424652
# 483.523      611308       -2   8.16497e-07       2.99735   0.000425834
# 482.588      606636       -2   9.92058e-08       2.99456   0.000426109
# 482.35       605583       -2   9.63510e-09       2.99381   0.000426180
# 482.295      605321       -2   4.03834e-09       2.99365   0.000426196
# 419.07       605258       -1   1.69871e-09       2.82867   0.000446229
# 391.033      523202       -1   6.35487e-10       2.74612   0.000456317
# 377.443      485815       -1   1.29055e-10       2.70197   0.000461572
# 370.428      467874       -1   5.64935e-12       2.67793   0.000464395
# 366.352      458692       -1   1.84198e-12       2.66524   0.000466051
# 362.181      452903       -1   9.01707e-13       2.64939   0.000467808
# 316.511      447713        0   4.42898e-13       2.60396   0.000487492
# 290.788      343463        0   3.13930e-14       2.53526   0.000501169
# 271.46       288562        0   1.10269e-14       2.46727   0.000513021
# 242.419      247560       -1   2.81252e-15       2.26119   0.000535583
# 208.038      218222       -2   8.09421e-16       2.07761   0.000575659
# 195.292      106546       -3   2.42130e-16       1.92074   0.000612893
# 00613213     22791.7       0   2.81477e-17       1.92070   0.0
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.81477e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 194.993      31240.1       0   2.81477e-17       1.91601   0.000615715
# 194.618      18092.7      -1   2.81477e-17       1.89184   0.000621180
# 194.534      4459.19      -2   2.81477e-17       1.87621   0.000624108
# 194.527      415.126      -3   2.81477e-17       1.87171   0.000624850
# 194.527      25.8695      -4   2.81477e-17       1.87052   0.000625036
# 194.527      1.0098       -5   2.81477e-17       1.87026   0.000625075
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.81477e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 194.527      0.215141     -3   2.81477e-17       1.87022   0.000625082
# ==============================
#  Variances and Principal Axes
#                  2        3
#  7.0989E-11|  0.0002   1.0000
#  4.0637E-03|  1.0000  -0.0002
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    4.064e-03  -6.219e-07
#   -6.219e-07   1.662e-10
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.81477E-17  +/-  -1.00000
#    2    2   bremss     kT         keV      1.87022      +/-  6.37472E-02
#    3    2   bremss     norm                6.25082E-04  +/-  1.28905E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                194.5268     using 91 bins.
#
# Test statistic : Chi-Squared                194.5268     using 91 bins.
#  Null hypothesis probability of 5.0961e-10 with 88 degrees of freedom
#  Model Flux 0.0014856 photons (1.8023e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              8.701788e+08     using 91 bins.
#
# Test statistic : Chi-Squared              8.701788e+08     using 91 bins.
#  Null hypothesis probability of 0.000000e+00 with 88 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 2322.81      145.967      -3      0.936745      0.925716    0.00184769
# 2263.41      8869.53      -4      0.919716      0.852593    0.00191343
# 2198.65      14225.6      -5      0.899807      0.757513    0.00209384
# 2169.93      12176.9      -6      0.864606      0.708840    0.00215739
# 2163.7       2268.7       -7      0.848485      0.685087    0.00218114
# 2162.97      284.178      -8      0.836630      0.684869    0.00213454
#        -9      0.835584      0.681488    0.00214153
# 2161.85      222.306     -10      0.838950      0.667066    0.00220636
# 2161.75      383.879     -11      0.833135      0.670403    0.00217125
# 2161.73      68.569      -12      0.834057      0.668151    0.00218339
# 2161.73      11.9496     -13      0.833171      0.668757    0.00217754
# 2161.73      2.0632      -14      0.833352      0.668401    0.00217957
# 2161.73      0.364375    -15      0.833215      0.668507    0.00217862
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.3432E-09| -0.0042   0.0036   1.0000
#  1.6011E-04| -0.6412  -0.7674   0.0001
#  3.3644E-04|  0.7673  -0.6412   0.0055
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.639e-04  -8.676e-05   1.419e-06
#   -8.676e-05   2.326e-04  -1.196e-06
#    1.419e-06  -1.196e-06   1.158e-08
# ------------------------------------
#
# ====================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.833215     +/-  1.62460E-02
#    2    2   apec       kT         keV      0.668507     +/-  1.52514E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.17862E-03  +/-  1.07632E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                2161.729     using 91 bins.
#
# Test statistic : Chi-Squared                2161.729     using 91 bins.
#  Null hypothesis probability of 0.000e+00 with 88 degrees of freedom
#  Model Flux 0.00039195 photons (7.9283e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.296720e+10     using 91 bins.
#
# Test statistic : Chi-Squared              9.296720e+10     using 91 bins.
#  Null hypothesis probability of 0.000000e+00 with 88 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 4499.6       170.175      -2     0.0405516      0.615227   2.94229e-05
# 3240.79      5.01234e+06  -3   0.000551424       2.14503   9.91814e-05
# 407.743      3.53878e+06  -4     0.0918528       2.58073   0.000432323
# 221.278      744422       -5     0.0445519       2.12845   0.000410766
# 86.2303      342490       -6     0.0145485       2.24164   0.000427740
# 80.9023      84035.6      -7     0.0239149       2.25682   0.000434707
# 80.8947      1498.15      -8     0.0244864       2.25845   0.000435474
# 80.8947      3.2397       -9     0.0244933       2.25847   0.000435486
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.3758E-11| -0.0015  -0.0000   1.0000
#  1.6345E-05|  0.9869  -0.1614   0.0015
#  2.2727E-03|  0.1614   0.9869   0.0003
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.510e-05   3.593e-04   1.265e-07
#    3.593e-04   2.214e-03   6.251e-07
#    1.265e-07   6.251e-07   2.478e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.44933E-02  +/-  8.66624E-03
#    2    2   powerlaw   PhoIndex            2.25847      +/-  4.70530E-02
#    3    2   powerlaw   norm                4.35486E-04  +/-  1.57404E-05
# ________________________________________________________________________
#
#
#      using 91 bins.i-Squared                 80.8947
#
# Test statistic : Chi-Squared                 80.8947     using 91 bins.
#  Null hypothesis probability of 6.9149e-01 with 88 degrees of freedom
#  Model Flux 0.0015436 photons (2.1624e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ### Black body + Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_
#  1.5937E-10| -0.0024  -0.0000  -0.0324  -0.0001   0.9995
#  1.8353E-05|  0.9821   0.0401  -0.0000  -0.1841   0.0023
#  9.0272E-03| -0.1557   0.7232   0.0000  -0.6729  -0.0004
#  1.5058E-02|  0.1062   0.6895  -0.0000   0.7165   0.0003
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    4.062e-04   8.693e-05  -1.910e-08   2.088e-03   1.138e-06
#    8.693e-05   1.188e-02  -1.497e-08   3.046e-03   5.921e-07
#   -1.910e-08  -1.497e-08   1.116e-12  -1.014e-07  -5.904e-11
#    2.088e-03   3.046e-03  -1.014e-07   1.182e-02   5.966e-06
#    1.138e-06   5.921e-07  -5.904e-11   5.966e-06   3.361e-09
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.27999E-02  +/-  2.01540E-02
#    2    2   bbody      kT         keV      0.298361     +/-  0.108996
#    3    2   bbody      norm                6.94718E-07  +/-  1.05648E-06
#    4    3   powerlaw   PhoIndex            2.20001      +/-  0.108709
#    5    3   powerlaw   norm                3.98591E-04  +/-  5.79732E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 80.4528     using 91 bins.
#
# Test statistic : Chi-Squared                 80.4528     using 91 bins.
# probability of 6.4850e-01 with 86 degrees of freedom
#  Model Flux 0.0017233 photons (2.2432e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ### Bremss + Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*(bremss+powerlaw)")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremsspowerlaw = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(bremss<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.624943e+11     using 91 bins.
#
# Test statistic : Chi-Squared              1.624943e+11     using 91 bins.
#  Null hypothesis probability of 0.000000e+00 with 86 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 4197.01      214981       -1      0.427977       1.09999   4.45471e-05       1.09648   6.96596e-05
# 3677.5       1.3108e+06   -2      0.174618       7.34187   4.46781e-06       1.52929   0.000101204
# 1189.18      1.88488e+06  -3     0.0326147       3.61870   0.000317986      0.830643   4.33264e-05
# 984.838      646639       -3    0.00639407       1.49758   0.000335814       1.03989   4.32001e-05
# 295.483      1.37292e+06  -3    0.00137251       1.27070   0.000415900       1.91881   0.000114263
# 105.932      603160       -3   0.000222940       1.23786   0.000292205       1.88936   0.000227824
# 81.5348      126676       -3   9.43004e-05       1.15863   0.000208921       2.05722   0.000292293
# 81.374       29016        -4     0.0126544       1.13460   9.40615e-05       2.19346   0.000372139
# 80.6636      2130.29      -5     0.0123979       1.16874   9.36592e-05       2.17366   0.000370470
# 80.6635      29.4579      -6     0.0126620       1.17464   9.17276e-05       2.17606   0.000371672
# 80.6635      28.8653      -7     0.0126245       1.17371   9.20889e-05       2.17568   0.000371464
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  2.5065E-11| -0.0013   0.0000   0.4279  -0.0000   0.9038
#  2.8387E-09|  0.0023   0.0000  -0.9038  -0.0014   0.4279
#  1.6923E-05|  0.9916   0.0098   0.0028  -0.1292   0.0001
#  4.5652E-02|  0.1294  -0.1166  -0.0009   0.9847   0.0007
#  8.9938E-01| -0.0055  -0.9931   0.0001  -0.1169  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    8.084e-04   4.193e-03  -6.016e-06   6.392e-03   4.111e-06
#    4.193e-03   8.877e-01  -9.885e-05   9.918e-02   3.173e-05
#   -6.016e-06  -9.885e-05   5.403e-08  -5.400e-05  -3.332e-08
#    6.392e-03   9.918e-02  -5.400e-05   5.656e-02   3.394e-05
#    4.111e-06   3.173e-05  -3.332e-08   3.394e-05   2.199e-08
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bremss<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.26245E-02  +/-  2.84328E-02
#    2    2   bremss     kT         keV      1.17371      +/-  0.942170
#    3    2   bremss     norm                9.20889E-05  +/-  2.32433E-04
#    4    3   powerlaw   PhoIndex            2.17568      +/-  0.237823
#    5    3   powerlaw   norm                3.71464E-04  +/-  1.48276E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 80.6635     using 91 bins.
#
# Test statistic : Chi-Squared                 80.6635     using 91 bins.
#  Null hypothesis probability of 6.4226e-01 with 86 degrees of freedom
#  Model Flux  0.001708 photons (2.2322e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %% [markdown]
# ## Flux
# ### X-ray flux
# - X-ray flux of the best-fitting model ``Black body + Powerlaw``: **2.2432e-12 ergs/cm^2/s**.

# %%
Flux_bp = 2.2432e-12 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END)
print(f"Black body + Powerlaw : F_x-ray = {Flux_bp} ergs/cm^2/s")
# Out:
# X-ray flux :
# Black body + Powerlaw : F_x-ray = 2.2432e-12 ergs/cm^2/s

# %% [markdown]
# ### Optical flux

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)

G = 19.7505

F = F_optical(G)

print(color.BOLD+"Optical flux : "+color.END+f"F_optical = {F} ergs/cm^2/s")
# Out:
# Optical flux : F_optical = 1.3212630781247998e-13 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray Flux / Optical Flux ratio : "+color.END)
print(f"Black body + Powerlaw : F_x-ray/F_optical = {Flux_bp/F}")
# Out:
# X-ray Flux / Optical Flux ratio :
# Black body + Powerlaw : F_x-ray/F_optical = 16.97769382297171

# %% [markdown]
# ## Luminosity

# %%
"""GAIA"""

P_mas = 0.1954
d_kpc = 1/P_mas # Distance en kpc
d_cm = d_kpc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
Luminosity_bp = 4*np.pi*Flux_bp*(d_cm)**2 # erg/s

print(color.BOLD+"(GAIA)"+color.END)
print(f"Distance : d = {d_cm} cm")
print(color.BOLD+"Luminosity :"+color.END)
print(f"Black body + Powerlaw : L_x-ray = {Luminosity_bp} erg/s")
# Out:
# (GAIA)
# Distance : d = 1.5791709314227227e+22 cm
# Luminosity :
# Black body + Powerlaw : L_x-ray = 7.029689497089945e+33 erg/s
