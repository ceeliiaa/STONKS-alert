# %% [markdown]
# # ObsID : 0945020133, SRCNUM : 3, Instru : EMOS2
# **Simbad :** Seyfert 1 Galaxy (2XMM J033204.0-273726) https://simbad.cds.unistra.fr/simbad/sim-id?Ident=%40645704&Name=2XMM%20J033204.0-273726&submit=submit

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: Chi-Squared
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files

# %%
Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp.fits')[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945020133_SRCNUM3_EMOS2_spectrum_grp.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.408e-03 +/- 7.987e-04 (49.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-5
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.56e+04 sec
#  Using fit statistic: chi
#  Using Background File                MOSbackground_spectrum.fits
#   Background Exposure Time: 1.56e+04 sec
#  Using Response (RMF) File            MOS.rmf for Source 1
#  Using Auxiliary Response (ARF) File  MOS.arf

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 859.5, 661.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
plt.show()
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.287818e+11     using 5 bins.
#
# Test statistic : Chi-Squared              3.287818e+11     using 5 bins.
# +00 with 2 degrees of freedomof 0.000000e
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 31.3811      0.224207      0      0.369557       2.99953   3.05079e-06
# 30.4735      41981.6       0     0.0907012       2.98200   3.04470e-06
# 30.1668      74924.2       0     0.0363521       2.95189   3.05875e-06
# 29.9729      77398.9       0     0.0121816       2.92115   3.07321e-06
# 29.8426      74216.1       0    0.00100366       2.89171   3.08473e-06
# 29.7787      68572.6       0   0.000345775       2.86416   3.09231e-06
# 29.7245      60829.7       0   2.80424e-05       2.83895   3.09516e-06
# 29.6783      53850.9       0   8.76527e-06       2.81569   3.09401e-06
# 29.637       47582.9       0   4.06703e-06       2.79403   3.08948e-06
# 29.5993      42029         0   1.77027e-06       2.77372   3.08213e-06
# 29.5644      37124.7       0   6.44769e-07       2.75450   3.07242e-06
# 29.5316      32789.1       0   9.21377e-08       2.73616   3.06073e-06
# 29.5004      28946.5       0   2.41898e-08       2.71856   3.04737e-06
# 29.4704      25540.6       0   7.45783e-09       2.70156   3.03261e-06
# 29.4413      22516.6       0   3.33292e-09       2.68508   3.01668e-06
# 29.4128      19827.2       0   1.29713e-09       2.66897   2.99975e-06
# 29.3848      17416.6       0   2.91628e-10       2.65322   2.98199e-06
# 29.357       15261.3       0   4.31230e-11       2.63774   2.96354e-06
# 29.3293      13320         0   1.23762e-11       2.62247   2.94452e-06
# 29.3017      11554.3       0   4.77653e-12       2.60739   2.92495e-06
# 29.2737      9970.07       0   9.65986e-13       2.59230   2.90536e-06
# 29.2451      8363.95       0   1.29909e-14       2.57715   2.88573e-06
# 29.2135      6722.77       0   1.62462e-15       2.56066   2.86632e-06
# 28.9152      4407.95       0   7.25480e-16       2.41715   2.66396e-06
# 28.4942      7106.73       0   6.79708e-17       2.24655   2.46504e-06
# 27.9659      35451         0   2.77820e-17       2.07652   2.24429e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at
# 2.20308      6802.49       0   1.05576e-05       4.06830   2.28491e-05
# 2.20168      6364.09       0   3.53416e-06       4.05874   2.28713e-05
# 2.20058      5979.99       0   7.02412e-08       4.04974   2.28919e-05
# 2.19977      5634.53       0   1.67525e-08       4.04251   2.29110e-05
# 2.19903      5312.3        0   3.52171e-09       4.03441   2.29287e-05
# 2.19837      5027.2        0   2.47094e-10       4.02672   2.29453e-05
# 2.19777      4763.73       0   4.43534e-11       4.01946   2.29607e-05
# 2.19725      4519.36       0   1.92322e-11       4.01262   2.29751e-05
# 2.19678      4292.96       0   6.78171e-12       4.00608   2.29885e-05
# 2.19636      4083.5        0   6.06942e-13       3.99998   2.30010e-05
# 2.196        3888.33       0   2.16197e-13       3.99521   2.30126e-05
# 2.19565      3698.83       0   3.05211e-14       3.98903   2.30238e-05
# 2.19534      3533.43       0   7.07165e-15       3.98367   2.30341e-05
# 2.19502      3377.16       0   2.50269e-15       3.97939   2.30465e-05
# 2.19484      3168.05       0   1.00586e-15       3.97578   2.30529e-05
# 2.19459      3074.93       0   3.08037e-18       3.97039   2.30620e-05
# 2.19441      2944.49       0   1.23842e-18       3.96674   2.30690e-05
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.23842e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 2.19295      4258.9        0   1.23842e-18       3.93435   2.31463e-05
# 2.19198      2397.93      -1   1.23842e-18       3.86630   2.32499e-05
# 2.19198      365.343       0   1.23842e-18       3.86769   2.32509e-05
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.23842e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 2.19197      309.681      -3   1.23842e-18       3.86346   2.32634e-05
# ==============================
#  Variances and Principal Axes
#                  2        3
#  1.6188E-11|  0.0000   1.0000
#  8.8779E+00|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    8.878e+00  -5.059e-06
#   -5.059e-06   1.907e-11
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.23842E-18  +/-  -1.00000
#    2    2   bremss     kT         keV      3.86346      +/-  2.97958
#    3    2   bremss     norm                2.32634E-05  +/-  4.36704E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.1920     using 5 bins.
#
# Test statistic : Chi-Squared                  2.1920     using 5 bins.
#  Null hypothesis probability of 3.3421e-01 with 2 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 857.5, 662.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.676558e+09     using 5 bins.
#
# Test statistic : Chi-Squared              1.676558e+09     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 7.52416      0.32004      -1       1.05333      0.953405   0.000139782
# 7.47501      1081.22      -1       1.08480      0.918056   0.000150073
# 7.45398      679.439      -1       1.10867      0.889573   0.000158474
# 7.4446       707.089      -1       1.11880      0.884520   0.000162850
# 7.4409       179.919      -1       1.12652      0.874882   0.000166077
# 7.43874      128.231      -1       1.13203      0.866521   0.000168630
# 7.43849      95.7557      -1       1.13610      0.859827   0.000170630
# 7.43789      85.1756       0       1.13708      0.865079   0.000170422
# 7.43764      40.2687       0       1.13730      0.863281   0.000170519
# 7.43751      31.5549       0       1.13741      0.862018   0.000170674
# 7.43749      49.9844       0       1.13741      0.861897   0.000170690
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.0356E-09| -0.0002   0.0001   1.0000
#  4.7239E-02|  0.9070   0.4211   0.0001
#  8.0439E-01| -0.4211   0.9070  -0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.815e-01  -2.892e-01   8.495e-05
#   -2.892e-01   6.701e-01  -1.664e-04
#    8.495e-05  -1.664e-04   4.540e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.13741      +/-  0.426060
#    2    2   apec       kT         keV      0.861897     +/-  0.818595
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.70690E-04  +/-  2.13063E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  7.4375     using 5 bins.
#
# Test statistic : Chi-Squared                  7.4375     using 5 bins.
#  Null hypothesis probability of 2.4264e-02 with 2 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 866.5, 662.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              8.008108e+10     using 5 bins.
#
# Test statistic : Chi-Squared              8.008108e+10     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 24.3687      1.62169      -1      0.493616       1.47361   7.66880e-06
# 10.3605      191214       -2      0.184999       2.81434   2.01202e-05
# 6.65469      115536       -1     0.0482668       1.58946   2.28560e-05
# 2.8355       123077       -2    0.00464599       1.72014   1.74335e-05
# 2.79704      24897.4      -3    0.00197829       1.62689   1.60993e-05
# 2.74864      13624.9      -4   0.000589324       1.65443   1.62853e-05
# 2.74772      744.638      -1   0.000220184       1.64545   1.62228e-05
# 2.74761      265.431      -1   6.42134e-05       1.64355   1.61970e-05
# 2.7476       109.05       -1   2.77475e-05       1.64264   1.61852e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  7.9789E-12| -0.0001   0.0000   1.0000
#  1.8324E-04|  0.9990  -0.0457   0.0001
#  1.8727E-01|  0.0457   0.9990   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.746e-04   8.548e-03   8.136e-08
#    8.548e-03   1.869e-01   1.202e-06
#    8.136e-08   1.202e-06   1.950e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.77475E-05  +/-  2.39706E-02
#    2    2   powerlaw   PhoIndex            1.64264      +/-  0.432296
#    3    2   powerlaw   norm                1.61852E-05  +/-  4.41596E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.7476     using 5 bins.
#
# Test statistic : Chi-Squared                  2.7476     using 5 bins.
#  Null hypothesis probability of 2.5314e-01 with 2 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 660.5, -0.5)

# %% [markdown]
# ## Flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 6.5715e-05 photons (1.3551e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 1.3551e-13 # ergs/cm^2/s

# %% [markdown]
# ### ESASky
# On ESASky, the pointer for GLADE is slightly off the source, but no other sources seem to correspond to it in any wavelength. https://sky.esa.int/esasky/?target=53.01683333333333%20-27.62344444444444&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
#
# - Stack Catalogue name : 4XMMs J033204.0-2737254XMM J033204.0-273725
# - RA : 03h 32m 04.042s
# - DEC : -27° 37' 25.23"
#
# ``GLADE``
#
# - No : 1 697 6000
# - RA : 3h 32m 04.416s
# - DEC : -27° 37' 39.40"
# - Distance : 7173.0551 Mpc

# %% [markdown]
# ### Luminosity

# %%
"""GLADE"""

d_kpc = 7173055.1 # Distance en kpc
d_cm = d_kpc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
Luminosity = 4*np.pi*Flux*(d_cm)**2 # erg/s

print(color.BOLD+"(GLADE)"+color.END)
print(f"Distance : {d_cm} cm")
print(f"Luminosité : {Luminosity} erg/s")
# Out:
# (GLADE)
# Distance : 2.213389612207e+28 cm
# Luminosité : 8.342513999362726e+44 erg/s
