# %% [markdown]
# # ObsID : 0945020133, SRCNUM : 3, Instru : EMOS1
# **Simbad :** Seyfert 1 Galaxy (2XMM J033204.0-273726) https://simbad.cds.unistra.fr/simbad/sim-id?Ident=%40645704&Name=2XMM%20J033204.0-273726&submit=submit

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: Chi-Squared
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files

# %%
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945020133_SRCNUM3_EMOS1_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  -1.527e-02 +/- 1.535e-03 (-142.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-152
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 1.558e+04 sec
#  Using fit statistic: chi
#  Using Background File                MOSbackground_spectrum.fits
#   Background Exposure Time: 1.558e+04 sec
#  Using Response (RMF) File            MOS.rmf for Source 1
#  Using Auxiliary Response (ARF) File  MOS.arf

# %%
print(f"Number of counts : {1.558e+04*1.527e-02}")
# Out:
# Number of counts : 237.9066

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
spec.ignore("**-0.2 12-**")
# Out:
#      6 channels (1-6) ignored in spectrum #     1
#    141 channels (12,152) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 852.5, 659.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
plt.show()
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared                867917.5     using 5 bins.
#
# Test statistic : Chi-Squared                867917.5     using 5 bins.
#  Null hypothesis probability of 0.0e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 0       3.00000       0.00000      1.0000
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 2.28571      184.571      -3       1.00000       3.00000       0.00000
# ====================
#  Variances and Principal Axes
#                  3
#  4.6127E-06|  1.0000
# --------------------
#
# ============
#   Covariance Matrix
#         1
#    4.613e-06
# ------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  -1.00000
#    2    2   bbody      kT         keV      3.00000      +/-  -1.00000
#    3    2   bbody      norm                0.0          +/-  2.14771E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2857     using 5 bins.
#
# Test statistic : Chi-Squared                  2.2857     using 5 bins.
#  Null hypothesis probability of 3.1891e-01 with 2 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 857.5, 661.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                109707.4     using 5 bins.
#
# Test statistic : Chi-Squared                109707.4     using 5 bins.
#  Null hypothesis probability of 0.0e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 2.28571      74.4181      -3       1.00000       7.00000       0.00000
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 2.28571      74.4181      -3       1.00000       7.00000       0.00000
# ====================
#  Variances and Principal Axes
#                  3
#  3.6561E-05|  1.0000
# --------------------
#
# ============
#   Covariance Matrix
#         1
#    3.656e-05
# ------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  -1.00000
#    2    2   bremss     kT         keV      7.00000      +/-  -1.00000
#    3    2   bremss     norm                0.0          +/-  6.04653E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2857     using 5 bins.
#
# Test statistic : Chi-Squared                  2.2857     using 5 bins.
#  Null hypothesis probability of 3.1891e-01 with 2 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 859.5, 661.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared                21642.99     using 5 bins.
#
# Test statistic : Chi-Squared                21642.99     using 5 bins.
#  Null hypothesis probability of 0.00e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 2.28571      38.5618      -3       1.00000       1.00000       0.00000
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 2.28571      38.5618      -3       1.00000       1.00000       0.00000
# ====================
#  Variances and Principal Axes
#                  5
#  1.8616E-04|  1.0000
# --------------------
#
# ============
#   Covariance Matrix
#         1
#    1.862e-04
# ------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  -1.00000
#    2    2   apec       kT         keV      1.00000      +/-  -1.00000
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                0.0          +/-  1.36442E-02
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2857     using 5 bins.
#
# Test statistic : Chi-Squared                  2.2857     using 5 bins.
#  Null hypothesis probability of 3.1891e-01 with 2 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 660.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                497642.1     using 5 bins.
#
# Test statistic : Chi-Squared                497642.1     using 5 bins.
#  Null hypothesis probability of 0.0e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 2.28571      153.4        -3       1.00000       1.00000       0.00000
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 2.28571      153.4        -3       1.00000       1.00000       0.00000
# ====================
#  Variances and Principal Axes
#                  3
#  8.0479E-06|  1.0000
# --------------------
#
# ============
#   Covariance Matrix
#         1
#    8.048e-06
# ------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  -1.00000
#    2    2   powerlaw   PhoIndex            1.00000      +/-  -1.00000
#    3    2   powerlaw   norm                0.0          +/-  2.83688E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2857     using 5 bins.
#
# Test statistic : Chi-Squared                  2.2857     using 5 bins.
#  Null hypothesis probability of 3.1891e-01 with 2 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 659.5, -0.5)

# %% [markdown]
# ### ESASky
#
# On ESASky, the pointer for GLADE is slightly off the source, but no other sources seem to correspond to it in any wavelength. https://sky.esa.int/esasky/?target=53.01683333333333%20-27.62344444444444&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
#
# - Stack Catalogue name : 4XMMs J033204.0-2737254XMM J033204.0-273725
# - RA : 03h 32m 04.042s
# - DEC : -27° 37' 25.23"
#
# ``GLADE``
#
# - No : 1 697 6000
# - RA : 3h 32m 04.416s
# - DEC : -27° 37' 39.40"
# - Distance : 7173.0551 Mpc

# %% [markdown]
# ## Flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux         0 photons (0 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 0 # ergs/cm^2/s

# %% [markdown]
# ### Luminosity

# %%
### """GLADE"""

d_kpc = 7173055.1 # Distance en kpc
d_cm = d_kpc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
Luminosity = 4*np.pi*Flux*(d_cm)**2 # erg/s

print(color.BOLD+"(GLADE)"+color.END)
print(f"Distance : {d_cm} cm")
print(f"Luminosité : {Luminosity} erg/s")
# Out:
# (GLADE)
# Distance : 2.213389612207e+28 cm
# Luminosité : 0.0 erg/s
