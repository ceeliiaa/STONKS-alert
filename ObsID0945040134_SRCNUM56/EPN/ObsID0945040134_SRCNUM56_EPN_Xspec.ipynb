# %% [markdown]
# # ObsID : 0945040134, SRCNUM : 56, Instru : EPN

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: Chi-Squared
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files
# Spectrum, Background, Response, Auxiliary response.

# %%
Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp.fits')[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945040134_SRCNUM56_EPN_spectrum_grp.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  5.254e-03 +/- 2.183e-03 (25.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-9
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.146e+04 sec
#  Using fit statistic: chi
#  Using Background File                ObsID0945040134_SRCNUM56_EPN_background_spectrum.fits
#   Background Exposure Time: 1.146e+04 sec
#  Using Response (RMF) File            ObsID0945040134_SRCNUM56_EPN.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945040134_SRCNUM56_EPN.arf

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 861.5, 662.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.611439e+11     using 9 bins.
#
# Test statistic : Chi-Squared              1.611439e+11     using 9 bins.
# +00 with 6 degrees of freedomof 0.000000e
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.36538      0.0925626    -1      0.317619       3.39911   6.41711e-06
# 7.12191      56045.1      -1      0.143987       3.52927   7.28772e-06
# 7.06558      40071        -2     0.0464927       4.22451   1.08675e-05
# 6.945        27839.2      -2     0.0187640       4.62301   1.44179e-05
# 6.9161       13284.7      -2    0.00742504       4.96488   1.75405e-05
# 6.91075      8472.04      -2    0.00183845       5.29332   2.06437e-05
# 6.89976      6735.16      -1   0.000552008       5.31458   2.11314e-05
# 6.88989      5304.34       0   0.000212584       5.29819   2.13187e-05
# 6.88736      3631.42       0   4.70734e-05       5.29352   2.13886e-05
# 6.88663      3064.16       0   5.93803e-06       5.29275   2.14191e-05
# 6.88641      2876.13       0   8.06329e-07       5.29323   2.14368e-05
# 6.88635      2812.41       0   1.65367e-07       5.29412   2.14502e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.7721E-11| -0.0000  -0.0000   1.0000
#  8.7140E-01|  0.9991   0.0434   0.0000
#  1.3017E+02| -0.0434   0.9991   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.114e+00  -5.601e+00  -5.292e-05
#   -5.601e+00   1.299e+02   1.294e-03
#   -5.292e-05   1.294e-03   1.297e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.65367E-07  +/-  1.05569
#    2    2   bbody      kT         keV      5.29412      +/-  11.3984
#    3    2   bbody      norm                2.14502E-05  +/-  1.13879E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  6.8863     using 9 bins.
#
# Test statistic : Chi-Squared                  6.8863     using 9 bins.
#  Null hypothesis probability of 3.3149e-01 with 6 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bbody.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 861.5, 661.5, -0.5)

# %% [markdown]
# ### bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              8.619361e+09     using 9 bins.
#
# Test statistic : Chi-Squared              8.619361e+09     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.8962       0.068683      0       1.03550       11.4333   2.50915e-05
# 7.67862      3432.72       0      0.960143       29.4057   2.50931e-05
# 7.55302      8764.83      -1      0.637435       197.294   3.58218e-05
# 7.38056      4292.15      -1      0.869326       196.194   4.21803e-05
# 7.37214      1616.49      -1      0.932238       198.802   4.65263e-05
# 7.36557      1830.13       0      0.950789       199.038   4.63159e-05
# 7.36327      1205.5        0      0.961598       199.178   4.62424e-05
# 7.36238      905.101       0      0.968044       199.274   4.62339e-05
# 7.36201      765.99        0      0.972073       199.348   4.62523e-05
# 7.36188      704.499       0      0.974726       199.356   4.62800e-05
# 7.36184      684.054       0      0.976573       199.360   4.63084e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.1214E-10| -0.0000  -0.0000   1.0000
#  1.1031E+00|  1.0000   0.0002   0.0000
#  4.7448E+07| -0.0002   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.548e+00  -1.077e+04  -6.792e-04
#   -1.077e+04   4.745e+07   3.075e+00
#   -6.792e-04   3.075e+00   2.000e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#         1   TBabs      nH         10^22    0.976573     +/-  1.88352
#    2    2   bremss     kT         keV      199.360      +/-  6888.23
#    3    2   bremss     norm                4.63084E-05  +/-  4.47193E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  7.3618     using 9 bins.
#
# Test statistic : Chi-Squared                  7.3618     using 9 bins.
#  Null hypothesis probability of 2.8868e-01 with 6 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 859.5, 662.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.166767e+09     using 9 bins.
#
# Test statistic : Chi-Squared              2.166767e+09     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 10.6235      0.67949      -1       1.04828       2.17731   3.45920e-05
# 8.91269      10441.1      -1      0.430711       9.30372   3.96893e-05
# 8.59094      4175.23      -1      0.316753       56.8453   5.77066e-05
# 7.66946      455.675      -1      0.641101       53.8341   7.45462e-05
# 7.51559      1070.71      -1      0.834671       63.5169   9.61955e-05
# 7.48029      1614.23       0      0.883320       63.8424   9.61083e-05
# 7.46723      971.248       0      0.916057       63.9864   9.65416e-05
# 7.462        710.285       0      0.938561       63.9950   9.71531e-05
# 7.45967      629.401       0      0.954682       63.9999   9.77750e-05
# 7.4587       620.174       0      0.966643       63.9999   9.83453e-05
# 7.4584       641.109       0      0.975790       64.0000   9.88421e-05
# 7.45668      671.983       0      0.980230       64.0000   9.86529e-05
# 7.45536      584.972       0      0.984154       64.0000   9.84918e-05
# 7.45436      510.133       0      0.987623       64.0000   9.83551e-05
# 7.45358      445.757       0      0.990692       64.0000   9.82393e-05
# 7.45298      390.383       0      0.993411       64.0000   9.81416e-05
# 7.45252      342.757       0      0.995822       64.0000   9.80597e-05
# 7.45216      301.802       0      0.997965       64.0000   9.79912e-05
# 7.45188      266.595       0      0.999871       64.0000   9.79344e-05
# 7.45166      236.34        0       1.00157       64.0000   9.78875e-05
# 7.45149      210.354       0       1.00309       64.0000   9.78493e-05
# 7.45135      188.049       0       1.00445       64.0000   9.78186e-05
# 7.45124      168.917       0       1.00568       64.0000   9.77941e-05
# 7.45115      152.521       0       1.00678       64.0000   9.77751e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.4334E-09| -0.0000  -0.0000   1.0000
#  1.1474E+00|  1.0000   0.0006   0.0000
#  6.7185E+06| -0.0006   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.799e+00  -4.221e+03  -6.248e-04
#   -4.221e+03   6.719e+06   1.062e+00
#   -6.248e-04   1.062e+00   1.709e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00678      +/-  1.94909
#    2    2   apec       kT         keV      64.0000      +/-  2592.01
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                9.77751E-05  +/-  4.13447E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  7.4511     using 9 bins.
#
# Test statistic : Chi-Squared                  7.4511     using 9 bins.
#  Null hypothesis probability of 2.8113e-01 with 6 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 865.5, 662.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.567954e+10     using 9 bins.
#
# Test statistic : Chi-Squared              4.567954e+10     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 6.60638      0.132569     -2      0.392033     0.0250449   3.66515e-06
# 6.5475       45104.8      -1      0.143353     0.0115702   3.23786e-06
# 6.51634      13459        -2      0.228088    -0.0183066   3.16239e-06
# 6.51561      2385.66      -3      0.122249     -0.120012   2.65710e-06
# 6.51139      11537.1      -4      0.196907    -0.0871118   2.86057e-06
# 6.51086      1347.51      -2      0.137184     -0.120901   2.69836e-06
# 6.51003      457.141      -3      0.182006     -0.101323   2.80150e-06
# 6.50974      298.469      -2      0.145603     -0.121277   2.70487e-06
# 6.50951      31.4774      -3      0.173323     -0.108835   2.76884e-06
# 6.5095       128.042      -3      0.146177     -0.126674   2.68592e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0192E-12| -0.0000  -0.0000   1.0000
#  2.9059E-01|  0.7470  -0.6649  -0.0000
#  2.3040E+00|  0.6649   0.7470   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.181e+00   9.999e-01   4.427e-06
#    9.999e-01   1.414e+00   5.776e-06
#    4.427e-06   5.776e-06   2.486e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.146177     +/-  1.08654
#    2    2   powerlaw   PhoIndex            -0.126674    +/-  1.18912
#    3    2   powerlaw   norm                2.68592E-06  +/-  4.98608E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  6.5095     using 9 bins.
#
# Test statistic : Chi-Squared                  6.5095     using 9 bins.
#  Null hypothesis probability of 3.6859e-01 with 6 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 861.5, 665.5, -0.5)

# %% [markdown]
# ## Flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.6883e-05 photons (3.9552e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 3.9552e-13 # ergs/cm^2/s

# %% [markdown]
# ### ESASky
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J033651.5-2819524
# - IAU name : XMM J033651.5-281952
# - RA : 03h 36m 51.547s
# - DEC : -28° 19' 52.59"

# %% [markdown]
# ### Luminosité
# Aucune distance  n'est diponible sur ESASky.
