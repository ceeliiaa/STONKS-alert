# %% [markdown]
# # ObsID : 0945040138, SRCNUM : 14, Instru : EPN
# Not on Simbad

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=53.822291666666665%20-27.52513888888889&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J033517.2-273130
# - IAU name : 4XMM J033517.2-273130
# - RA : 03h 35m 17.272s
# - DEC : -27° 31' 30.54"

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files
# Spectrum, Background, Response, Auxiliary response.

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945040138_SRCNUM14_EPN_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  6.960e-03 +/- 1.449e-03 (59.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-52
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 5941 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0945040138_SRCNUM14_EPN_background_spectrum.fits
#   Background Exposure Time: 5941 sec
#  Using Response (RMF) File            ObsID0945040138_SRCNUM14_EPN.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945040138_SRCNUM14_EPN.arf

# %%
n_cts = 6.960e-03*5941

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 41.34936
#
# The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
spec.ignore("**-0.2 12-**")
# Out:
#      7 channels (1-7) ignored in spectrum #     1
#     41 channels (12,52) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 661.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic                3543.228     using 4 bins.
#
# Test statistic : Chi-Squared                762117.1     using 4 bins.
#  Null hypothesis probability of 0.0e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 5.87229      850.08       -3      0.352772       198.817      0.490927
# 5.83848      0.00375718    2     0.0307263       197.617      0.691499
# 4.01378      0.0522115     1   0.000721055       60.6784       1.38281
# 3.99478      1.1918        0    0.00288675       60.8447       1.37146
# 3.95811      0.915198      0     0.0140438       60.7006       1.38093
# 3.93135      0.265049     -1     0.0714264       56.0003       1.70247
# 3.92717      0.0153701    -1     0.0448936       57.6339       1.55506
# 3.92614      0.103431     -1     0.0569891       56.9944       1.60493
# 3.9259       0.0267456    -1     0.0502926       57.3565       1.57021
# 3.92584      0.0208076    -1     0.0535624       57.1690       1.58414
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3545E-02|  0.9956   0.0076  -0.0933
#  4.4240E+04|  0.0936  -0.0821   0.9922
#  1.5040E+11|  0.0001   0.9966   0.0825
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.252e+03   1.136e+07   9.442e+05
#    1.136e+07   1.494e+11   1.236e+10
#    9.442e+05   1.236e+10   1.023e+09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.35624E-02  +/-  35.3810
#    2    2   bbody      kT         keV      57.1690      +/-  3.86499E+05
#    3    2   bbody      norm                1.58414      +/-  3.19786E+04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  3.9258     using 4 bins.
#
# Test statistic : Chi-Squared                  3.9070     using 4 bins.
#  Null hypothesis probability of 4.8085e-02 with 1 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 855.5, 656.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                2504.901     using 4 bins.
#
# Test statistic : Chi-Squared                384561.3     using 4 bins.
#  Null hypothesis probability of 0.0e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 1457.57      632.915      -3      0.375571       3.32376      0.104274
# 699.527      2808.9       -4      0.171895       194.104     0.0324102
# 549.147      3918.46      -4     0.0133171       199.045    0.00399774
# 105.038      24264.7      -3    0.00459068       199.261   0.000761910
# 12.3899      26714.5      -3     0.0717172       199.328   0.000374136
# 4.38098      7032.36      -4      0.946463       15.0688    0.00144709
# 3.89245      92.8038      -5      0.392436       6.93314   0.000462022
# 3.78254      180.293      -5      0.172061       198.643   0.000184799
# 3.74095      447.086      -2      0.134724       198.817   0.000158187
# 3.74024      29.8883       0      0.136129       198.790   0.000158378
# 3.73995      11.3735       0      0.137137       198.722   0.000159019
# 3.73971      29.5721       0      0.137948       198.626   0.000159856
# 3.73948      37.1536       0      0.138657       198.504   0.000160770
# 3.73926      39.8065       0      0.139309       198.356   0.000161707
# 3.73904      40.133        0      0.139926       198.178   0.000162640
# 3.73883      39.3606       0      0.140519       197.961   0.000163556
# 3.73826      38.0539      -1      0.148232       188.858   0.000169425
# 3.73731      100.031       0      0.148025       185.145   0.000169858
# 3.73677      65.8789       0      0.147913       180.974   0.000170146
# 3.73658      33.597        0      0.147889       177.630   0.000170296
# 3.73654      10.4352       0      0.147929       175.898   0.000170347
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.8394E-08| -0.0016  -0.0000   1.0000
#  1.1098E+02|  1.0000  -0.0000   0.0016
#  6.5033E+11|  0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.383e+02   1.459e+07   5.541e+00
#    1.459e+07   6.503e+11   2.392e+05
#    5.541e+00   2.392e+05   8.825e-02
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.147929     +/-  20.9350
#    2    2   bremss     kT         keV      175.898      +/-  8.06433E+05
#    3    2   bremss     norm                1.70347E-04  +/-  0.297073
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  3.7365     using 4 bins.
#
# Test statistic : Chi-Squared                  3.7306     using 4 bins.
#  Null hypothesis probability of 5.3425e-02 with 1 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 660.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic                1930.669     using 4 bins.
#
# Test statistic : Chi-Squared                230227.9     using 4 bins.
#  Null hypothesis probability of 0.0e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 5.88049      826.569      -3       206.645     0.0366532       99.2299
# 5.88049      5.20464e-48  -4       58.0053     0.0164583       39.1281
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.0000E+18| -0.0001   1.0000   0.0000
#  3.6987E+108|  1.0000   0.0001  -0.0007
#  2.5317E+115| -0.0007   0.0000  -1.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#   1.752e+109 -5.735e+106  1.871e+112
#  -5.735e+106  2.412e+104 -7.814e+109
#   1.871e+112 -7.814e+109  2.532e+115
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    58.0053      +/-  4.18603E+54
#    2    2   apec       kT         keV      1.64583E-02  +/-  1.55314E+52
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                39.1281      +/-  5.03159E+57
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  5.8805     using 4 bins.
#
# Test statistic : Chi-Squared                  2.3712     using 4 bins.
#  Null hypothesis probability of 1.2359e-01 with 1 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 851.5, 652.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                4503.694     using 4 bins.
#
# Test statistic : Chi-Squared              1.223918e+06     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 5.88049      1111.5       -1       118.647       5.69677      0.380198
# 5.58464      8.13587e-06  -2       54.6499       8.24859       8660.21
# 4.22747      0.0641496     0       44.8923       7.67440       15455.9
# 4.22605      0.0185796     0       44.7650       7.67090       15545.8
# 4.22484      0.00340899   -1       44.2451       7.69142       15319.8
# 4.20426      0.0019122    -2       38.9456       7.93631       12468.7
# 4.20101      0.0219573    -2       28.5889       8.55953       6985.88
# 4.02162      0.209815     -1       27.8681       8.84339       5882.27
# 4.002        0.00568904   -1       26.9910       8.99082       5696.58
# 3.99396      0.00838371   -1       26.3185       9.08352       5539.99
# 3.98682      0.0319164    -1       25.8278       9.17141       5352.00
# 3.98111      0.0342308    -1       25.4468       9.24658       5196.99
# 3.97708      0.033053     -1       25.1455       9.30871       5075.63
# 3.97422      0.0319024    -1       24.9056       9.35997       4979.87
# 3.9721       0.0308039    -1       24.7136       9.40251       4903.90
# 3.97048      0.0296623    -1       24.5587       9.43817       4843.82
# 3.96921      0.0284772    -1       24.4329       9.46837       4796.85
# 3.9682       0.0272871    -1       24.3302       9.49425       4760.87
# 3.96577      0.0261322     0       24.3580       9.49726       4709.00
# 3.96516      0.0148718     0       24.3663       9.49927       4683.46
# 3.96501      0.00997327    0       24.3661       9.49966       4669.41
# 3.96495      0.00831402    0       24.3630       9.49984       4659.28
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  7.0858E-01| -0.3020  -0.9533   0.0002
#  7.3104E+04|  0.9533  -0.3020  -0.0004
#  3.7647E+13|  0.0004   0.0001   1.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.066e+06   1.629e+06   1.623e+10
#    1.629e+06   3.955e+05   3.826e+09
#    1.623e+10   3.826e+09   3.765e+13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    24.3630      +/-  2658.25
#    2    2   powerlaw   PhoIndex            9.49984      +/-  628.871
#    3    2   powerlaw   norm                4659.28      +/-  6.13572E+06
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  3.9650     using 4 bins.
#
# Test statistic : Chi-Squared                  3.9448     using 4 bins.
#  Null hypothesis probability of 4.7016e-02 with 1 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 860.5, 660.5, -0.5)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 53.8219681°
# - DEC = -27.5251507°
#
# 53.82 -27.53
#
# **Column density :** nH = 1*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 5.356239805345745e+20
#
# bremss
# (tbabs) : 1.4792889820618125e+21
#
# apec
# (tbabs) : 5.8005255162548565e+23
#
# powerlaw
# (tbabs) : 2.4363000327016072e+23

# %% [markdown]
# ## Flux
# ### X-ray flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 0.0055903 photons (3.1225e-11 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 3.1225e-11 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END+f"F_X = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux : F_X = 3.1225e-11 ergs/cm^2/s

# %% [markdown]
# ### Optical flux
# No GAIA information, so we use the lower limit of 20.7 mag.

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)
    
G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
print(f"F_x-ray = {Flux/F}*F_optical")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 566.6477230324028
# F_x-ray = 566.6477230324028*F_optical

# %% [markdown]
# ## Luminosity
# No distance or parallax is available on ESASky.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s

print(color.BOLD+"For a star in the milky way? with d=[1 pc - 30 kpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s


print(color.BOLD+"For a galaxy? with d=[1 Mpc - 10 Gpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")
# Out:
# For a star in the milky way? with d=[1 pc - 30 kpc] :
# Luminosity : [3.736110496154486e+27, 3.736110496154485e+33] erg/s
# For a galaxy? with d=[1 Mpc - 10 Gpc] :
# Luminosity : [3.7361104961544855e+39, 3.7361104961544856e+47] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L = 4*np.pi*Flux*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L,D_pc)
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
