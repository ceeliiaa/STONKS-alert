# %% [markdown]
# # ObsID : 0945040138, SRCNUM : 14, Instru : EPN
# Not on Simbad.

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=53.822291666666665%20-27.52513888888889&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J033517.2-273130
# - IAU name : 4XMM J033517.2-273130
# - RA : 03h 35m 17.272s
# - DEC : -27° 31' 30.54"

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files
# Spectrum, Background, Response, Auxiliary response.

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945040138_SRCNUM14_EPN_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  6.960e-03 +/- 1.449e-03 (59.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-52
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 5941 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0945040138_SRCNUM14_EPN_background_spectrum.fits
#   Background Exposure Time: 5941 sec
#  Using Response (RMF) File            ObsID0945040138_SRCNUM14_EPN.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945040138_SRCNUM14_EPN.arf

# %%
n_cts = 6.960e-03*5941

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 41.34936
#
# The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
#      7 channels (1-7) ignored in spectrum #     1
#      1 channels (52) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 661.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              4.301838e+06     using 44 bins.
#
# Test statistic : Chi-Squared              4.940226e+11     using 44 bins.
#  Null hypothesis probability of 0.000000e+00 with 41 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 86.8076      869711       -3      0.363782       193.767      0.495824
# 86.1229      0.672861     -3      0.164993       198.925      0.480056
# 84.8229      1.36561      -3     0.0399738       199.361      0.621010
# 84.4465      1.68175       0    0.00496973       199.363      0.616184
# 84.3998      1.91716       0   0.000753059       199.363      0.612717
# 84.396       1.9433        0   0.000229375       199.363      0.609683
# 84.3932      1.94154       1   1.45544e-06       199.363      0.609809
# 84.3931      1.94361       1   5.65695e-07       199.363      0.609935
# 84.393       1.94386       1   1.20869e-07       199.363      0.610059
# 84.3929      1.9441        1   9.67439e-09       199.363      0.610182
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.4063E-02| -0.0989  -0.0091   0.9951
#  1.2929E+00|  0.9951  -0.0009   0.0989
#  2.0961E+08| -0.0001   1.0000   0.0091
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.837e+00  -1.080e+04  -9.854e+01
#   -1.080e+04   2.096e+08   1.915e+06
#   -9.854e+01   1.915e+06   1.749e+04
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.67439E-09  +/-  1.35547
#    2    2   bbody      kT         keV      199.363      +/-  1.44772E+04
#    3    2   bbody      norm                0.610182     +/-  132.250
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 84.3929     using 44 bins.
#
# Test statistic : Chi-Squared                 49.5617     using 44 bins.
#  Null hypothesis probability of 1.6873e-01 with 41 degrees of freedom
#  Model Flux 4.3745e-05 photons (5.5944e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 659.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model (Second best fit)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.029848e+06     using 44 bins.
#
# Test statistic : Chi-Squared              2.348133e+10     using 44 bins.
#  Null hypothesis probability of 0.000000e+00 with 41 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 564017       196340       -3      0.170194       199.338      0.459155
# 135451       257027       -1     0.0752904       199.357     0.0916194
# 51994        253613       -1     0.0325499       199.361     0.0314450
# 4630.16      279704       -1    0.00386981       199.363    0.00270284
# 1414.24      303351       -1   0.000582175       199.363   0.000901582
# 510.084      296372       -2   0.000181745       199.363   0.000378225
# 93.3665      274617       -3   1.80964e-05       199.363   9.37096e-05
# 61.6497      170993       -4     0.0231521       79.4967   4.54251e-05
# 55.4183      111238       -5    0.00144362       198.994   3.02191e-05
# 55.01        25292.7      -2     0.0229874       59.1543   2.60676e-05
# 54.9663      4122.02      -2     0.0150946       38.7117   2.25745e-05
# 54.9489      3997.9       -1     0.0223039       32.9130   2.21115e-05
# 54.9307      1227.04      -2     0.0220726       21.4780   2.02079e-05
# 54.9285      2492.53      -3     0.0274693       16.8460   1.96141e-05
# 54.9271      688.035      -1     0.0243147       17.7556   1.95331e-05
# 54.9269      169.708      -2     0.0259437       17.6806   1.96283e-05
# 54.9269      17.525       -2     0.0242087       18.2796   1.96184e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.8407E-11| -0.0001  -0.0000   1.0000
#  3.5676E-03|  1.0000   0.0010   0.0001
# 3.2828E+03| -0.0010   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.654e-03  -3.183e+00  -1.306e-07
#   -3.183e+00   3.283e+03   4.056e-04
#   -1.306e-07   4.056e-04   8.786e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.42087E-02  +/-  8.15704E-02
#    2    2   bremss     kT         keV      18.2796      +/-  57.2954
#    3    2   bremss     norm                1.96184E-05  +/-  9.37315E-06
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 54.9269     using 44 bins.
#
# Test statistic : Chi-Squared                 45.7398     using 44 bins.
#  Null hypothesis probability of 2.8179e-01 with 41 degrees of freedom
#  Model Flux 3.483e-05 photons (1.1895e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 660.5, -0.5)

# %% [markdown]
# ### Apec model (Best fit)

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic                447442.6     using 44 bins.
#
# Test statistic : Chi-Squared              4.331905e+09     using 44 bins.
#  Null hypothesis probability of 0.000000e+00 with 41 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 209127       137452       -3      0.247459       35.2861      0.344821
# 76491.8      112397       -4     0.0479534       49.9053     0.0926622
# 31708.3      143812       -5     0.0177900       58.5733     0.0366541
# 323.999      147679       -6    0.00494753       63.0934   0.000543679
# 114.343      124528       -7   0.000962664       63.8275   0.000230701
# 55.3575      94321.7      -8     0.0484925       31.1641   7.30840e-05
# 54.9953      8258.8       -9    0.00390362       14.9436   4.74131e-05
# 54.6101      5032.57      -1     0.0452290       7.14029   4.77013e-05
# 54.5829      8975.11      -1     0.0206991       11.0498   4.98743e-05
# 54.4757      698.887       0     0.0272730       9.09836   4.96243e-05
# 54.4573      628.686       0     0.0306399       8.68192   4.96363e-05
# 54.453       93.7341       0     0.0325508       8.28774   4.96496e-05
# 54.4516      73.1705      -1     0.0352141       8.17287   5.00297e-05
# 54.4515      111.206      -2     0.0341265       8.25802   4.99445e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.1957E-10| -0.0002  -0.0000   1.0000
#  3.8749E-03|  1.0000   0.0028   0.0002
#  2.1779E+02| -0.0028   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.548e-03  -6.037e-01   4.913e-07
#   -6.037e-01   2.178e+02   8.238e-05
#    4.913e-07   8.238e-05   2.844e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.41265E-02  +/-  7.44853E-02
#    2    2   apec       kT         keV      8.25802      +/-  14.7577
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.99445E-05  +/-  1.68635E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 54.4515     using 44 bins.
#
# Test statistic : Chi-Squared                 46.3227     using 44 bins.
#  Null hypothesis probability of 2.6204e-01 with 41 degrees of freedom
#  Model Flux 3.3622e-05 photons (1.0759e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 857.5, 656.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              2.486590e+06     using 44 bins.
#
# Test statistic : Chi-Squared              1.314847e+11     using 44 bins.
#  Null hypothesis probability of 0.000000e+00 with 41 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 377131       631104       -1      0.372950       7.70756     0.0699277
# 97.8759      1.0266e+06   -2       1355.41       2.11696       65.1616
# 97.5666      0.264721      1       1340.31       2.05733       74.4245
# 96.7815      0.380625      0       1256.89       1.71451       134.955
# 96.1092      1.00893       0       1280.47       1.79217       109.182
# 96.1049      0.022103     -1       1292.60       1.77270       111.733
# 96.076       0.00717975   -2       1375.64       1.59795       137.243
# 95.9776      0.0391412    -3       1749.35      0.746914       256.780
# 95.8412      0.258163     -2       1912.43      0.384349       415.293
# 95.7433      0.195024     -2       2093.12    0.00558498       681.770
# 95.6537      0.188149     -2       2266.39     -0.355724       1102.03
# 95.5759      0.17347      -2       2428.09     -0.690451       1734.40
# 95.5124      0.151804     -2       2576.96     -0.994767       2642.38
# 95.4631      0.127648     -2       2711.99      -1.26631       3881.27
# 95.4264      0.103523     -2       2832.37      -1.50370       5479.83
# 95.4003      0.0809138    -2       2937.60      -1.70669       7422.30
# 95.3826      0.0608572    -2       3027.73      -1.87640       9640.89
# 95.3722      0.0440769    -2       3103.45      -2.00978       12026.7
# 95.3697      0.0436722    -1       3107.88      -2.02016       12422.7
# 95.3689      0.0194794    -1       3113.50      -2.02847       12732.0
# 95.3682      0.0151411    -1       3119.23      -2.03630       13027.4
# 95.3676      0.0142446    -1       3124.89      -2.04393       13321.7
# 95.3669      0.0138953    -1       3130.46      -2.05139       13617.0
# 95.3663      0.0136383    -1       3135.92      -2.05869       13913.4
# 95.3658      0.0134031    -1       3141.29      -2.06584       14210.9
# 95.3652      0.013178     -1       3146.56      -2.07283       14509.5
# 95.3647      0.0129611    -1       3151.73      -2.07968       14809.0
# 95.3642      0.0127513    -1       3156.80      -2.08638       15109.5
# 95.3637      0.0125482    -1       3161.79      -2.09294       15410.7
# 95.3632      0.0123512    -1       3166.68      -2.09935       15712.6
# 95.3628      0.0121599    -1       3171.48      -2.10562       16015.1
# 95.3623      0.011974     -1       3176.20      -2.11175       16318.2
# 95.3619      0.011793     -1       3180.82      -2.11775       16621.8
# 95.3615      0.0116165    -1       3185.36      -2.12362       16925.7
# 95.3611      0.0114443    -1       3189.82      -2.12935       17229.9
# 95.3607      0.0112761    -1       3194.20      -2.13496       17534.3
# 95.3604      0.0111116    -1       3198.49      -2.14044       17838.9
# 95.36        0.0109505    -1       3202.71      -2.14580       18143.6
# 95.3597      0.0107927    -1       3206.84      -2.15104       18448.2
# 95.3593      0.0106379    -1       3210.90      -2.15617       18752.8
# 95.359       0.010486     -1       3214.89      -2.16118       19057.2
# 95.3587      0.0103368    -1       3218.80      -2.16607       19361.4
# 95.3585      0.0101901    -1       3222.64      -2.17086       19665.3
# 95.3582      0.0100458    -1       3226.40      -2.17553       19968.8
# 95.3579      0.00990382   -1       3230.10      -2.18011       20271.9
# 95.3576      0.00976398   -1       3233.73      -2.18458       20574.5
# 95.3574      0.0096262    -1       3237.30      -2.18895       20876.6
# 95.3572      0.0094904    -1       3240.79      -2.19322       21178.0
# 95.3569      0.00935649   -1       3244.23      -2.19739       21478.8
# 95.3567      0.00922439   -1       3247.60      -2.20147       21778.8
# 95.3565      0.00909404   -1       3250.90      -2.20546       22078.0
# 95.3563      0.00896539   -1       3254.15      -2.20936       22376.4
# 95.3561      0.00883836   -1       3257.34      -2.21318       22673.9
# 95.3559      0.00871293   -1       3260.47      -2.21691       22970.4
# 95.3557      0.00858903   -1       3263.54      -2.22055       23265.9
# 95.3555      0.00846664   -1       3266.56      -2.22411       23560.4
# 95.3554      0.00834572   -1       3269.52      -2.22760       23853.7
# 95.3552      0.00822623   -1       3272.43      -2.23101       24145.9
# 95.3551      0.00810815   -1       3275.29      -2.23434       24436.9
# 95.3549      0.00799145   -1       3278.09      -2.23760       24726.7
# 95.3548      0.00787611   -1       3280.85      -2.24078       25015.2
# 95.3546      0.0077621    -1       3283.55      -2.24390       25302.4
# 95.3545      0.00764941   -1       3286.21      -2.24694       25588.2
# 95.3543      0.00753802   -1       3288.82      -2.24992       25872.6
# 95.3542      0.00742792   -1       3291.38      -2.25284       26155.5
#     0.00731908   -1       3293.89      -2.25569       26437.1
# 95.354       0.00721149   -1       3296.36      -2.25848       26717.1
# 95.3539      0.00710515   -1       3298.79      -2.26121       26995.5
# 95.3538      0.00700004   -1       3301.18      -2.26387       27272.5
# 95.3536      0.00689615   -1       3303.52      -2.26648       27547.8
# 95.3535      0.00679347   -1       3305.82      -2.26904       27821.5
# 95.3534      0.00669199   -1       3308.08      -2.27154       28093.6
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  7.1494E+02| -0.0028  -1.0000   0.0000
#  1.2668E+09|  1.0000  -0.0028  -0.0004
#  2.7237E+18|  0.0004   0.0000   1.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.326e+11   1.443e+10   1.084e+15
#    1.443e+10   4.828e+08   3.626e+13
#    1.084e+15   3.626e+13   2.724e+18
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3308.08      +/-  6.57727E+05
#    2    2   powerlaw   PhoIndex            -2.27154     +/-  2.19732E+04
#    3    2   powerlaw   norm                2.80936E+04  +/-  1.65038E+09
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 95.3534     using 44 bins.
#
# Test statistic : Chi-Squared                 32.5011     using 44 bins.
#  Null hypothesis probability of 8.2576e-01 with 41 degrees of freedom
#  Model Flux 0.00010633 photons (2.017e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 855.5, 657.5, -0.5)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 53.8219681°
# - DEC = -27.5251507°
#
# 53.82 -27.53
#
# **Column density :** nH = 1*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss (Second best fit)"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec (Best fit)"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 96743932676825.22
#
# bremss (Second best fit)
# (tbabs) : 2.4208745048452343e+20
#
# apec (Best fit)
# (tbabs) : 3.412654318606745e+20
#
# powerlaw
# (tbabs) : 3.3080770100945536e+25

# %% [markdown]
# ## Flux
# ### X-ray flux
# - X-ray flux of the best-fitting model ``Apec`` with C-statistic = 54.4515 using 44 bins: **1.0759e-13 ergs/cm^2/s**.
# - X-ray flux of the second best-fitting model ``Bremss`` with C-statistic = 54.9269 using 44 bins: **1.1895e-13 ergs/cm^2/s**.

# %%
Flux = 1.0759e-13 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END)
print(f"Apec : F_x-ray = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux :
# Apec : F_x-ray = 1.0759e-13 ergs/cm^2/s

# %% [markdown]
# ### Optical flux
# No GAIA information, so we use the lower limit of 20.7 mag.

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)
    
G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical flux (lower limit) : "+color.END+f"F_optical = {F} ergs/cm^2/s")
# Out:
# Optical flux (lower limit) : F_optical = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 1.9524620823396708

# %% [markdown]
# ## Luminosity
# No distance or parallax data is available on ESASky.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s

print(color.BOLD+"Luminosity of a galactic source with d = [1 pc - 30 kpc] :"+color.END)
print(f"Apec : F_x-ray = [{L1}, {L2}] erg/s")
print()

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s


print(color.BOLD+"Luminosity of an extragalactic source with d = [1 Mpc - 10 Gpc] :"+color.END)
print(f"Apec : F_x-ray = [{L1}, {L2}] erg/s")
# Out:
# Luminosity of a galactic source with d = [1 pc - 30 kpc] :
# Apec : F_x-ray = [1.287327872798274e+25, 1.287327872798274e+31] erg/s
#
# Luminosity of an extragalactic source with d = [1 Mpc - 10 Gpc] :
# Apec : F_x-ray = [1.2873278727982741e+37, 1.287327872798274e+45] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L = 4*np.pi*Flux*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L,D_pc, lw=1, color='darkseagreen', label="Apec")
plt.legend(loc='best')
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
