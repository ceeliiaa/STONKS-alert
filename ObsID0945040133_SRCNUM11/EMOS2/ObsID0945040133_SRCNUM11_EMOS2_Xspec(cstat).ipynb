# %% [markdown]
# # ObsID : 0945040133, SRCNUM : 11, Instru : EMOS2
# Not on Simbad.

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=54.38275000000001%20-28.289333333333335&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J033731.8-281722
# - IAU name : 4XMM J033731.8-281721
# - RA : 03h 37m 31.839s
# - DEC : -28° 17' 22.01"

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files
# Spectrum, Background, Response, Auxiliary response.

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945040133_SRCNUM11_EMOS2_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.490e-03 +/- 6.686e-04 (74.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-51
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.114e+04 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0945040133_SRCNUM11_EMOS2_background_spectrum.fits
#   Background Exposure Time: 1.114e+04 sec
#  Using Response (RMF) File            ObsID0945040133_SRCNUM11_EMOS2.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945040133_SRCNUM11_EMOS2.arf

# %%
n_cts = 3.490e-03*1.115e+04

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 38.9135
#
# The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
#      4 channels (1-4) ignored in spectrum #     1
#       No channels ignored (no channels in specified range)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 860.5, 661.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              1.511031e+07     using 47 bins.
#
# Test statistic : Chi-Squared              4.974244e+12     using 47 bins.
#  Null hypothesis probability of 0.000000e+00 with 44 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 2.1244e+06   3.07049e+06  -3     0.0772352       1.10619     0.0225377
# 100.589      1.57222e+07  -4     0.0120940       199.317     0.0111383
# 89.5996      37.3662      -4    0.00370666       79.1653    0.00500387
# 86.7483      273.901      -5    0.00152416       199.356      0.348339
# 84.8483      6.48192      -3   0.000722479       199.361      0.158174
# 84.7896      4.9097        0   0.000178405       199.356      0.160115
# 84.7382      4.74494       0   4.30143e-05       199.351      0.161966
# 84.6917      4.58898       0   9.31989e-06       199.346      0.163728
# 84.6493      4.4434        0   9.33008e-07       199.341      0.165403
# 84.6103      4.30801       0   4.11019e-07       199.337      0.166992
# 84.5739      4.17845       0   1.26286e-07       199.332      0.168533
# .50492e-08       199.328      0.169982
# 84.511       3.9151        0   1.94076e-08       199.324      0.171342
# 84.4839      3.79895       0   1.57681e-09       199.321      0.172618
# 84.4593      3.6921        0   4.61758e-10       199.317      0.173815
# 84.4369      3.59376       0   1.83081e-10       199.314      0.174935
# 84.4166      3.50342       0   4.36735e-11       199.311      0.175985
# 84.3982      3.42069       0   9.00527e-12       199.308      0.176962
# 84.3815      3.34196       0   1.59283e-13       199.305      0.177871
# 84.3609      3.21376       0   1.95941e-14       199.302      0.179030
# 84.3435      3.27134       0   5.12676e-15       199.299      0.180038
# 84.3075      3.0983        0   1.03426e-15       199.293      0.182226
# 84.1719      2.68064       0   4.81858e-16       199.262      0.192295
# 84.17        10.5612       1   2.22949e-16       199.261      0.192469
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.22949e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 84.1484      2.73335       0   2.22949e-16       199.255      0.194510
# 84.0847      2.50627       0   2.22949e-16       199.231      0.202022
# 84.0507      1.70536      -1   2.22949e-16       199.199      0.208187
# 84.0399      1.0117       -1   2.22949e-16       199.179      0.211339
# 84.038       0.668313     -1   2.22949e-16       199.160      0.212011
# 84.0353      0.591503     -1   2.22949e-16       199.145      0.213271
# 84.0348      0.455184     -1   2.22949e-16       199.130      0.213467
# 84.0346      0.429912     -1   2.22949e-16       199.115      0.213582
# 84.0341      0.41299      -1   2.22949e-16       199.100      0.213802
# 84.0338      0.385468     -1   2.22949e-16       199.086      0.213940
# 84.0333      0.366581     -1   2.22949e-16       199.073      0.214263
# 84.0322      0.329014      0   2.22949e-16       199.067      0.215205
# 84.0317      0.230618      0   2.22949e-16       199.063      0.215826
# 84.0315      0.165964      0   2.22949e-16       199.059      0.216257
# 84.0314      0.121143      0   2.22949e-16       199.056      0.216506
# 84.0313      0.0949714     0   2.22949e-16       199.054      0.216657
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.22949e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 84.0313      0.0788647     0   2.22949e-16       199.052      0.216802
# ==============================
#  Variances and Principal Axes
#                  2        3
#  4.9563E-03| -0.0033   1.0000
#  2.6077E+08|  1.0000   0.0033
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    2.608e+08   8.485e+05
#    8.485e+05   2.761e+03
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.22949E-16  +/-  -1.00000
#    2    2   bbody      kT         keV      199.052      +/-  1.61482E+04
#    3    2   bbody      norm                0.216802     +/-  52.5446
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 84.0313     using 47 bins.
#
# Test statistic : Chi-Squared                 38.2826     using 47 bins.
#  Null hypothesis probability of 7.1435e-01 with 44 degrees of freedom
#  Model Flux 1.5616e-05 photons (1.997e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 656.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model (Second best fit)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              3.346219e+06     using 47 bins.
#
# Test statistic : Chi-Squared              1.433876e+11     using 47 bins.
#  Null hypothesis probability of 0.000000e+00 with 44 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 1.06444e+06  616895       -3      0.360030       199.361      0.360165
# 37734.1      508539       -4      0.114313       199.363     0.0103672
# 6716.27      614729       -5     0.0545028       199.363    0.00178604
# 822.235      659195       -6    0.00393012       88.4171   0.000197019
# 409.635      846678       -7    0.00111795       38.6056   9.19819e-05
# 68.8321      978106       -8   0.000461659       11.7219   2.09011e-06
# 45.6956      2.25797e+06  -9     0.0424126       5.55397   5.20433e-06
# 36.0389      836325      -10     0.0118849       8.56329   7.33820e-06
# 34.5093      299330      -11    0.00587084       9.03355   8.41673e-06
# 34.2746      100200      -12   8.51802e-05       9.29796   8.51466e-06
# 34.2674      69081       -13   1.54030e-05       9.28280   8.52429e-06
# 34.2666      67369       -14   6.71199e-06       9.27635   8.52462e-06
# 34.2602      67261.4      -2   2.45942e-06       9.23161   8.53228e-06
# 34.2592      65903.4      -2   3.33821e-07       9.21921   8.53261e-06
# 34.2582      65788.1      -2   6.85391e-08       9.20724   8.53287e-06
# 34.258       65690.9      -2   2.22605e-09       9.20461   8.53292e-06
# 34.216       65671.5      -1   4.82062e-10       8.85166   8.58404e-06
# 34.2083      56648.3      -1   4.82239e-11       8.77743   8.59348e-06
# 34.2071      54986        -1   2.11241e-11       8.76501   8.59500e-06
# 34.1524      54717.5       0   8.49782e-12       8.21758   8.68652e-06
# 34.1303      39890.4       0   2.66869e-12       7.96240   8.74201e-06
# 34.1209      31569.5       0   1.24991e-12       7.84516   8.77302e-06
# 34.1166      27083.9       0   5.50157e-13       7.78767   8.78971e-06
# 34.1156      24707.1       0   1.77583e-13       7.77401   8.79379e-06
# 34.1104      24128.6       0   3.18318e-14       7.69001   8.81529e-06
# 34.0942      21100.1      -1   6.18629e-15       7.19786   8.94099e-06
# 34.0942      4511.72       0   1.60843e-15       7.19948   8.94230e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.4837E-12| -0.0000   0.0000   1.0000
#  1.2050E-03|  1.0000   0.0032   0.0000
#  5.5761E+01| -0.0032   1.0000  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.767e-03  -1.770e-01   5.663e-08
#   -1.770e-01   5.576e+01  -6.312e-06
#    5.663e-08  -6.312e-06   4.309e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.60843E-15  +/-  4.20345E-02
#    2    2   bremss     kT         keV      7.19948      +/-  7.46730
#    3    2   bremss     norm                8.94230E-06  +/-  2.07587E-06
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 34.0942     using 47 bins.
#
# Test statistic : Chi-Squared                 34.0159     using 47 bins.
#  Null hypothesis probability of 8.6102e-01 with 44 degrees of freedom
#  Model Flux 2.2415e-05 photons (4.9606e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 859.5, 659.5, -0.5)

# %% [markdown]
# ### Apec model (Best fit)

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic              1.183714e+06     using 47 bins.
#
# Test statistic : Chi-Squared              1.599575e+10     using 47 bins.
#  Null hypothesis probability of 0.000000e+00 with 44 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 700283       341355       -3      0.359565       38.1822      0.443397
# 373000       277696       -4     0.0544529       61.2111      0.191872
# 11484.2      339184       -5     0.0131412       63.8874    0.00578248
# 8846.82      342546       -6    0.00355379      0.236249    0.00184781
# 1470.92      813551       -7   2.79925e-05       15.1547   0.000619498
# 1033.41      456212       -3   1.01351e-05       1.33775   0.000222183
# 46.506       895490       -4   1.44180e-06       11.8106   4.36600e-05
# 44.4527      190987       -1   3.63501e-07       6.91636   1.23050e-05
# -2   1.65651e-07       8.55456   1.92245e-05
# 34.0502      114524       -3   6.03890e-08       7.53637   2.23116e-05
# 33.9864      33440.5      -4   2.70410e-08       7.59338   2.27105e-05
# 33.9857      25314.5      -5   1.01128e-08       7.59591   2.27169e-05
# 33.9856      25196        -4   1.64856e-09       7.59574   2.27170e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.6006E-11| -0.0001  -0.0000   1.0000
#  1.7200E-03|  1.0000   0.0029   0.0001
#  4.6819E+01| -0.0029   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.124e-03  -1.375e-01   1.019e-07
#   -1.375e-01   4.682e+01   5.198e-06
#    1.019e-07   5.198e-06   2.457e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.64856E-09  +/-  4.60872E-02
#    2    2   apec       kT         keV      7.59574      +/-  6.84241
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.27170E-05  +/-  4.95693E-06
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 33.9856     using 47 bins.
#
# Test statistic : Chi-Squared                 31.8180     using 47 bins.
#  Null hypothesis probability of 9.1460e-01 with 44 degrees of freedom
#  Model Flux 2.1017e-05 photons (5.1679e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 860.5, 661.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremsserlaw = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              8.344326e+06     using 47 bins.
#
# Test statistic : Chi-Squared              9.923528e+11     using 47 bins.
#  Null hypothesis probability of 0.000000e+00 with 44 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 1.64726e+06  2.13986e+06  -3      0.356329       6.32204      0.415633
# 103.202      1.70456e+06  -4       5101.59      -1.13283      0.206263
# 99.9093      4.51505e-14  -5       2418.97       7.19383   2.63339e+13
# 84.8456      1.22785      -2       3324.44       4.15005   1.67166e+14
# 84.8201      1.18263      -3       3524.73       3.75773   2.80198e+14
# 84.6301      1.28772      -3       3672.41       3.45865   4.26143e+14
# 84.5385      0.891612     -3       3800.22       3.20679   6.12101e+14
# 84.4879      0.642025     -3       3911.39       2.99192   8.39279e+14
# 84.457       0.477143     -3       4008.84       2.80630   1.10789e+15
# 84.4366      0.3637       -3       4094.93       2.64419   1.41729e+15
# 84.4223      0.282987     -3       4171.52       2.50131   1.76605e+15
# 84.4122      0.221431     -3       4233.96       2.38577   2.11745e+15
# 84.4052      0.165745     -3       4290.87       2.28151   2.49752e+15
# 84.3995      0.136334     -3       4342.76       2.18693   2.90456e+15
# 84.395       0.113681     -3       4390.25       2.10075   3.33635e+15
# 84.3912      0.0955611    -3       4433.86       2.02193   3.79053e+15
# 84.3881      0.0808862    -3       4474.01       1.94963   4.26468e+15
# 84.3854      0.0688846    -3       4511.09       1.88310   4.75636e+15
# 84.3832      0.0589846    -3       4545.40       1.82173   5.26316e+15
# 84.3813      0.0507553    -3       4577.22       1.76499   5.78272e+15
# 84.3797      0.0438676    -3       4606.79       1.71242   6.31275e+15
# 84.3783      0.0380669    -3       4634.30       1.66363   6.85106e+15
# 84.3771      0.0331544    -3       4659.95       1.61827   7.39557e+15
# 84.376       0.0289729    -3       4683.90       1.57604   7.94433e+15
# 84.3751      0.0253969    -3       4706.28       1.53667   8.49551e+15
# 84.3743      0.0223259    -3       4727.22       1.49992   9.04741e+15
# 84.3736      0.0196782    -3       4746.84       1.46558   9.59846e+15
# 84.373       0.0173872    -3       4765.24       1.43345   1.01472e+16
# 84.3725      0.0153982    -3       4782.52       1.40337   1.06924e+16
# 84.372       0.0136662    -3       4798.74       1.37518   1.12329e+16
# 84.3716      0.0121536    -3       4814.00       1.34875   1.17675e+16
# 84.3712      0.0108291    -3       4828.36       1.32394   1.22954e+16
# 84.3709      0.00966636   -3       4841.88       1.30064   1.28158e+16
# 84.3706      0.00864328   -3       4854.61       1.27874   1.33278e+16
# 84.3704      0.00774108   -3       4866.62       1.25816   1.38310e+16
# 84.3701      0.00694385   -3       4877.95       1.23880   1.43248e+16
# 84.3699      0.006238     -3       4888.63       1.22058   1.48087e+16
# 84.3697      0.0056119    -3       4898.73       1.20343   1.52824e+16
# 84.3696      0.00505558   -3       4908.26       1.18728   1.57457e+16
# 84.3694      0.00456043   -3       4917.27       1.17206   1.61982e+16
# 84.3693      0.00411903   -3       4925.79       1.15773   1.66398e+16
# 84.3692      0.00372496   -3       4933.85       1.14421   1.70705e+16
# 84.3691      0.00337264   -3       4941.48       1.13147   1.74901e+16
# 84.369       0.0030572    -3       4948.70       1.11946   1.78988e+16
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  0.0000E+00|  0.0000  -1.0000   0.0000
#  1.5984E+10|  1.0000   0.0000  -0.0000
#  8.5241E+42| -0.0000   0.0000  -1.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.678e+12   1.643e+11   8.082e+27
#    1.643e+11   3.524e+09   1.733e+26
#    8.082e+27   1.733e+26   8.524e+42
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4948.70      +/-  2.77098E+06
#    2    2   powerlaw   PhoIndex            1.11946      +/-  5.93620E+04
#    3    2   powerlaw   norm                1.78988E+16  +/-  2.91960E+21
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 84.3690     using 47 bins.
#
# Test statistic : Chi-Squared                 59.0610     using 47 bins.
#  Null hypothesis probability of 6.4095e-02 with 44 degrees of freedom
#  Model Flux   0.10327 photons (1.9666e-09 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremsserlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 659.5, -0.5)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 54.3826624°
# - Dec: -28.2894459°
#
# 54.38 -28.29
#
# **Column density :** nH = 2*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss (Second best fit)"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec (Best fit)"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_bremsserlaw*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 2229494.7568418826
#
# bremss (Second best fit)
# (tbabs) : 16084306.06560011
#
# apec (Best fit)
# (tbabs) : 16485565231590.666
#
# powerlaw
# (tbabs) : 4.9486952455188644e+25

# %% [markdown]
# ## Flux
# ### X-ray flux
# - X-ray flux of the best-fitting model ``Apec`` with C-statistic = 33.9856 using 47 bins: **5.1679e-14 ergs/cm^2/s**.
# - X-ray flux of the second best-fitting model ``Bremss`` with C-statistic = 34.0942 using 47 bins: **4.9609e-14 ergs/cm^2/s**.

# %%
Flux_apec = 5.1679e-14 # ergs/cm^2/s
Flux_bremss = 4.9609e-14 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END)
print(f"Apec : F_x-ray = {Flux_apec} ergs/cm^2/s")
print(f"Bremss : F_x-ray = {Flux_bremss} ergs/cm^2/s")
# Out:
# X-ray flux :
# Apec : F_x-ray = 5.1679e-14 ergs/cm^2/s
# Bremss : F_x-ray = 4.9609e-14 ergs/cm^2/s

# %% [markdown]
# ### Optical flux
# No magnitude value from GAIA is available, so we use GAIA's limiting magnitude of G = 20.7.

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)
    
G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical flux (lower limit) : "+color.END+f"F_optical = {F} ergs/cm^2/s")
# Out:
# Optical flux (lower limit) : F_optical = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END)
print(f"Apec : F_x-ray/F_optical = {Flux_apec/F} ergs/cm^2/s")
print(f"Bremss : F_x-ray/F_optical = {Flux_bremss/F} ergs/cm^2/s")
# Out:
# X-ray flux / Optical flux ratio :
# Apec : F_x-ray/F_optical = 0.9378314708916428 ergs/cm^2/s
# Bremss : F_x-ray/F_optical = 0.9002666738803674 ergs/cm^2/s

# %% [markdown]
# ## Luminosity
# No distance or parallax data is available on ESASky.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1_apec = 4*np.pi*Flux_apec*(d1_cm)**2 # erg/s
L2_apec = 4*np.pi*Flux_apec*(d2_cm)**2 # erg/s
L1_bremss = 4*np.pi*Flux_bremss*(d1_cm)**2 # erg/s
L2_bremss = 4*np.pi*Flux_bremss*(d2_cm)**2 # erg/s

print(color.BOLD+"Luminosity of a galactic source with d = [1 pc - 30 kpc] :"+color.END)
print(f"Apec : [{L1_apec}, {L2_apec}] erg/s")
print(f"Bremss : [{L1_bremss}, {L2_bremss}] erg/s")
print()

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1_apec = 4*np.pi*Flux_apec*(d1_cm)**2 # erg/s
L2_apec = 4*np.pi*Flux_apec*(d2_cm)**2 # erg/s
L1_bremss = 4*np.pi*Flux_bremss*(d1_cm)**2 # erg/s
L2_bremss = 4*np.pi*Flux_bremss*(d2_cm)**2 # erg/s

print(color.BOLD+"Luminosity of an extragalactic source with d = [1 Mpc - 10 Gpc] :"+color.END)
print(f"Apec : [{L1_apec}, {L2_apec}] erg/s")
print(f"Bremss : [{L1_bremss}, {L2_bremss}] erg/s")
# Out:
# Luminosity of a galactic source with d = [1 pc - 30 kpc] :
# Apec : [6.183457304428108e+24, 6.183457304428107e+30] erg/s
# Bremss : [5.935779202681437e+24, 5.935779202681437e+30] erg/s
#
# Luminosity of an extragalactic source with d = [1 Mpc - 10 Gpc] :
# Apec : [6.183457304428107e+36, 6.183457304428108e+44] erg/s
# Bremss : [5.935779202681438e+36, 5.935779202681437e+44] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L_apec = 4*np.pi*Flux_apec*(d_cm)**2 # erg/s
L_bremss = 4*np.pi*Flux_bremss*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L_apec,D_pc, lw=1, color='darkseagreen', label="Apec")
plt.plot(L_bremss,D_pc, lw=1, color='firebrick', label="Bremss")
plt.legend(loc='best')
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
