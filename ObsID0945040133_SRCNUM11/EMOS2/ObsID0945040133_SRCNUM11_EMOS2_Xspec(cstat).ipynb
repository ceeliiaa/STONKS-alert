# %% [markdown]
# # ObsID : 0945040133, SRCNUM : 11, Instru : EMOS2
# Not on Simbad

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=54.38275000000001%20-28.289333333333335&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J033731.8-281722
# - IAU name : 4XMM J033731.8-281721
# - RA : 03h 37m 31.839s
# - DEC : -28° 17' 22.01"

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files
# Spectrum, Background, Response, Auxiliary response.

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945040133_SRCNUM11_EMOS2_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.490e-03 +/- 6.686e-04 (74.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-51
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.114e+04 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0945040133_SRCNUM11_EMOS2_background_spectrum.fits
#   Background Exposure Time: 1.114e+04 sec
#  Using Response (RMF) File            ObsID0945040133_SRCNUM11_EMOS2.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945040133_SRCNUM11_EMOS2.arf

# %%
n_cts = 3.490e-03*1.115e+04

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 38.9135
#
# The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
spec.ignore("**-0.2 12-**")
# Out:
#      4 channels (1-4) ignored in spectrum #     1
#     40 channels (12,51) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 860.5, 661.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic                28578.14     using 7 bins.
#
# Test statistic : Chi-Squared              3.944100e+07     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 15.603       6327.05      -3     0.0307368       199.341      0.362944
# 13.0876      0.337871     -2       457.496       44.9278       398.015
# 7.72219      0.029716     -2       321.682       46.1269       348.452
# 4.39314      0.0471025    -3       49.6609       94.0502       57.3059
# 3.90758      0.020324     -2       23.6573       103.753       46.0822
# 3.90362      0.00828798    0       22.6028       99.4788       46.8442
# 3.88688      0.00772892    0       22.7551       99.7201       46.5063
# 3.87718      0.0058137     0       22.8610       99.9082       46.2453
using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 16.0313      2791.28      -2       14.2623      0.101012      0.428524
# 16.0313      9.75552e-05  -3       6.65593     0.0439588      0.210471
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 1
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 2
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 5
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  7.4113E+10|  0.8003  -0.0076   0.5996
#  7.4113E+12| -0.0029   0.9999   0.0165
#  5.8264E+16| -0.5996  -0.0150   0.8002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#   -3.899e+28   3.682e+26  -2.921e+28
#    3.682e+26  -3.477e+24   2.758e+26
#   -2.921e+28   2.758e+26  -2.188e+28
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    6.65593      +/-  -1.00000
#    2    2   apec       kT         keV      4.39588E-02  +/-  -1.00000
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                0.210471     +/-  -1.00000
# ________________________________________________________________________
#
#
#                  16.0313     using 7 bins.
#
# Test statistic : Chi-Squared                  5.3777     using 7 bins.
#  Null hypothesis probability of 2.5069e-01 with 4 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 852.5, 654.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                27071.75     using 7 bins.
#
# Test statistic : Chi-Squared              3.422756e+07     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 16.0313      6419.75       0       535.718       6.75139    0.00273412
# 4.28474      4.89836e-07   7       185.961       1.20571      0.948389
# 4.28474      0.866968      6       185.961       1.20571      0.948389
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.4692E-02| -0.0083  -0.8789   0.4770
#  1.7602E+04|  0.0581  -0.4766  -0.8772
#  6.9103E+11|  0.9983   0.0205   0.0550
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.886e+11   1.413e+10   3.795e+10
#    1.413e+10   2.901e+08   7.789e+08
#    3.795e+10   7.789e+08   2.092e+09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    185.961      +/-  8.29846E+05
#    2    2   powerlaw   PhoIndex            1.20571      +/-  1.70314E+04
#    3    2   powerlaw   norm                0.948389     +/-  4.57355E+04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  4.2847     using 7 bins.
#
# Test statistic : Chi-Squared                  6.5711     using 7 bins.
#  Null hypothesis probability of 1.6037e-01 with 4 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 854.5, 659.5, -0.5)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 54.3826624°
# - Dec: -28.2894459°
#
# 54.38 -28.29
#
# **Column density :** nH = 2*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 2.2909493293210074e+23
#
# bremss
# (tbabs) : 9.87835521363811e+22
#
# apec
# (tbabs) : 6.655934488349814e+22
#
# powerlaw
# (tbabs) : 1.85961230645079e+24

# %% [markdown]
# ## Flux
# ### X-ray flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux  0.033743 photons (5.3166e-10 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 5.3166e-10 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END+f"F_X = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux : F_X = 5.3166e-10 ergs/cm^2/s

# %% [markdown]
# ### Optical flux

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)
    
G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
print(f"F_x-ray = {Flux/F}*F_optical")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 9648.16424106989
# F_x-ray = 9648.16424106989*F_optical

# %% [markdown]
# ## Luminosity
# No distance or parallax is available on ESASky.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s

print(color.BOLD+"For a star in the milky way? with d=[1 pc - 30 kpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s


print(color.BOLD+"For a galaxy? with d=[1 Mpc - 10 Gpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")
# Out:
# For a star in the milky way? with d=[1 pc - 30 kpc] :
# Luminosity : [6.36137872341231e+28, 6.361378723412309e+34] erg/s
# For a galaxy? with d=[1 Mpc - 10 Gpc] :
# Luminosity : [6.36137872341231e+40, 6.36137872341231e+48] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L = 4*np.pi*Flux*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L,D_pc)
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
