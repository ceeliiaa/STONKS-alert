# %% [markdown]
# # ObsID : 0945040133, SRCNUM : 11, Instru : EMOS1
# Not on Simbad

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=54.38275000000001%20-28.289333333333335&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J033731.8-281722
# - IAU name : 4XMM J033731.8-281721
# - RA : 03h 37m 31.839s
# - DEC : -28° 17' 22.01"

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files
# Spectrum, Background, Response, Auxiliary response.

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945040133_SRCNUM11_EMOS1_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.654e-03 +/- 5.583e-04 (52.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-34
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 1.115e+04 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0945040133_SRCNUM11_EMOS1_background_spectrum.fits
#   Background Exposure Time: 1.115e+04 sec
#  Using Response (RMF) File            ObsID0945040133_SRCNUM11_EMOS1.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945040133_SRCNUM11_EMOS1.arf

# %%
n_cts = 1.654e-03*1.115e+04

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 18.4421
#
# The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#       No channels ignored (no channels in specified range)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 661.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              1.176350e+07     using 32 bins.
#
# Test statistic : Chi-Squared              7.632872e+12     using 32 bins.
#  Null hypothesis probability of 0.000000e+00 with 29 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 570144       2.39845e+06  -3     0.0261969       1.00921    0.00649708
# 5      0.484783    0.00258622   0.0047055
# 53.606       2.86234e+07  -5    0.00143827       199.252    0.00121996
# 53.5977      1.61989      -3   0.000450598       199.345   0.000363827
# 53.5957      1.55237      -3   3.77345e-05       199.355   0.000169996
# 53.5944      1.53656      -3   1.01591e-05       199.362   5.62182e-05
# 53.5931      1.52807      -3   4.94863e-06       199.363   8.28923e-07
# 53.5931      1.52413      -3   2.18811e-06       199.363   3.89262e-07
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.6105E-03| -0.0000  -0.0000   1.0000
#  1.4878E+11|  1.0000   0.0001   0.0000
#  2.0898E+19| -0.0001   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.081e+11  -1.114e+15  -1.381e+07
#   -1.114e+15   2.090e+19   2.595e+11
#   -1.381e+07   2.595e+11   3.221e+03
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.18811E-06  +/-  4.56211E+05
#    2    2   bbody      kT         keV      199.363      +/-  4.57146E+09
#    3    2   bbody      norm                3.89262E-07  +/-  56.7572
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 53.5931     using 32 bins.
#
# Test statistic : Chi-Squared                 21.7323     using 32 bins.
#  Null hypothesis probability of 8.3110e-01 with 29 degrees of freedom
#  Model Flux 2.7907e-11 photons (3.5689e-19 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 852.5, 657.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model (Best fit)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              2.689830e+06     using 32 bins.
#
# Test statistic : Chi-Squared              1.559338e+11     using 32 bins.
#  Null hypothesis probability of 0.000000e+00 with 29 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 29336.3      497721       -3      0.130216       2.04698    0.00779059
# 9636.23      635026       -4     0.0555945       198.134    0.00305437
# 1167.52      540296       -5       3.77081       36.5963   0.000911990
# 203.681      218916       -2     0.0584512       9.02776   5.18166e-05
# 40.0502      818085       -3      0.255493       3.10766   1.66886e-05
# 33.444       180702       -4      0.651121      0.928124   4.46673e-05
# 33.0823      1712.17      -1      0.560032      0.814915   4.83208e-05
# 33.0358      3370.27      -2      0.530213      0.800226   4.98788e-05
# 33.0268      166.082      -3      0.491327      0.844678   4.29058e-05
# 33.0186      1405.09      -4      0.475934      0.845241   4.26178e-05
# 33.016       12.0463      -5      0.458483      0.866897   3.99335e-05
# 33.0146      303.78       -6      0.452124      0.864613   3.98521e-05
# 33.014       2.6384       -7      0.442883      0.878557   3.83850e-05
# 33.0137      111.364      -8      0.441322      0.872813   3.87026e-05
# 33.0135      10.1194      -9      0.435445      0.884528   3.76263e-05
# 33.0135      69.0973     -10      0.435806      0.877666   3.80879e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.1945E-10| -0.0001   0.0001   1.0000
#  4.7793E-02|  0.9179   0.3969   0.0000
#  7.2831E-01| -0.3969   0.9179  -0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.550e-01  -2.479e-01   2.348e-05
#   -2.479e-01   6.211e-01  -5.121e-05
#    2.348e-05  -5.121e-05   4.506e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.435806     +/-  0.393670
#    2    2   bremss     kT         keV      0.877666     +/-  0.788118
#    3    2   bremss     norm                3.80879E-05  +/-  6.71284E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 33.0135     using 32 bins.
#
# Test statistic : Chi-Squared                 25.3567     using 32 bins.
#  Null hypothesis probability of 6.5961e-01 with 29 degrees of freedom
#  Model Flux 7.2129e-06 photons (1.6255e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 855.5, 656.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic                974046.9     using 32 bins.
#
# Test statistic : Chi-Squared              2.131414e+10     using 32 bins.
#  Null hypothesis probability of 0.000000e+00 with 29 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 53.5931      282389       -3       3557.83      0.430922      0.421899
# 53.5931      5.30647e-23  -4       999999.       47.8960   1.00000e+24
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
# ***Warning: Zero alpha-matrix diagonal element for parameter 2
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 1 is pegged at 999999 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 2 is pegged at 47.896 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 5 is pegged at 1e+24 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***XSPEC Error:  No variable parameters for fit
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 AllModels.clear()
#       2 mo = Model("tbabs*apec")
# ----> 3 Fit.perform()
#       4 Plot.device = "/xs"
#       5 Plot("data resid")
#
# File /mnt/c/Users/acer/HEASoft/heasoft-6.34/x86_64-pc-linux-gnu-libc2.35/lib/python/xspec/fit.py:533, in FitManager.perform(self)
#     530 """Perform a fit."""
#     532 fitArgs = ["fit"]
# --> 533 _pyXspec.doXspecCmd(fitArgs)
#
# Exception: Error executing command: fit

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
AllModels.calcFlux(".2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              6.627050e+06     using 32 bins.
#
# Test statistic : Chi-Squared              1.356522e+12     using 32 bins.
#  Null hypothesis probability of 0.000000e+00 with 29 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 53.5931      1.68817e+06  -3       19434.0       6.41609       132541.
# 53.5931      2.64013e-62  -4       4256.45       8.28178       25761.3
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 1
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 2
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 3
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0000E+18|  0.0001   0.0000   1.0000
#  1.0000E+18| -0.0029  -1.0000   0.0000
#  6.8891E+133|  1.0000  -0.0029  -0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#  -9.586e+139 -1.928e+138 -7.242e+143
#  -1.928e+138 -3.877e+136 -1.456e+142
#  -7.242e+143 -1.456e+142 -5.471e+147
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4256.45      +/-  -1.00000
#    2    2   powerlaw   PhoIndex            8.28178      +/-  -1.00000
#    3    2   powerlaw   norm                2.57613E+04  +/-  -1.00000
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 53.5931     using 32 bins.
#
# Test statistic : Chi-Squared                 21.7323     using 32 bins.
#  Null hypothesis probability of 8.3110e-01 with 29 degrees of freedom
#  Model Flux 4.5255e-19 photons (8.5971e-27 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 852.5, 651.5, -0.5)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 54.3826624°
# - Dec: -28.2894459°
#
# 54.38 -28.29
#
# **Column density :** nH = 2*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss (Best fit)"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 2.188114320492893e+16
#
# bremss (Best fit)
# (tbabs) : 4.3580612803027277e+21
#
# powerlaw
# (tbabs) : 4.256447555099148e+25

# %% [markdown]
# ## Flux
# ### X-ray flux
# - X-ray flux of the best-fitting model ``Bremss`` with C-statistic = 33.0135 using 32 bins: **1.6254e-13 ergs/cm^2/s**.

# %%
Flux = 1.6255e-14 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END)
print(f"Bremss model : F_x-ray = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux :
# Bremss model : F_x-ray = 1.6255e-14 ergs/cm^2/s

# %% [markdown]
# ### Optical flux
# No magnitude value from GAIA is available, so we use GAIA's limiting magnitude of G = 20.7.

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)
    
G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 0.29498346638564316

# %% [markdown]
# ## Luminosity
# No distance or parallax data is available on ESASky.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s

print(color.BOLD+"For a star in the milky way? with d=[1 pc - 30 kpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s


print(color.BOLD+"For a galaxy? with d=[1 Mpc - 10 Gpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")
# Out:
# For a star in the milky way? with d=[1 pc - 30 kpc] :
# Luminosity : [1.9449311806242164e+24, 1.9449311806242163e+30] erg/s
# For a galaxy? with d=[1 Mpc - 10 Gpc] :
# Luminosity : [1.9449311806242164e+36, 1.9449311806242165e+44] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L = 4*np.pi*Flux*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L,D_pc)
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
