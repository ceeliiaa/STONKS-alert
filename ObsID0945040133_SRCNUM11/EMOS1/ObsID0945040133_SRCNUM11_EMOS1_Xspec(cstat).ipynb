# %% [markdown]
# # ObsID : 0945040133, SRCNUM : 11, Instru : EMOS1
# Not on Simbad

# %% [markdown]
# ## ESASky
#
# https://sky.esa.int/esasky/?target=54.38275000000001%20-28.289333333333335&hips=XMM-Newton+EPIC+color&fov=1&projection=SIN&cooframe=J2000&sci=true&lang=fr
#
# ``EPIC Stack``
# - Stack Catalogue name : 4XMMs J033731.8-281722
# - IAU name : 4XMM J033731.8-281721
# - RA : 03h 37m 31.839s
# - DEC : -28° 17' 22.01"

# %%
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

plt.rcParams['figure.figsize'] = [12,7]

# %% [markdown]
# ## Fit statistic

# %%
Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# Parameter delta values for fits will now be 0.0001 * parValue

# %% [markdown]
# ## Load files
# Spectrum, Background, Response, Auxiliary response.

# %%
AllData.clear()
spec = Spectrum(glob.glob('ObsID*_SRCNUM*_E*_spectrum_grp_cstat.fits')[0])
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: ObsID0945040133_SRCNUM11_EMOS1_spectrum_grp_cstat.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.654e-03 +/- 5.583e-04 (52.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-34
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 1.115e+04 sec
#  Using fit statistic: cstat
#  Using Background File                ObsID0945040133_SRCNUM11_EMOS1_background_spectrum.fits
#   Background Exposure Time: 1.115e+04 sec
#  Using Response (RMF) File            ObsID0945040133_SRCNUM11_EMOS1.rmf for Source 1
#  Using Auxiliary Response (ARF) File  ObsID0945040133_SRCNUM11_EMOS1.arf

# %%
n_cts = 1.654e-03*1.115e+04

print("Number of counts =",n_cts)

if int(n_cts)<100:
    print()
    print("The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.")
# Out:
# Number of counts = 18.4421
#
# The low number of counts indicates that we should consider using cstat fit statistic instead of chi statistic.

# %% [markdown]
# ## Plot spectrum

# %%
Plot.xAxis="keV"
Plot.device = "/xs"
Plot.xLog=True
Plot.yLog=True
#Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
spec.ignore("**-0.2 12-**")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#     23 channels (12,34) ignored in spectrum #     1

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 661.5, -0.5)

# %% [markdown]
# ### Black body model

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bbody = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic                45929.64     using 9 bins.
#
# Test statistic : Chi-Squared              8.533638e+07     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 13.5573      10329.1      -2      0.255635       199.293      0.164207
# 9.4714       0.0993791    -3       79.3329       63.7514       17.8324
# 9.26109      0.0156383    -3       93.9539       56.9960       23.5480
# 9.25965      0.00121131   -3       106.888       54.6365       26.5665
# 9.25907      1.45509e-05  -3       119.146       52.4535       29.8649
# 9.25853      8.73239e-05  -3       131.202       50.4527       33.4219
# 9.25802      0.000106067  -3       143.191       48.5944       37.2851
# 9.25754      0.000124541  -3       155.206       46.8468       41.5104
# 9.25706      0.000134883  -3       167.328       45.1888       46.1589
# 9.2566       0.000144882  -3       179.622       43.6045       51.3006
# 9.25613      0.000153503  -3       192.145       42.0822       57.0146
# 9.25497      0.000165515  -4       317.279       27.8445       118.873
# 9.24661      0.00371726   -4       481.837       17.7219       264.171
# 9.24613      0.000123361  -3       501.411       17.0771       298.314
# 9.24563      0.000764776  -3       520.810       16.4624       336.516
# 9.24514      0.00080915   -3       540.067       15.8843       378.757
# 9.24468      0.000826249  -3       559.103       15.3418       425.178
# 9.24425      0.000824191  -3       577.848       14.8342       475.882
# 9.24385      0.000823035  -3       596.235       14.3599       530.948
# 9.24347      0.000809877  -3       614.214       13.9174       590.411
# 9.24313      0.000790711  -3       631.745       13.5051       654.276
# 9.2428       0.000782763  -3       648.794       13.1208       722.549
# 9.24251      0.000750855  -3       665.345       12.7630       795.171
# 9.24224      0.000740488  -3       681.384       12.4295       872.121
# 85       953.32100712952  -3       696.911       12.11
# 9.24176      0.000685691  -3       711.929       11.8281       1038.71
# 9.24155      0.000658305  -3       726.446       11.5569       1128.23
# 9.24136      0.000636516  -3       740.474       11.3031       1221.81
# 9.24118      0.000607172  -3       754.029       11.0652       1319.38
# 9.24102      0.000574355  -3       767.127       10.8421       1420.87
# 9.24087      0.000549965  -3       779.786       10.6326       1526.23
# 9.24073      0.000533932  -3       792.024       10.4354       1635.43
# 9.2406       0.000511652  -3       803.858       10.2496       1748.42
# 9.24048      0.000487529  -3       815.311       10.0742       1865.12
# 9.24037      0.000468166  -3       826.398       9.90843       1985.52
# 9.24027      0.000446089  -3       837.138       9.75142       2109.59
# 9.24017      0.000424482  -3       847.549       9.60258       2237.28
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.5293E+07| -0.0379  -0.9993   0.0020
#  3.5293E+09|  0.9992  -0.0379   0.0100
#  1.4248E+18| -0.0099   0.0024   0.9999
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.390e+14  -3.311e+13  -1.407e+16
#   -3.311e+13   7.888e+12   3.352e+15
#   -1.407e+16   3.352e+15   1.425e+18
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    847.549      +/-  1.17901E+07
#    2    2   bbody      kT         keV      9.60258      +/-  2.80856E+06
#    3    2   bbody      norm                2237.28      +/-  1.19359E+09
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  9.2402     using 9 bins.
#
# sing 9 bins.ic : Chi-Squared                  4.9370     u
#  Null hypothesis probability of 5.5192e-01 with 6 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bbody2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 664.5, -0.5)

# %% [markdown]
# ### Bremsstrahlung model

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_bremss = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                27538.78     using 9 bins.
#
# Test statistic : Chi-Squared              3.486456e+07     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 13.6511      9811.96      -3       1923.78       2.08860       1968.67
# 13.6511      1.87046e-06   5       1745.02       2.64310       4752.97
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.3288E+16| -0.0031   1.0000   0.0002
#  1.6666E+23|  0.9998   0.0031  -0.0175
#  1.7027E+32| -0.0175   0.0001  -0.9998
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.213e+28  -4.315e+26   2.979e+30
#   -4.315e+26   3.572e+24  -2.466e+28
#    2.979e+30  -2.466e+28   1.702e+32
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1745.02      +/-  2.28316E+14
#    2    2   bremss     kT         keV      2.64310      +/-  1.89004E+12
#    3    2   bremss     norm                4752.97      +/-  1.30466E+16
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 13.6511     using 9 bins.
#
# Test statistic : Chi-Squared                  5.0719     using 9 bins.
#  Null hypothesis probability of 5.3462e-01 with 6 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_bremss2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 856.5, 659.5, -0.5)

# %% [markdown]
# ### Apec model

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_apec = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic                34161.05     using 9 bins.
#
# Test statistic : Chi-Squared              8.438921e+07     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 13.6488      24385.3      -3       1632.61       61.8416       2968.70
# 13.5659      3.56904e-06   2       1342.26       25.3605       9817.27
# 13.3444      0.000188716   1       1257.78       58.6252       16647.3
# 235.29       29.1111       19763.6 1
# 11.4603      0.000651907   0       1108.15       56.8201       40853.7
# 11.0563      0.00251626    0       1091.23       25.7001       46814.4
# 9.6986       0.00386861    0       1049.92       45.8857       63759.5
# 9.32669      0.00238734   -1       1032.93       57.9164       73439.2
# 9.2544       0.00132603   -2       1020.33       61.4286       83104.5
# 9.24203      0.000695018  -1       1022.48       63.2015       81640.3
# 9.24042      0.000265081  -1       1023.21       63.6489       81230.6
# 9.2401       0.000137264  -1       1023.51       63.9617       81136.1
# 9.24003      9.42753e-05  -1       1023.66       63.9951       81147.8
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  3.1728E+03|  0.9948   0.1015  -0.0014
#  1.5033E+10| -0.1015   0.9948   0.0032
#  2.7045E+19| -0.0017   0.0031  -1.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.877e+13  -1.424e+14   4.615e+16
#   -1.424e+14   2.575e+14  -8.346e+16
#    4.615e+16  -8.346e+16   2.704e+19
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1023.66      +/-  8.87503E+06
#    2    2   apec       kT         keV      63.9951      +/-  1.60482E+07
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                8.11478E+04  +/-  5.20043E+09
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                  9.2400     using 9 bins.
#
# Test statistic : Chi-Squared                  4.9800     using 9 bins.
#  Null hypothesis probability of 5.4639e-01 with 6 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_apec2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 854.5, 659.5, -0.5)

# %% [markdown]
# ### Powerlaw model

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot.device = "/xs"
Plot("data resid")
nH_powerlaw = mo.TBabs.nH.values[0]
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                48659.81     using 9 bins.
#
# Test statistic : Chi-Squared              1.013597e+08     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 13.6511      14732        -3       5925.30       8.45509       13845.3
# 11.1107      8.48599e-24  18       1866.23       2.48599   4.18573e+08
# 11.1107      2.85013      17       1866.23       2.48599   4.18573e+08
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  0.0000E+00|  0.0000  -1.0000   0.0000
#  1.2891E+11|  1.0000  -0.0000  -0.0000
#  4.3880E+31| -0.0000  -0.0000  -1.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.578e+16   1.448e+15   1.699e+24
#    1.448e+15   3.187e+13   3.739e+22
#    1.699e+24   3.739e+22   4.388e+31
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1866.23      +/-  2.56472E+08
#    2    2   powerlaw   PhoIndex            2.48599      +/-  5.64503E+06
#    3    2   powerlaw   norm                4.18573E+08  +/-  6.62420E+15
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 11.1107     using 9 bins.
#
# Test statistic : Chi-Squared                 12.6264     using 9 bins.
#  Null hypothesis probability of 4.9368e-02 with 6 degrees of freedom

# %%
img = plt.imread(glob.glob('ObsID*_SRCNUM*_E*_Spectrum_powerlaw2.png')[0])
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 854.5, 656.5, -0.5)

# %% [markdown]
# ## Column density nH
# ### 3DNH-tool
# http://astro.uni-tuebingen.de/nh3d/nhtool
#
# **Sky coordinates (°) :**
#
# - RA = 54.3826624°
# - Dec: -28.2894459°
#
# 54.38 -28.29
#
# **Column density :** nH = 2*10^20 cm^-2

# %%
print("The different models give a column density of :")
print()
print(color.BOLD+"bbody"+color.END)
print(f"(tbabs) : {nH_bbody*10**22}")
print()
print(color.BOLD+"bremss"+color.END)
print(f"(tbabs) : {nH_bremss*10**22}")
print()
print(color.BOLD+"apec"+color.END)
print(f"(tbabs) : {nH_apec*10**22}")
print()
print(color.BOLD+"powerlaw"+color.END)
print(f"(tbabs) : {nH_powerlaw*10**22}")
# Out:
# The different models give a column density of :
#
# bbody
# (tbabs) : 8.475491107486553e+24
#
# bremss
# (tbabs) : 1.7450178554145608e+25
#
# apec
# (tbabs) : 1.023655385177795e+25
#
# powerlaw
# (tbabs) : 1.8662315681904688e+25

# %% [markdown]
# ## Flux
# ### X-ray flux

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux   0.54814 photons (1.0286e-08 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Flux = 1.0286e-08 # ergs/cm^2/s
print(color.BOLD+"X-ray flux : "+color.END+f"F_X = {Flux} ergs/cm^2/s")
# Out:
# X-ray flux : F_X = 1.0286e-08 ergs/cm^2/s

# %% [markdown]
# ### Optical flux

# %%
def F_optical(mag):
    F0 = 1.05*10**(-5) # GAIA zero point magnitude
    return F0*10**(-0.4*mag)
    
G = 20.7

F = F_optical(G)

print(color.BOLD+"Optical  flux : "+color.END+f"F_opt = {F} ergs/cm^2/s")
# Out:
# Optical  flux : F_opt = 5.510478332622621e-14 ergs/cm^2/s

# %% [markdown]
# ### X-ray flux / Optical flux ratio

# %%
print(color.BOLD+"X-ray flux / Optical flux ratio : "+color.END+f"F_x-ray/F_optical = {Flux/F}")
print(f"F_x-ray = {Flux/F}*F_optical")
# Out:
# X-ray flux / Optical flux ratio : F_x-ray/F_optical = 186662.56138066598
# F_x-ray = 186662.56138066598*F_optical

# %% [markdown]
# ## Luminosity
# No distance or parallax is available on ESASky.

# %%
# For a star in the milky way : d=[1 pc - 30 kpc]
d_pc = 1 # Distance en pc
d_kpc = 30 # Distance en kpc

d1_cm = d_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_pc*3.0857*10**21 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s

print(color.BOLD+"For a star in the milky way? with d=[1 pc - 30 kpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")

# For a galaxy : d=[1 Mpc - 10 Gpc]
d_Mpc = 1 # Distance en Mpc
d_Gpc = 10 # Distance en Gpc

d1_cm = d_Mpc*3.0857*10**24 # Distance en cm, avec 1 pc = 3.0857*10^18 cm
d2_cm = d_Gpc*3.0857*10**27 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L1 = 4*np.pi*Flux*(d1_cm)**2 # erg/s
L2 = 4*np.pi*Flux*(d2_cm)**2 # erg/s


print(color.BOLD+"For a galaxy? with d=[1 Mpc - 10 Gpc] :"+color.END)
print(f"Luminosity : [{L1}, {L2}] erg/s")
# Out:
# For a star in the milky way? with d=[1 pc - 30 kpc] :
# Luminosity : [1.2307328282928755e+30, 1.2307328282928752e+36] erg/s
# For a galaxy? with d=[1 Mpc - 10 Gpc] :
# Luminosity : [1.2307328282928755e+42, 1.2307328282928755e+50] erg/s

# %%
D_pc = np.arange(1, 10**10, 1000)

d_cm = D_pc*3.0857*10**18 # Distance en cm, avec 1 pc = 3.0857*10^18 cm

# La source est supposée sphérique pour le calcul de la luminosité : L = 4*pi*F*D^2
L = 4*np.pi*Flux*(d_cm)**2 # erg/s

plt.figure(figsize=[10,5])
plt.plot(L,D_pc)
plt.xlabel("Luminosity (erg/s)")
plt.ylabel("Distance (pc)")
plt.xscale("log")
plt.yscale("log")
plt.grid()
